# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
age_90 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1990_Y2020M10D15.CSV')
age_90 = age_90[age_90['sex_id']==3]

age_90_25 = age_90[age_90['age_group_id'] == 10]
age_90_30 = age_90[age_90['age_group_id'] == 11]
age_90_35 = age_90[age_90['age_group_id'] == 12]
age_90_40 = age_90[age_90['age_group_id'] == 13]
age_90_45 = age_90[age_90['age_group_id'] == 14]
age_90_50 = age_90[age_90['age_group_id'] == 15]
age_90_55 = age_90[age_90['age_group_id'] == 16]
age_90_60 = age_90[age_90['age_group_id'] == 17]
age_90_65 = age_90[age_90['age_group_id'] == 18]
age_90_70 = age_90[age_90['age_group_id'] == 19]
age_90_75 = age_90[age_90['age_group_id'] == 20]
age_90_80 = age_90[age_90['age_group_id'] == 21]
age_90_all = age_90[age_90['age_group_id'] == 22]

age_90_list = age_90_all[['location_id','location_name']]
age_90_list['year'] = age_90_all['year_id']
age_90_list['pop_all'] = age_90_all['val']
age_90_list['pop_all_lb'] = age_90_all['lower']
age_90_list['pop_all_ub'] = age_90_all['upper']

age_90_list['pop_25'] = age_90_25['val'].values
age_90_list['pop_25_lb'] = age_90_25['lower'].values
age_90_list['pop_25_ub'] = age_90_25['upper'].values

age_90_list['pop_30'] = age_90_30['val'].values
age_90_list['pop_30_lb'] = age_90_30['lower'].values
age_90_list['pop_30_ub'] = age_90_30['upper'].values

age_90_list['pop_35'] = age_90_35['val'].values
age_90_list['pop_35_lb'] = age_90_35['lower'].values
age_90_list['pop_35_ub'] = age_90_35['upper'].values

age_90_list['pop_40'] = age_90_40['val'].values
age_90_list['pop_40_lb'] = age_90_40['lower'].values
age_90_list['pop_40_ub'] = age_90_40['upper'].values

age_90_list['pop_45'] = age_90_45['val'].values
age_90_list['pop_45_lb'] = age_90_45['lower'].values
age_90_list['pop_45_ub'] = age_90_45['upper'].values

age_90_list['pop_50'] = age_90_50['val'].values
age_90_list['pop_50_lb'] = age_90_50['lower'].values
age_90_list['pop_50_ub'] = age_90_50['upper'].values

age_90_list['pop_55'] = age_90_55['val'].values
age_90_list['pop_55_lb'] = age_90_55['lower'].values
age_90_list['pop_55_ub'] = age_90_55['upper'].values

age_90_list['pop_60'] = age_90_60['val'].values
age_90_list['pop_60_lb'] = age_90_60['lower'].values
age_90_list['pop_60_ub'] = age_90_60['upper'].values

age_90_list['pop_65'] = age_90_65['val'].values
age_90_list['pop_65_lb'] = age_90_65['lower'].values
age_90_list['pop_65_ub'] = age_90_65['upper'].values

age_90_list['pop_70'] = age_90_70['val'].values
age_90_list['pop_70_lb'] = age_90_70['lower'].values
age_90_list['pop_70_ub'] = age_90_70['upper'].values

age_90_list['pop_75'] = age_90_75['val'].values
age_90_list['pop_75_lb'] = age_90_75['lower'].values
age_90_list['pop_75_ub'] = age_90_75['upper'].values

age_90_list['pop_80'] = age_90_80['val'].values
age_90_list['pop_80_lb'] = age_90_80['lower'].values
age_90_list['pop_80_ub'] = age_90_80['upper'].values

age_90_list['pop_25plus'] = age_90_list['pop_25']+age_90_list['pop_30']+age_90_list['pop_35']+age_90_list['pop_40']+age_90_list['pop_45']+age_90_list['pop_50']+age_90_list['pop_55']+age_90_list['pop_60']+age_90_list['pop_65']+age_90_list['pop_70']+age_90_list['pop_75']+age_90_list['pop_80']
age_90_list['pop_25plus_lb'] = age_90_list['pop_25_lb']+age_90_list['pop_30_lb']+age_90_list['pop_35_lb']+age_90_list['pop_40_lb']+age_90_list['pop_45_lb']+age_90_list['pop_50_lb']+age_90_list['pop_55_lb']+age_90_list['pop_60_lb']+age_90_list['pop_65_lb']+age_90_list['pop_70_lb']+age_90_list['pop_75_lb']+age_90_list['pop_80_lb']
age_90_list['pop_25plus_ub'] = age_90_list['pop_25_ub']+age_90_list['pop_30_ub']+age_90_list['pop_35_ub']+age_90_list['pop_40_ub']+age_90_list['pop_45_ub']+age_90_list['pop_50_ub']+age_90_list['pop_55_ub']+age_90_list['pop_60_ub']+age_90_list['pop_65_ub']+age_90_list['pop_70_ub']+age_90_list['pop_75_ub']+age_90_list['pop_80_ub']

age_90_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_90_list.csv', index=False)

# %%
age_91 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1991_Y2020M10D15.CSV')
age_91 = age_91[age_91['sex_id']==3]

age_91_25 = age_91[age_91['age_group_id'] == 10]
age_91_30 = age_91[age_91['age_group_id'] == 11]
age_91_35 = age_91[age_91['age_group_id'] == 12]
age_91_40 = age_91[age_91['age_group_id'] == 13]
age_91_45 = age_91[age_91['age_group_id'] == 14]
age_91_50 = age_91[age_91['age_group_id'] == 15]
age_91_55 = age_91[age_91['age_group_id'] == 16]
age_91_60 = age_91[age_91['age_group_id'] == 17]
age_91_65 = age_91[age_91['age_group_id'] == 18]
age_91_70 = age_91[age_91['age_group_id'] == 19]
age_91_75 = age_91[age_91['age_group_id'] == 20]
age_91_80 = age_91[age_91['age_group_id'] == 21]
age_91_all = age_91[age_91['age_group_id'] == 22]

age_91_list = age_91_all[['location_id','location_name']]
age_91_list['year'] = age_91_all['year_id']
age_91_list['pop_all'] = age_91_all['val']
age_91_list['pop_all_lb'] = age_91_all['lower']
age_91_list['pop_all_ub'] = age_91_all['upper']

age_91_list['pop_25'] = age_91_25['val'].values
age_91_list['pop_25_lb'] = age_91_25['lower'].values
age_91_list['pop_25_ub'] = age_91_25['upper'].values

age_91_list['pop_30'] = age_91_30['val'].values
age_91_list['pop_30_lb'] = age_91_30['lower'].values
age_91_list['pop_30_ub'] = age_91_30['upper'].values

age_91_list['pop_35'] = age_91_35['val'].values
age_91_list['pop_35_lb'] = age_91_35['lower'].values
age_91_list['pop_35_ub'] = age_91_35['upper'].values

age_91_list['pop_40'] = age_91_40['val'].values
age_91_list['pop_40_lb'] = age_91_40['lower'].values
age_91_list['pop_40_ub'] = age_91_40['upper'].values

age_91_list['pop_45'] = age_91_45['val'].values
age_91_list['pop_45_lb'] = age_91_45['lower'].values
age_91_list['pop_45_ub'] = age_91_45['upper'].values

age_91_list['pop_50'] = age_91_50['val'].values
age_91_list['pop_50_lb'] = age_91_50['lower'].values
age_91_list['pop_50_ub'] = age_91_50['upper'].values

age_91_list['pop_55'] = age_91_55['val'].values
age_91_list['pop_55_lb'] = age_91_55['lower'].values
age_91_list['pop_55_ub'] = age_91_55['upper'].values

age_91_list['pop_60'] = age_91_60['val'].values
age_91_list['pop_60_lb'] = age_91_60['lower'].values
age_91_list['pop_60_ub'] = age_91_60['upper'].values

age_91_list['pop_65'] = age_91_65['val'].values
age_91_list['pop_65_lb'] = age_91_65['lower'].values
age_91_list['pop_65_ub'] = age_91_65['upper'].values

age_91_list['pop_70'] = age_91_70['val'].values
age_91_list['pop_70_lb'] = age_91_70['lower'].values
age_91_list['pop_70_ub'] = age_91_70['upper'].values

age_91_list['pop_75'] = age_91_75['val'].values
age_91_list['pop_75_lb'] = age_91_75['lower'].values
age_91_list['pop_75_ub'] = age_91_75['upper'].values

age_91_list['pop_80'] = age_91_80['val'].values
age_91_list['pop_80_lb'] = age_91_80['lower'].values
age_91_list['pop_80_ub'] = age_91_80['upper'].values

age_91_list['pop_25plus'] = age_91_list['pop_25']+age_91_list['pop_30']+age_91_list['pop_35']+age_91_list['pop_40']+age_91_list['pop_45']+age_91_list['pop_50']+age_91_list['pop_55']+age_91_list['pop_60']+age_91_list['pop_65']+age_91_list['pop_70']+age_91_list['pop_75']+age_91_list['pop_80']
age_91_list['pop_25plus_lb'] = age_91_list['pop_25_lb']+age_91_list['pop_30_lb']+age_91_list['pop_35_lb']+age_91_list['pop_40_lb']+age_91_list['pop_45_lb']+age_91_list['pop_50_lb']+age_91_list['pop_55_lb']+age_91_list['pop_60_lb']+age_91_list['pop_65_lb']+age_91_list['pop_70_lb']+age_91_list['pop_75_lb']+age_91_list['pop_80_lb']
age_91_list['pop_25plus_ub'] = age_91_list['pop_25_ub']+age_91_list['pop_30_ub']+age_91_list['pop_35_ub']+age_91_list['pop_40_ub']+age_91_list['pop_45_ub']+age_91_list['pop_50_ub']+age_91_list['pop_55_ub']+age_91_list['pop_60_ub']+age_91_list['pop_65_ub']+age_91_list['pop_70_ub']+age_91_list['pop_75_ub']+age_91_list['pop_80_ub']

age_91_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_91_list.csv', index=False)

# %%
age_92 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1992_Y2020M10D15.CSV')
age_92 = age_92[age_92['sex_id']==3]

age_92_25 = age_92[age_92['age_group_id'] == 10]
age_92_30 = age_92[age_92['age_group_id'] == 11]
age_92_35 = age_92[age_92['age_group_id'] == 12]
age_92_40 = age_92[age_92['age_group_id'] == 13]
age_92_45 = age_92[age_92['age_group_id'] == 14]
age_92_50 = age_92[age_92['age_group_id'] == 15]
age_92_55 = age_92[age_92['age_group_id'] == 16]
age_92_60 = age_92[age_92['age_group_id'] == 17]
age_92_65 = age_92[age_92['age_group_id'] == 18]
age_92_70 = age_92[age_92['age_group_id'] == 19]
age_92_75 = age_92[age_92['age_group_id'] == 20]
age_92_80 = age_92[age_92['age_group_id'] == 21]
age_92_all = age_92[age_92['age_group_id'] == 22]

age_92_list = age_92_all[['location_id','location_name']]
age_92_list['year'] = age_92_all['year_id']
age_92_list['pop_all'] = age_92_all['val']
age_92_list['pop_all_lb'] = age_92_all['lower']
age_92_list['pop_all_ub'] = age_92_all['upper']

age_92_list['pop_25'] = age_92_25['val'].values
age_92_list['pop_25_lb'] = age_92_25['lower'].values
age_92_list['pop_25_ub'] = age_92_25['upper'].values

age_92_list['pop_30'] = age_92_30['val'].values
age_92_list['pop_30_lb'] = age_92_30['lower'].values
age_92_list['pop_30_ub'] = age_92_30['upper'].values

age_92_list['pop_35'] = age_92_35['val'].values
age_92_list['pop_35_lb'] = age_92_35['lower'].values
age_92_list['pop_35_ub'] = age_92_35['upper'].values

age_92_list['pop_40'] = age_92_40['val'].values
age_92_list['pop_40_lb'] = age_92_40['lower'].values
age_92_list['pop_40_ub'] = age_92_40['upper'].values

age_92_list['pop_45'] = age_92_45['val'].values
age_92_list['pop_45_lb'] = age_92_45['lower'].values
age_92_list['pop_45_ub'] = age_92_45['upper'].values

age_92_list['pop_50'] = age_92_50['val'].values
age_92_list['pop_50_lb'] = age_92_50['lower'].values
age_92_list['pop_50_ub'] = age_92_50['upper'].values

age_92_list['pop_55'] = age_92_55['val'].values
age_92_list['pop_55_lb'] = age_92_55['lower'].values
age_92_list['pop_55_ub'] = age_92_55['upper'].values

age_92_list['pop_60'] = age_92_60['val'].values
age_92_list['pop_60_lb'] = age_92_60['lower'].values
age_92_list['pop_60_ub'] = age_92_60['upper'].values

age_92_list['pop_65'] = age_92_65['val'].values
age_92_list['pop_65_lb'] = age_92_65['lower'].values
age_92_list['pop_65_ub'] = age_92_65['upper'].values

age_92_list['pop_70'] = age_92_70['val'].values
age_92_list['pop_70_lb'] = age_92_70['lower'].values
age_92_list['pop_70_ub'] = age_92_70['upper'].values

age_92_list['pop_75'] = age_92_75['val'].values
age_92_list['pop_75_lb'] = age_92_75['lower'].values
age_92_list['pop_75_ub'] = age_92_75['upper'].values

age_92_list['pop_80'] = age_92_80['val'].values
age_92_list['pop_80_lb'] = age_92_80['lower'].values
age_92_list['pop_80_ub'] = age_92_80['upper'].values

age_92_list['pop_25plus'] = age_92_list['pop_25']+age_92_list['pop_30']+age_92_list['pop_35']+age_92_list['pop_40']+age_92_list['pop_45']+age_92_list['pop_50']+age_92_list['pop_55']+age_92_list['pop_60']+age_92_list['pop_65']+age_92_list['pop_70']+age_92_list['pop_75']+age_92_list['pop_80']
age_92_list['pop_25plus_lb'] = age_92_list['pop_25_lb']+age_92_list['pop_30_lb']+age_92_list['pop_35_lb']+age_92_list['pop_40_lb']+age_92_list['pop_45_lb']+age_92_list['pop_50_lb']+age_92_list['pop_55_lb']+age_92_list['pop_60_lb']+age_92_list['pop_65_lb']+age_92_list['pop_70_lb']+age_92_list['pop_75_lb']+age_92_list['pop_80_lb']
age_92_list['pop_25plus_ub'] = age_92_list['pop_25_ub']+age_92_list['pop_30_ub']+age_92_list['pop_35_ub']+age_92_list['pop_40_ub']+age_92_list['pop_45_ub']+age_92_list['pop_50_ub']+age_92_list['pop_55_ub']+age_92_list['pop_60_ub']+age_92_list['pop_65_ub']+age_92_list['pop_70_ub']+age_92_list['pop_75_ub']+age_92_list['pop_80_ub']

age_92_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_92_list.csv', index=False)

# %%
age_93 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1993_Y2020M10D15.CSV')
age_93 = age_93[age_93['sex_id']==3]

age_93_25 = age_93[age_93['age_group_id'] == 10]
age_93_30 = age_93[age_93['age_group_id'] == 11]
age_93_35 = age_93[age_93['age_group_id'] == 12]
age_93_40 = age_93[age_93['age_group_id'] == 13]
age_93_45 = age_93[age_93['age_group_id'] == 14]
age_93_50 = age_93[age_93['age_group_id'] == 15]
age_93_55 = age_93[age_93['age_group_id'] == 16]
age_93_60 = age_93[age_93['age_group_id'] == 17]
age_93_65 = age_93[age_93['age_group_id'] == 18]
age_93_70 = age_93[age_93['age_group_id'] == 19]
age_93_75 = age_93[age_93['age_group_id'] == 20]
age_93_80 = age_93[age_93['age_group_id'] == 21]
age_93_all = age_93[age_93['age_group_id'] == 22]

age_93_list = age_93_all[['location_id','location_name']]
age_93_list['year'] = age_93_all['year_id']
age_93_list['pop_all'] = age_93_all['val']
age_93_list['pop_all_lb'] = age_93_all['lower']
age_93_list['pop_all_ub'] = age_93_all['upper']

age_93_list['pop_25'] = age_93_25['val'].values
age_93_list['pop_25_lb'] = age_93_25['lower'].values
age_93_list['pop_25_ub'] = age_93_25['upper'].values

age_93_list['pop_30'] = age_93_30['val'].values
age_93_list['pop_30_lb'] = age_93_30['lower'].values
age_93_list['pop_30_ub'] = age_93_30['upper'].values

age_93_list['pop_35'] = age_93_35['val'].values
age_93_list['pop_35_lb'] = age_93_35['lower'].values
age_93_list['pop_35_ub'] = age_93_35['upper'].values

age_93_list['pop_40'] = age_93_40['val'].values
age_93_list['pop_40_lb'] = age_93_40['lower'].values
age_93_list['pop_40_ub'] = age_93_40['upper'].values

age_93_list['pop_45'] = age_93_45['val'].values
age_93_list['pop_45_lb'] = age_93_45['lower'].values
age_93_list['pop_45_ub'] = age_93_45['upper'].values

age_93_list['pop_50'] = age_93_50['val'].values
age_93_list['pop_50_lb'] = age_93_50['lower'].values
age_93_list['pop_50_ub'] = age_93_50['upper'].values

age_93_list['pop_55'] = age_93_55['val'].values
age_93_list['pop_55_lb'] = age_93_55['lower'].values
age_93_list['pop_55_ub'] = age_93_55['upper'].values

age_93_list['pop_60'] = age_93_60['val'].values
age_93_list['pop_60_lb'] = age_93_60['lower'].values
age_93_list['pop_60_ub'] = age_93_60['upper'].values

age_93_list['pop_65'] = age_93_65['val'].values
age_93_list['pop_65_lb'] = age_93_65['lower'].values
age_93_list['pop_65_ub'] = age_93_65['upper'].values

age_93_list['pop_70'] = age_93_70['val'].values
age_93_list['pop_70_lb'] = age_93_70['lower'].values
age_93_list['pop_70_ub'] = age_93_70['upper'].values

age_93_list['pop_75'] = age_93_75['val'].values
age_93_list['pop_75_lb'] = age_93_75['lower'].values
age_93_list['pop_75_ub'] = age_93_75['upper'].values

age_93_list['pop_80'] = age_93_80['val'].values
age_93_list['pop_80_lb'] = age_93_80['lower'].values
age_93_list['pop_80_ub'] = age_93_80['upper'].values

age_93_list['pop_25plus'] = age_93_list['pop_25']+age_93_list['pop_30']+age_93_list['pop_35']+age_93_list['pop_40']+age_93_list['pop_45']+age_93_list['pop_50']+age_93_list['pop_55']+age_93_list['pop_60']+age_93_list['pop_65']+age_93_list['pop_70']+age_93_list['pop_75']+age_93_list['pop_80']
age_93_list['pop_25plus_lb'] = age_93_list['pop_25_lb']+age_93_list['pop_30_lb']+age_93_list['pop_35_lb']+age_93_list['pop_40_lb']+age_93_list['pop_45_lb']+age_93_list['pop_50_lb']+age_93_list['pop_55_lb']+age_93_list['pop_60_lb']+age_93_list['pop_65_lb']+age_93_list['pop_70_lb']+age_93_list['pop_75_lb']+age_93_list['pop_80_lb']
age_93_list['pop_25plus_ub'] = age_93_list['pop_25_ub']+age_93_list['pop_30_ub']+age_93_list['pop_35_ub']+age_93_list['pop_40_ub']+age_93_list['pop_45_ub']+age_93_list['pop_50_ub']+age_93_list['pop_55_ub']+age_93_list['pop_60_ub']+age_93_list['pop_65_ub']+age_93_list['pop_70_ub']+age_93_list['pop_75_ub']+age_93_list['pop_80_ub']

age_93_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_93_list.csv', index=False)

# %%
age_94 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1994_Y2020M10D15.CSV')
age_94 = age_94[age_94['sex_id']==3]

age_94_25 = age_94[age_94['age_group_id'] == 10]
age_94_30 = age_94[age_94['age_group_id'] == 11]
age_94_35 = age_94[age_94['age_group_id'] == 12]
age_94_40 = age_94[age_94['age_group_id'] == 13]
age_94_45 = age_94[age_94['age_group_id'] == 14]
age_94_50 = age_94[age_94['age_group_id'] == 15]
age_94_55 = age_94[age_94['age_group_id'] == 16]
age_94_60 = age_94[age_94['age_group_id'] == 17]
age_94_65 = age_94[age_94['age_group_id'] == 18]
age_94_70 = age_94[age_94['age_group_id'] == 19]
age_94_75 = age_94[age_94['age_group_id'] == 20]
age_94_80 = age_94[age_94['age_group_id'] == 21]
age_94_all = age_94[age_94['age_group_id'] == 22]

age_94_list = age_94_all[['location_id','location_name']]
age_94_list['year'] = age_94_all['year_id']
age_94_list['pop_all'] = age_94_all['val']
age_94_list['pop_all_lb'] = age_94_all['lower']
age_94_list['pop_all_ub'] = age_94_all['upper']

age_94_list['pop_25'] = age_94_25['val'].values
age_94_list['pop_25_lb'] = age_94_25['lower'].values
age_94_list['pop_25_ub'] = age_94_25['upper'].values

age_94_list['pop_30'] = age_94_30['val'].values
age_94_list['pop_30_lb'] = age_94_30['lower'].values
age_94_list['pop_30_ub'] = age_94_30['upper'].values

age_94_list['pop_35'] = age_94_35['val'].values
age_94_list['pop_35_lb'] = age_94_35['lower'].values
age_94_list['pop_35_ub'] = age_94_35['upper'].values

age_94_list['pop_40'] = age_94_40['val'].values
age_94_list['pop_40_lb'] = age_94_40['lower'].values
age_94_list['pop_40_ub'] = age_94_40['upper'].values

age_94_list['pop_45'] = age_94_45['val'].values
age_94_list['pop_45_lb'] = age_94_45['lower'].values
age_94_list['pop_45_ub'] = age_94_45['upper'].values

age_94_list['pop_50'] = age_94_50['val'].values
age_94_list['pop_50_lb'] = age_94_50['lower'].values
age_94_list['pop_50_ub'] = age_94_50['upper'].values

age_94_list['pop_55'] = age_94_55['val'].values
age_94_list['pop_55_lb'] = age_94_55['lower'].values
age_94_list['pop_55_ub'] = age_94_55['upper'].values

age_94_list['pop_60'] = age_94_60['val'].values
age_94_list['pop_60_lb'] = age_94_60['lower'].values
age_94_list['pop_60_ub'] = age_94_60['upper'].values

age_94_list['pop_65'] = age_94_65['val'].values
age_94_list['pop_65_lb'] = age_94_65['lower'].values
age_94_list['pop_65_ub'] = age_94_65['upper'].values

age_94_list['pop_70'] = age_94_70['val'].values
age_94_list['pop_70_lb'] = age_94_70['lower'].values
age_94_list['pop_70_ub'] = age_94_70['upper'].values

age_94_list['pop_75'] = age_94_75['val'].values
age_94_list['pop_75_lb'] = age_94_75['lower'].values
age_94_list['pop_75_ub'] = age_94_75['upper'].values

age_94_list['pop_80'] = age_94_80['val'].values
age_94_list['pop_80_lb'] = age_94_80['lower'].values
age_94_list['pop_80_ub'] = age_94_80['upper'].values

age_94_list['pop_25plus'] = age_94_list['pop_25']+age_94_list['pop_30']+age_94_list['pop_35']+age_94_list['pop_40']+age_94_list['pop_45']+age_94_list['pop_50']+age_94_list['pop_55']+age_94_list['pop_60']+age_94_list['pop_65']+age_94_list['pop_70']+age_94_list['pop_75']+age_94_list['pop_80']
age_94_list['pop_25plus_lb'] = age_94_list['pop_25_lb']+age_94_list['pop_30_lb']+age_94_list['pop_35_lb']+age_94_list['pop_40_lb']+age_94_list['pop_45_lb']+age_94_list['pop_50_lb']+age_94_list['pop_55_lb']+age_94_list['pop_60_lb']+age_94_list['pop_65_lb']+age_94_list['pop_70_lb']+age_94_list['pop_75_lb']+age_94_list['pop_80_lb']
age_94_list['pop_25plus_ub'] = age_94_list['pop_25_ub']+age_94_list['pop_30_ub']+age_94_list['pop_35_ub']+age_94_list['pop_40_ub']+age_94_list['pop_45_ub']+age_94_list['pop_50_ub']+age_94_list['pop_55_ub']+age_94_list['pop_60_ub']+age_94_list['pop_65_ub']+age_94_list['pop_70_ub']+age_94_list['pop_75_ub']+age_94_list['pop_80_ub']

age_94_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_94_list.csv', index=False)

# %%
age_95 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1995_Y2020M10D15.CSV')
age_95 = age_95[age_95['sex_id']==3]

age_95_25 = age_95[age_95['age_group_id'] == 10]
age_95_30 = age_95[age_95['age_group_id'] == 11]
age_95_35 = age_95[age_95['age_group_id'] == 12]
age_95_40 = age_95[age_95['age_group_id'] == 13]
age_95_45 = age_95[age_95['age_group_id'] == 14]
age_95_50 = age_95[age_95['age_group_id'] == 15]
age_95_55 = age_95[age_95['age_group_id'] == 16]
age_95_60 = age_95[age_95['age_group_id'] == 17]
age_95_65 = age_95[age_95['age_group_id'] == 18]
age_95_70 = age_95[age_95['age_group_id'] == 19]
age_95_75 = age_95[age_95['age_group_id'] == 20]
age_95_80 = age_95[age_95['age_group_id'] == 21]
age_95_all = age_95[age_95['age_group_id'] == 22]

age_95_list = age_95_all[['location_id','location_name']]
age_95_list['year'] = age_95_all['year_id']
age_95_list['pop_all'] = age_95_all['val']
age_95_list['pop_all_lb'] = age_95_all['lower']
age_95_list['pop_all_ub'] = age_95_all['upper']

age_95_list['pop_25'] = age_95_25['val'].values
age_95_list['pop_25_lb'] = age_95_25['lower'].values
age_95_list['pop_25_ub'] = age_95_25['upper'].values

age_95_list['pop_30'] = age_95_30['val'].values
age_95_list['pop_30_lb'] = age_95_30['lower'].values
age_95_list['pop_30_ub'] = age_95_30['upper'].values

age_95_list['pop_35'] = age_95_35['val'].values
age_95_list['pop_35_lb'] = age_95_35['lower'].values
age_95_list['pop_35_ub'] = age_95_35['upper'].values

age_95_list['pop_40'] = age_95_40['val'].values
age_95_list['pop_40_lb'] = age_95_40['lower'].values
age_95_list['pop_40_ub'] = age_95_40['upper'].values

age_95_list['pop_45'] = age_95_45['val'].values
age_95_list['pop_45_lb'] = age_95_45['lower'].values
age_95_list['pop_45_ub'] = age_95_45['upper'].values

age_95_list['pop_50'] = age_95_50['val'].values
age_95_list['pop_50_lb'] = age_95_50['lower'].values
age_95_list['pop_50_ub'] = age_95_50['upper'].values

age_95_list['pop_55'] = age_95_55['val'].values
age_95_list['pop_55_lb'] = age_95_55['lower'].values
age_95_list['pop_55_ub'] = age_95_55['upper'].values

age_95_list['pop_60'] = age_95_60['val'].values
age_95_list['pop_60_lb'] = age_95_60['lower'].values
age_95_list['pop_60_ub'] = age_95_60['upper'].values

age_95_list['pop_65'] = age_95_65['val'].values
age_95_list['pop_65_lb'] = age_95_65['lower'].values
age_95_list['pop_65_ub'] = age_95_65['upper'].values

age_95_list['pop_70'] = age_95_70['val'].values
age_95_list['pop_70_lb'] = age_95_70['lower'].values
age_95_list['pop_70_ub'] = age_95_70['upper'].values

age_95_list['pop_75'] = age_95_75['val'].values
age_95_list['pop_75_lb'] = age_95_75['lower'].values
age_95_list['pop_75_ub'] = age_95_75['upper'].values

age_95_list['pop_80'] = age_95_80['val'].values
age_95_list['pop_80_lb'] = age_95_80['lower'].values
age_95_list['pop_80_ub'] = age_95_80['upper'].values

age_95_list['pop_25plus'] = age_95_list['pop_25']+age_95_list['pop_30']+age_95_list['pop_35']+age_95_list['pop_40']+age_95_list['pop_45']+age_95_list['pop_50']+age_95_list['pop_55']+age_95_list['pop_60']+age_95_list['pop_65']+age_95_list['pop_70']+age_95_list['pop_75']+age_95_list['pop_80']
age_95_list['pop_25plus_lb'] = age_95_list['pop_25_lb']+age_95_list['pop_30_lb']+age_95_list['pop_35_lb']+age_95_list['pop_40_lb']+age_95_list['pop_45_lb']+age_95_list['pop_50_lb']+age_95_list['pop_55_lb']+age_95_list['pop_60_lb']+age_95_list['pop_65_lb']+age_95_list['pop_70_lb']+age_95_list['pop_75_lb']+age_95_list['pop_80_lb']
age_95_list['pop_25plus_ub'] = age_95_list['pop_25_ub']+age_95_list['pop_30_ub']+age_95_list['pop_35_ub']+age_95_list['pop_40_ub']+age_95_list['pop_45_ub']+age_95_list['pop_50_ub']+age_95_list['pop_55_ub']+age_95_list['pop_60_ub']+age_95_list['pop_65_ub']+age_95_list['pop_70_ub']+age_95_list['pop_75_ub']+age_95_list['pop_80_ub']

age_95_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_95_list.csv', index=False)

# %%
age_96 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1996_Y2020M10D15.CSV')
age_96 = age_96[age_96['sex_id']==3]

age_96_25 = age_96[age_96['age_group_id'] == 10]
age_96_30 = age_96[age_96['age_group_id'] == 11]
age_96_35 = age_96[age_96['age_group_id'] == 12]
age_96_40 = age_96[age_96['age_group_id'] == 13]
age_96_45 = age_96[age_96['age_group_id'] == 14]
age_96_50 = age_96[age_96['age_group_id'] == 15]
age_96_55 = age_96[age_96['age_group_id'] == 16]
age_96_60 = age_96[age_96['age_group_id'] == 17]
age_96_65 = age_96[age_96['age_group_id'] == 18]
age_96_70 = age_96[age_96['age_group_id'] == 19]
age_96_75 = age_96[age_96['age_group_id'] == 20]
age_96_80 = age_96[age_96['age_group_id'] == 21]
age_96_all = age_96[age_96['age_group_id'] == 22]

age_96_list = age_96_all[['location_id','location_name']]
age_96_list['year'] = age_96_all['year_id']
age_96_list['pop_all'] = age_96_all['val']
age_96_list['pop_all_lb'] = age_96_all['lower']
age_96_list['pop_all_ub'] = age_96_all['upper']

age_96_list['pop_25'] = age_96_25['val'].values
age_96_list['pop_25_lb'] = age_96_25['lower'].values
age_96_list['pop_25_ub'] = age_96_25['upper'].values

age_96_list['pop_30'] = age_96_30['val'].values
age_96_list['pop_30_lb'] = age_96_30['lower'].values
age_96_list['pop_30_ub'] = age_96_30['upper'].values

age_96_list['pop_35'] = age_96_35['val'].values
age_96_list['pop_35_lb'] = age_96_35['lower'].values
age_96_list['pop_35_ub'] = age_96_35['upper'].values

age_96_list['pop_40'] = age_96_40['val'].values
age_96_list['pop_40_lb'] = age_96_40['lower'].values
age_96_list['pop_40_ub'] = age_96_40['upper'].values

age_96_list['pop_45'] = age_96_45['val'].values
age_96_list['pop_45_lb'] = age_96_45['lower'].values
age_96_list['pop_45_ub'] = age_96_45['upper'].values

age_96_list['pop_50'] = age_96_50['val'].values
age_96_list['pop_50_lb'] = age_96_50['lower'].values
age_96_list['pop_50_ub'] = age_96_50['upper'].values

age_96_list['pop_55'] = age_96_55['val'].values
age_96_list['pop_55_lb'] = age_96_55['lower'].values
age_96_list['pop_55_ub'] = age_96_55['upper'].values

age_96_list['pop_60'] = age_96_60['val'].values
age_96_list['pop_60_lb'] = age_96_60['lower'].values
age_96_list['pop_60_ub'] = age_96_60['upper'].values

age_96_list['pop_65'] = age_96_65['val'].values
age_96_list['pop_65_lb'] = age_96_65['lower'].values
age_96_list['pop_65_ub'] = age_96_65['upper'].values

age_96_list['pop_70'] = age_96_70['val'].values
age_96_list['pop_70_lb'] = age_96_70['lower'].values
age_96_list['pop_70_ub'] = age_96_70['upper'].values

age_96_list['pop_75'] = age_96_75['val'].values
age_96_list['pop_75_lb'] = age_96_75['lower'].values
age_96_list['pop_75_ub'] = age_96_75['upper'].values

age_96_list['pop_80'] = age_96_80['val'].values
age_96_list['pop_80_lb'] = age_96_80['lower'].values
age_96_list['pop_80_ub'] = age_96_80['upper'].values

age_96_list['pop_25plus'] = age_96_list['pop_25']+age_96_list['pop_30']+age_96_list['pop_35']+age_96_list['pop_40']+age_96_list['pop_45']+age_96_list['pop_50']+age_96_list['pop_55']+age_96_list['pop_60']+age_96_list['pop_65']+age_96_list['pop_70']+age_96_list['pop_75']+age_96_list['pop_80']
age_96_list['pop_25plus_lb'] = age_96_list['pop_25_lb']+age_96_list['pop_30_lb']+age_96_list['pop_35_lb']+age_96_list['pop_40_lb']+age_96_list['pop_45_lb']+age_96_list['pop_50_lb']+age_96_list['pop_55_lb']+age_96_list['pop_60_lb']+age_96_list['pop_65_lb']+age_96_list['pop_70_lb']+age_96_list['pop_75_lb']+age_96_list['pop_80_lb']
age_96_list['pop_25plus_ub'] = age_96_list['pop_25_ub']+age_96_list['pop_30_ub']+age_96_list['pop_35_ub']+age_96_list['pop_40_ub']+age_96_list['pop_45_ub']+age_96_list['pop_50_ub']+age_96_list['pop_55_ub']+age_96_list['pop_60_ub']+age_96_list['pop_65_ub']+age_96_list['pop_70_ub']+age_96_list['pop_75_ub']+age_96_list['pop_80_ub']

age_96_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_96_list.csv', index=False)

# %%
age_97 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1997_Y2020M10D15.CSV')
age_97 = age_97[age_97['sex_id']==3]

age_97_25 = age_97[age_97['age_group_id'] == 10]
age_97_30 = age_97[age_97['age_group_id'] == 11]
age_97_35 = age_97[age_97['age_group_id'] == 12]
age_97_40 = age_97[age_97['age_group_id'] == 13]
age_97_45 = age_97[age_97['age_group_id'] == 14]
age_97_50 = age_97[age_97['age_group_id'] == 15]
age_97_55 = age_97[age_97['age_group_id'] == 16]
age_97_60 = age_97[age_97['age_group_id'] == 17]
age_97_65 = age_97[age_97['age_group_id'] == 18]
age_97_70 = age_97[age_97['age_group_id'] == 19]
age_97_75 = age_97[age_97['age_group_id'] == 20]
age_97_80 = age_97[age_97['age_group_id'] == 21]
age_97_all = age_97[age_97['age_group_id'] == 22]

age_97_list = age_97_all[['location_id','location_name']]
age_97_list['year'] = age_97_all['year_id']
age_97_list['pop_all'] = age_97_all['val']
age_97_list['pop_all_lb'] = age_97_all['lower']
age_97_list['pop_all_ub'] = age_97_all['upper']

age_97_list['pop_25'] = age_97_25['val'].values
age_97_list['pop_25_lb'] = age_97_25['lower'].values
age_97_list['pop_25_ub'] = age_97_25['upper'].values

age_97_list['pop_30'] = age_97_30['val'].values
age_97_list['pop_30_lb'] = age_97_30['lower'].values
age_97_list['pop_30_ub'] = age_97_30['upper'].values

age_97_list['pop_35'] = age_97_35['val'].values
age_97_list['pop_35_lb'] = age_97_35['lower'].values
age_97_list['pop_35_ub'] = age_97_35['upper'].values

age_97_list['pop_40'] = age_97_40['val'].values
age_97_list['pop_40_lb'] = age_97_40['lower'].values
age_97_list['pop_40_ub'] = age_97_40['upper'].values

age_97_list['pop_45'] = age_97_45['val'].values
age_97_list['pop_45_lb'] = age_97_45['lower'].values
age_97_list['pop_45_ub'] = age_97_45['upper'].values

age_97_list['pop_50'] = age_97_50['val'].values
age_97_list['pop_50_lb'] = age_97_50['lower'].values
age_97_list['pop_50_ub'] = age_97_50['upper'].values

age_97_list['pop_55'] = age_97_55['val'].values
age_97_list['pop_55_lb'] = age_97_55['lower'].values
age_97_list['pop_55_ub'] = age_97_55['upper'].values

age_97_list['pop_60'] = age_97_60['val'].values
age_97_list['pop_60_lb'] = age_97_60['lower'].values
age_97_list['pop_60_ub'] = age_97_60['upper'].values

age_97_list['pop_65'] = age_97_65['val'].values
age_97_list['pop_65_lb'] = age_97_65['lower'].values
age_97_list['pop_65_ub'] = age_97_65['upper'].values

age_97_list['pop_70'] = age_97_70['val'].values
age_97_list['pop_70_lb'] = age_97_70['lower'].values
age_97_list['pop_70_ub'] = age_97_70['upper'].values

age_97_list['pop_75'] = age_97_75['val'].values
age_97_list['pop_75_lb'] = age_97_75['lower'].values
age_97_list['pop_75_ub'] = age_97_75['upper'].values

age_97_list['pop_80'] = age_97_80['val'].values
age_97_list['pop_80_lb'] = age_97_80['lower'].values
age_97_list['pop_80_ub'] = age_97_80['upper'].values

age_97_list['pop_25plus'] = age_97_list['pop_25']+age_97_list['pop_30']+age_97_list['pop_35']+age_97_list['pop_40']+age_97_list['pop_45']+age_97_list['pop_50']+age_97_list['pop_55']+age_97_list['pop_60']+age_97_list['pop_65']+age_97_list['pop_70']+age_97_list['pop_75']+age_97_list['pop_80']
age_97_list['pop_25plus_lb'] = age_97_list['pop_25_lb']+age_97_list['pop_30_lb']+age_97_list['pop_35_lb']+age_97_list['pop_40_lb']+age_97_list['pop_45_lb']+age_97_list['pop_50_lb']+age_97_list['pop_55_lb']+age_97_list['pop_60_lb']+age_97_list['pop_65_lb']+age_97_list['pop_70_lb']+age_97_list['pop_75_lb']+age_97_list['pop_80_lb']
age_97_list['pop_25plus_ub'] = age_97_list['pop_25_ub']+age_97_list['pop_30_ub']+age_97_list['pop_35_ub']+age_97_list['pop_40_ub']+age_97_list['pop_45_ub']+age_97_list['pop_50_ub']+age_97_list['pop_55_ub']+age_97_list['pop_60_ub']+age_97_list['pop_65_ub']+age_97_list['pop_70_ub']+age_97_list['pop_75_ub']+age_97_list['pop_80_ub']

age_97_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_97_list.csv', index=False)

# %%
age_98 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1998_Y2020M10D15.CSV')
age_98 = age_98[age_98['sex_id']==3]

age_98_25 = age_98[age_98['age_group_id'] == 10]
age_98_30 = age_98[age_98['age_group_id'] == 11]
age_98_35 = age_98[age_98['age_group_id'] == 12]
age_98_40 = age_98[age_98['age_group_id'] == 13]
age_98_45 = age_98[age_98['age_group_id'] == 14]
age_98_50 = age_98[age_98['age_group_id'] == 15]
age_98_55 = age_98[age_98['age_group_id'] == 16]
age_98_60 = age_98[age_98['age_group_id'] == 17]
age_98_65 = age_98[age_98['age_group_id'] == 18]
age_98_70 = age_98[age_98['age_group_id'] == 19]
age_98_75 = age_98[age_98['age_group_id'] == 20]
age_98_80 = age_98[age_98['age_group_id'] == 21]
age_98_all = age_98[age_98['age_group_id'] == 22]

age_98_list = age_98_all[['location_id','location_name']]
age_98_list['year'] = age_98_all['year_id']
age_98_list['pop_all'] = age_98_all['val']
age_98_list['pop_all_lb'] = age_98_all['lower']
age_98_list['pop_all_ub'] = age_98_all['upper']

age_98_list['pop_25'] = age_98_25['val'].values
age_98_list['pop_25_lb'] = age_98_25['lower'].values
age_98_list['pop_25_ub'] = age_98_25['upper'].values

age_98_list['pop_30'] = age_98_30['val'].values
age_98_list['pop_30_lb'] = age_98_30['lower'].values
age_98_list['pop_30_ub'] = age_98_30['upper'].values

age_98_list['pop_35'] = age_98_35['val'].values
age_98_list['pop_35_lb'] = age_98_35['lower'].values
age_98_list['pop_35_ub'] = age_98_35['upper'].values

age_98_list['pop_40'] = age_98_40['val'].values
age_98_list['pop_40_lb'] = age_98_40['lower'].values
age_98_list['pop_40_ub'] = age_98_40['upper'].values

age_98_list['pop_45'] = age_98_45['val'].values
age_98_list['pop_45_lb'] = age_98_45['lower'].values
age_98_list['pop_45_ub'] = age_98_45['upper'].values

age_98_list['pop_50'] = age_98_50['val'].values
age_98_list['pop_50_lb'] = age_98_50['lower'].values
age_98_list['pop_50_ub'] = age_98_50['upper'].values

age_98_list['pop_55'] = age_98_55['val'].values
age_98_list['pop_55_lb'] = age_98_55['lower'].values
age_98_list['pop_55_ub'] = age_98_55['upper'].values

age_98_list['pop_60'] = age_98_60['val'].values
age_98_list['pop_60_lb'] = age_98_60['lower'].values
age_98_list['pop_60_ub'] = age_98_60['upper'].values

age_98_list['pop_65'] = age_98_65['val'].values
age_98_list['pop_65_lb'] = age_98_65['lower'].values
age_98_list['pop_65_ub'] = age_98_65['upper'].values

age_98_list['pop_70'] = age_98_70['val'].values
age_98_list['pop_70_lb'] = age_98_70['lower'].values
age_98_list['pop_70_ub'] = age_98_70['upper'].values

age_98_list['pop_75'] = age_98_75['val'].values
age_98_list['pop_75_lb'] = age_98_75['lower'].values
age_98_list['pop_75_ub'] = age_98_75['upper'].values

age_98_list['pop_80'] = age_98_80['val'].values
age_98_list['pop_80_lb'] = age_98_80['lower'].values
age_98_list['pop_80_ub'] = age_98_80['upper'].values

age_98_list['pop_25plus'] = age_98_list['pop_25']+age_98_list['pop_30']+age_98_list['pop_35']+age_98_list['pop_40']+age_98_list['pop_45']+age_98_list['pop_50']+age_98_list['pop_55']+age_98_list['pop_60']+age_98_list['pop_65']+age_98_list['pop_70']+age_98_list['pop_75']+age_98_list['pop_80']
age_98_list['pop_25plus_lb'] = age_98_list['pop_25_lb']+age_98_list['pop_30_lb']+age_98_list['pop_35_lb']+age_98_list['pop_40_lb']+age_98_list['pop_45_lb']+age_98_list['pop_50_lb']+age_98_list['pop_55_lb']+age_98_list['pop_60_lb']+age_98_list['pop_65_lb']+age_98_list['pop_70_lb']+age_98_list['pop_75_lb']+age_98_list['pop_80_lb']
age_98_list['pop_25plus_ub'] = age_98_list['pop_25_ub']+age_98_list['pop_30_ub']+age_98_list['pop_35_ub']+age_98_list['pop_40_ub']+age_98_list['pop_45_ub']+age_98_list['pop_50_ub']+age_98_list['pop_55_ub']+age_98_list['pop_60_ub']+age_98_list['pop_65_ub']+age_98_list['pop_70_ub']+age_98_list['pop_75_ub']+age_98_list['pop_80_ub']

age_98_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_98_list.csv', index=False)

# %%
age_99 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_1990_1999_0/IHME_GBD_2019_POP_1999_Y2020M10D15.CSV')
age_99 = age_99[age_99['sex_id']==3]

age_99_25 = age_99[age_99['age_group_id'] == 10]
age_99_30 = age_99[age_99['age_group_id'] == 11]
age_99_35 = age_99[age_99['age_group_id'] == 12]
age_99_40 = age_99[age_99['age_group_id'] == 13]
age_99_45 = age_99[age_99['age_group_id'] == 14]
age_99_50 = age_99[age_99['age_group_id'] == 15]
age_99_55 = age_99[age_99['age_group_id'] == 16]
age_99_60 = age_99[age_99['age_group_id'] == 17]
age_99_65 = age_99[age_99['age_group_id'] == 18]
age_99_70 = age_99[age_99['age_group_id'] == 19]
age_99_75 = age_99[age_99['age_group_id'] == 20]
age_99_80 = age_99[age_99['age_group_id'] == 21]
age_99_all = age_99[age_99['age_group_id'] == 22]

age_99_list = age_99_all[['location_id','location_name']]
age_99_list['year'] = age_99_all['year_id']
age_99_list['pop_all'] = age_99_all['val']
age_99_list['pop_all_lb'] = age_99_all['lower']
age_99_list['pop_all_ub'] = age_99_all['upper']

age_99_list['pop_25'] = age_99_25['val'].values
age_99_list['pop_25_lb'] = age_99_25['lower'].values
age_99_list['pop_25_ub'] = age_99_25['upper'].values

age_99_list['pop_30'] = age_99_30['val'].values
age_99_list['pop_30_lb'] = age_99_30['lower'].values
age_99_list['pop_30_ub'] = age_99_30['upper'].values

age_99_list['pop_35'] = age_99_35['val'].values
age_99_list['pop_35_lb'] = age_99_35['lower'].values
age_99_list['pop_35_ub'] = age_99_35['upper'].values

age_99_list['pop_40'] = age_99_40['val'].values
age_99_list['pop_40_lb'] = age_99_40['lower'].values
age_99_list['pop_40_ub'] = age_99_40['upper'].values

age_99_list['pop_45'] = age_99_45['val'].values
age_99_list['pop_45_lb'] = age_99_45['lower'].values
age_99_list['pop_45_ub'] = age_99_45['upper'].values

age_99_list['pop_50'] = age_99_50['val'].values
age_99_list['pop_50_lb'] = age_99_50['lower'].values
age_99_list['pop_50_ub'] = age_99_50['upper'].values

age_99_list['pop_55'] = age_99_55['val'].values
age_99_list['pop_55_lb'] = age_99_55['lower'].values
age_99_list['pop_55_ub'] = age_99_55['upper'].values

age_99_list['pop_60'] = age_99_60['val'].values
age_99_list['pop_60_lb'] = age_99_60['lower'].values
age_99_list['pop_60_ub'] = age_99_60['upper'].values

age_99_list['pop_65'] = age_99_65['val'].values
age_99_list['pop_65_lb'] = age_99_65['lower'].values
age_99_list['pop_65_ub'] = age_99_65['upper'].values

age_99_list['pop_70'] = age_99_70['val'].values
age_99_list['pop_70_lb'] = age_99_70['lower'].values
age_99_list['pop_70_ub'] = age_99_70['upper'].values

age_99_list['pop_75'] = age_99_75['val'].values
age_99_list['pop_75_lb'] = age_99_75['lower'].values
age_99_list['pop_75_ub'] = age_99_75['upper'].values

age_99_list['pop_80'] = age_99_80['val'].values
age_99_list['pop_80_lb'] = age_99_80['lower'].values
age_99_list['pop_80_ub'] = age_99_80['upper'].values

age_99_list['pop_25plus'] = age_99_list['pop_25']+age_99_list['pop_30']+age_99_list['pop_35']+age_99_list['pop_40']+age_99_list['pop_45']+age_99_list['pop_50']+age_99_list['pop_55']+age_99_list['pop_60']+age_99_list['pop_65']+age_99_list['pop_70']+age_99_list['pop_75']+age_99_list['pop_80']
age_99_list['pop_25plus_lb'] = age_99_list['pop_25_lb']+age_99_list['pop_30_lb']+age_99_list['pop_35_lb']+age_99_list['pop_40_lb']+age_99_list['pop_45_lb']+age_99_list['pop_50_lb']+age_99_list['pop_55_lb']+age_99_list['pop_60_lb']+age_99_list['pop_65_lb']+age_99_list['pop_70_lb']+age_99_list['pop_75_lb']+age_99_list['pop_80_lb']
age_99_list['pop_25plus_ub'] = age_99_list['pop_25_ub']+age_99_list['pop_30_ub']+age_99_list['pop_35_ub']+age_99_list['pop_40_ub']+age_99_list['pop_45_ub']+age_99_list['pop_50_ub']+age_99_list['pop_55_ub']+age_99_list['pop_60_ub']+age_99_list['pop_65_ub']+age_99_list['pop_70_ub']+age_99_list['pop_75_ub']+age_99_list['pop_80_ub']

age_99_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_99_list.csv', index=False)

# %%
age_00 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2000_Y2020M10D15.CSV')
age_00 = age_00[age_00['sex_id']==3]

age_00_25 = age_00[age_00['age_group_id'] == 10]
age_00_30 = age_00[age_00['age_group_id'] == 11]
age_00_35 = age_00[age_00['age_group_id'] == 12]
age_00_40 = age_00[age_00['age_group_id'] == 13]
age_00_45 = age_00[age_00['age_group_id'] == 14]
age_00_50 = age_00[age_00['age_group_id'] == 15]
age_00_55 = age_00[age_00['age_group_id'] == 16]
age_00_60 = age_00[age_00['age_group_id'] == 17]
age_00_65 = age_00[age_00['age_group_id'] == 18]
age_00_70 = age_00[age_00['age_group_id'] == 19]
age_00_75 = age_00[age_00['age_group_id'] == 20]
age_00_80 = age_00[age_00['age_group_id'] == 21]
age_00_all = age_00[age_00['age_group_id'] == 22]

age_00_list = age_00_all[['location_id','location_name']]
age_00_list['year'] = age_00_all['year_id']
age_00_list['pop_all'] = age_00_all['val']
age_00_list['pop_all_lb'] = age_00_all['lower']
age_00_list['pop_all_ub'] = age_00_all['upper']

age_00_list['pop_25'] = age_00_25['val'].values
age_00_list['pop_25_lb'] = age_00_25['lower'].values
age_00_list['pop_25_ub'] = age_00_25['upper'].values

age_00_list['pop_30'] = age_00_30['val'].values
age_00_list['pop_30_lb'] = age_00_30['lower'].values
age_00_list['pop_30_ub'] = age_00_30['upper'].values

age_00_list['pop_35'] = age_00_35['val'].values
age_00_list['pop_35_lb'] = age_00_35['lower'].values
age_00_list['pop_35_ub'] = age_00_35['upper'].values

age_00_list['pop_40'] = age_00_40['val'].values
age_00_list['pop_40_lb'] = age_00_40['lower'].values
age_00_list['pop_40_ub'] = age_00_40['upper'].values

age_00_list['pop_45'] = age_00_45['val'].values
age_00_list['pop_45_lb'] = age_00_45['lower'].values
age_00_list['pop_45_ub'] = age_00_45['upper'].values

age_00_list['pop_50'] = age_00_50['val'].values
age_00_list['pop_50_lb'] = age_00_50['lower'].values
age_00_list['pop_50_ub'] = age_00_50['upper'].values

age_00_list['pop_55'] = age_00_55['val'].values
age_00_list['pop_55_lb'] = age_00_55['lower'].values
age_00_list['pop_55_ub'] = age_00_55['upper'].values

age_00_list['pop_60'] = age_00_60['val'].values
age_00_list['pop_60_lb'] = age_00_60['lower'].values
age_00_list['pop_60_ub'] = age_00_60['upper'].values

age_00_list['pop_65'] = age_00_65['val'].values
age_00_list['pop_65_lb'] = age_00_65['lower'].values
age_00_list['pop_65_ub'] = age_00_65['upper'].values

age_00_list['pop_70'] = age_00_70['val'].values
age_00_list['pop_70_lb'] = age_00_70['lower'].values
age_00_list['pop_70_ub'] = age_00_70['upper'].values

age_00_list['pop_75'] = age_00_75['val'].values
age_00_list['pop_75_lb'] = age_00_75['lower'].values
age_00_list['pop_75_ub'] = age_00_75['upper'].values

age_00_list['pop_80'] = age_00_80['val'].values
age_00_list['pop_80_lb'] = age_00_80['lower'].values
age_00_list['pop_80_ub'] = age_00_80['upper'].values

age_00_list['pop_25plus'] = age_00_list['pop_25']+age_00_list['pop_30']+age_00_list['pop_35']+age_00_list['pop_40']+age_00_list['pop_45']+age_00_list['pop_50']+age_00_list['pop_55']+age_00_list['pop_60']+age_00_list['pop_65']+age_00_list['pop_70']+age_00_list['pop_75']+age_00_list['pop_80']
age_00_list['pop_25plus_lb'] = age_00_list['pop_25_lb']+age_00_list['pop_30_lb']+age_00_list['pop_35_lb']+age_00_list['pop_40_lb']+age_00_list['pop_45_lb']+age_00_list['pop_50_lb']+age_00_list['pop_55_lb']+age_00_list['pop_60_lb']+age_00_list['pop_65_lb']+age_00_list['pop_70_lb']+age_00_list['pop_75_lb']+age_00_list['pop_80_lb']
age_00_list['pop_25plus_ub'] = age_00_list['pop_25_ub']+age_00_list['pop_30_ub']+age_00_list['pop_35_ub']+age_00_list['pop_40_ub']+age_00_list['pop_45_ub']+age_00_list['pop_50_ub']+age_00_list['pop_55_ub']+age_00_list['pop_60_ub']+age_00_list['pop_65_ub']+age_00_list['pop_70_ub']+age_00_list['pop_75_ub']+age_00_list['pop_80_ub']

age_00_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_00_list.csv', index=False)

# %%
age_01 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2001_Y2020M10D15.CSV')
age_01 = age_01[age_01['sex_id']==3]

age_01_25 = age_01[age_01['age_group_id'] == 10]
age_01_30 = age_01[age_01['age_group_id'] == 11]
age_01_35 = age_01[age_01['age_group_id'] == 12]
age_01_40 = age_01[age_01['age_group_id'] == 13]
age_01_45 = age_01[age_01['age_group_id'] == 14]
age_01_50 = age_01[age_01['age_group_id'] == 15]
age_01_55 = age_01[age_01['age_group_id'] == 16]
age_01_60 = age_01[age_01['age_group_id'] == 17]
age_01_65 = age_01[age_01['age_group_id'] == 18]
age_01_70 = age_01[age_01['age_group_id'] == 19]
age_01_75 = age_01[age_01['age_group_id'] == 20]
age_01_80 = age_01[age_01['age_group_id'] == 21]
age_01_all = age_01[age_01['age_group_id'] == 22]

age_01_list = age_01_all[['location_id','location_name']]
age_01_list['year'] = age_01_all['year_id']
age_01_list['pop_all'] = age_01_all['val']
age_01_list['pop_all_lb'] = age_01_all['lower']
age_01_list['pop_all_ub'] = age_01_all['upper']

age_01_list['pop_25'] = age_01_25['val'].values
age_01_list['pop_25_lb'] = age_01_25['lower'].values
age_01_list['pop_25_ub'] = age_01_25['upper'].values

age_01_list['pop_30'] = age_01_30['val'].values
age_01_list['pop_30_lb'] = age_01_30['lower'].values
age_01_list['pop_30_ub'] = age_01_30['upper'].values

age_01_list['pop_35'] = age_01_35['val'].values
age_01_list['pop_35_lb'] = age_01_35['lower'].values
age_01_list['pop_35_ub'] = age_01_35['upper'].values

age_01_list['pop_40'] = age_01_40['val'].values
age_01_list['pop_40_lb'] = age_01_40['lower'].values
age_01_list['pop_40_ub'] = age_01_40['upper'].values

age_01_list['pop_45'] = age_01_45['val'].values
age_01_list['pop_45_lb'] = age_01_45['lower'].values
age_01_list['pop_45_ub'] = age_01_45['upper'].values

age_01_list['pop_50'] = age_01_50['val'].values
age_01_list['pop_50_lb'] = age_01_50['lower'].values
age_01_list['pop_50_ub'] = age_01_50['upper'].values

age_01_list['pop_55'] = age_01_55['val'].values
age_01_list['pop_55_lb'] = age_01_55['lower'].values
age_01_list['pop_55_ub'] = age_01_55['upper'].values

age_01_list['pop_60'] = age_01_60['val'].values
age_01_list['pop_60_lb'] = age_01_60['lower'].values
age_01_list['pop_60_ub'] = age_01_60['upper'].values

age_01_list['pop_65'] = age_01_65['val'].values
age_01_list['pop_65_lb'] = age_01_65['lower'].values
age_01_list['pop_65_ub'] = age_01_65['upper'].values

age_01_list['pop_70'] = age_01_70['val'].values
age_01_list['pop_70_lb'] = age_01_70['lower'].values
age_01_list['pop_70_ub'] = age_01_70['upper'].values

age_01_list['pop_75'] = age_01_75['val'].values
age_01_list['pop_75_lb'] = age_01_75['lower'].values
age_01_list['pop_75_ub'] = age_01_75['upper'].values

age_01_list['pop_80'] = age_01_80['val'].values
age_01_list['pop_80_lb'] = age_01_80['lower'].values
age_01_list['pop_80_ub'] = age_01_80['upper'].values

age_01_list['pop_25plus'] = age_01_list['pop_25']+age_01_list['pop_30']+age_01_list['pop_35']+age_01_list['pop_40']+age_01_list['pop_45']+age_01_list['pop_50']+age_01_list['pop_55']+age_01_list['pop_60']+age_01_list['pop_65']+age_01_list['pop_70']+age_01_list['pop_75']+age_01_list['pop_80']
age_01_list['pop_25plus_lb'] = age_01_list['pop_25_lb']+age_01_list['pop_30_lb']+age_01_list['pop_35_lb']+age_01_list['pop_40_lb']+age_01_list['pop_45_lb']+age_01_list['pop_50_lb']+age_01_list['pop_55_lb']+age_01_list['pop_60_lb']+age_01_list['pop_65_lb']+age_01_list['pop_70_lb']+age_01_list['pop_75_lb']+age_01_list['pop_80_lb']
age_01_list['pop_25plus_ub'] = age_01_list['pop_25_ub']+age_01_list['pop_30_ub']+age_01_list['pop_35_ub']+age_01_list['pop_40_ub']+age_01_list['pop_45_ub']+age_01_list['pop_50_ub']+age_01_list['pop_55_ub']+age_01_list['pop_60_ub']+age_01_list['pop_65_ub']+age_01_list['pop_70_ub']+age_01_list['pop_75_ub']+age_01_list['pop_80_ub']

age_01_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_01_list.csv', index=False)

# %%
age_02 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2002_Y2020M10D15.CSV')
age_02 = age_02[age_02['sex_id']==3]

age_02_25 = age_02[age_02['age_group_id'] == 10]
age_02_30 = age_02[age_02['age_group_id'] == 11]
age_02_35 = age_02[age_02['age_group_id'] == 12]
age_02_40 = age_02[age_02['age_group_id'] == 13]
age_02_45 = age_02[age_02['age_group_id'] == 14]
age_02_50 = age_02[age_02['age_group_id'] == 15]
age_02_55 = age_02[age_02['age_group_id'] == 16]
age_02_60 = age_02[age_02['age_group_id'] == 17]
age_02_65 = age_02[age_02['age_group_id'] == 18]
age_02_70 = age_02[age_02['age_group_id'] == 19]
age_02_75 = age_02[age_02['age_group_id'] == 20]
age_02_80 = age_02[age_02['age_group_id'] == 21]
age_02_all = age_02[age_02['age_group_id'] == 22]

age_02_list = age_02_all[['location_id','location_name']]
age_02_list['year'] = age_02_all['year_id']
age_02_list['pop_all'] = age_02_all['val']
age_02_list['pop_all_lb'] = age_02_all['lower']
age_02_list['pop_all_ub'] = age_02_all['upper']

age_02_list['pop_25'] = age_02_25['val'].values
age_02_list['pop_25_lb'] = age_02_25['lower'].values
age_02_list['pop_25_ub'] = age_02_25['upper'].values

age_02_list['pop_30'] = age_02_30['val'].values
age_02_list['pop_30_lb'] = age_02_30['lower'].values
age_02_list['pop_30_ub'] = age_02_30['upper'].values

age_02_list['pop_35'] = age_02_35['val'].values
age_02_list['pop_35_lb'] = age_02_35['lower'].values
age_02_list['pop_35_ub'] = age_02_35['upper'].values

age_02_list['pop_40'] = age_02_40['val'].values
age_02_list['pop_40_lb'] = age_02_40['lower'].values
age_02_list['pop_40_ub'] = age_02_40['upper'].values

age_02_list['pop_45'] = age_02_45['val'].values
age_02_list['pop_45_lb'] = age_02_45['lower'].values
age_02_list['pop_45_ub'] = age_02_45['upper'].values

age_02_list['pop_50'] = age_02_50['val'].values
age_02_list['pop_50_lb'] = age_02_50['lower'].values
age_02_list['pop_50_ub'] = age_02_50['upper'].values

age_02_list['pop_55'] = age_02_55['val'].values
age_02_list['pop_55_lb'] = age_02_55['lower'].values
age_02_list['pop_55_ub'] = age_02_55['upper'].values

age_02_list['pop_60'] = age_02_60['val'].values
age_02_list['pop_60_lb'] = age_02_60['lower'].values
age_02_list['pop_60_ub'] = age_02_60['upper'].values

age_02_list['pop_65'] = age_02_65['val'].values
age_02_list['pop_65_lb'] = age_02_65['lower'].values
age_02_list['pop_65_ub'] = age_02_65['upper'].values

age_02_list['pop_70'] = age_02_70['val'].values
age_02_list['pop_70_lb'] = age_02_70['lower'].values
age_02_list['pop_70_ub'] = age_02_70['upper'].values

age_02_list['pop_75'] = age_02_75['val'].values
age_02_list['pop_75_lb'] = age_02_75['lower'].values
age_02_list['pop_75_ub'] = age_02_75['upper'].values

age_02_list['pop_80'] = age_02_80['val'].values
age_02_list['pop_80_lb'] = age_02_80['lower'].values
age_02_list['pop_80_ub'] = age_02_80['upper'].values

age_02_list['pop_25plus'] = age_02_list['pop_25']+age_02_list['pop_30']+age_02_list['pop_35']+age_02_list['pop_40']+age_02_list['pop_45']+age_02_list['pop_50']+age_02_list['pop_55']+age_02_list['pop_60']+age_02_list['pop_65']+age_02_list['pop_70']+age_02_list['pop_75']+age_02_list['pop_80']
age_02_list['pop_25plus_lb'] = age_02_list['pop_25_lb']+age_02_list['pop_30_lb']+age_02_list['pop_35_lb']+age_02_list['pop_40_lb']+age_02_list['pop_45_lb']+age_02_list['pop_50_lb']+age_02_list['pop_55_lb']+age_02_list['pop_60_lb']+age_02_list['pop_65_lb']+age_02_list['pop_70_lb']+age_02_list['pop_75_lb']+age_02_list['pop_80_lb']
age_02_list['pop_25plus_ub'] = age_02_list['pop_25_ub']+age_02_list['pop_30_ub']+age_02_list['pop_35_ub']+age_02_list['pop_40_ub']+age_02_list['pop_45_ub']+age_02_list['pop_50_ub']+age_02_list['pop_55_ub']+age_02_list['pop_60_ub']+age_02_list['pop_65_ub']+age_02_list['pop_70_ub']+age_02_list['pop_75_ub']+age_02_list['pop_80_ub']

age_02_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_02_list.csv', index=False)

# %%
age_03 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2003_Y2020M10D15.CSV')
age_03 = age_03[age_03['sex_id']==3]

age_03_25 = age_03[age_03['age_group_id'] == 10]
age_03_30 = age_03[age_03['age_group_id'] == 11]
age_03_35 = age_03[age_03['age_group_id'] == 12]
age_03_40 = age_03[age_03['age_group_id'] == 13]
age_03_45 = age_03[age_03['age_group_id'] == 14]
age_03_50 = age_03[age_03['age_group_id'] == 15]
age_03_55 = age_03[age_03['age_group_id'] == 16]
age_03_60 = age_03[age_03['age_group_id'] == 17]
age_03_65 = age_03[age_03['age_group_id'] == 18]
age_03_70 = age_03[age_03['age_group_id'] == 19]
age_03_75 = age_03[age_03['age_group_id'] == 20]
age_03_80 = age_03[age_03['age_group_id'] == 21]
age_03_all = age_03[age_03['age_group_id'] == 22]

age_03_list = age_03_all[['location_id','location_name']]
age_03_list['year'] = age_03_all['year_id']
age_03_list['pop_all'] = age_03_all['val']
age_03_list['pop_all_lb'] = age_03_all['lower']
age_03_list['pop_all_ub'] = age_03_all['upper']

age_03_list['pop_25'] = age_03_25['val'].values
age_03_list['pop_25_lb'] = age_03_25['lower'].values
age_03_list['pop_25_ub'] = age_03_25['upper'].values

age_03_list['pop_30'] = age_03_30['val'].values
age_03_list['pop_30_lb'] = age_03_30['lower'].values
age_03_list['pop_30_ub'] = age_03_30['upper'].values

age_03_list['pop_35'] = age_03_35['val'].values
age_03_list['pop_35_lb'] = age_03_35['lower'].values
age_03_list['pop_35_ub'] = age_03_35['upper'].values

age_03_list['pop_40'] = age_03_40['val'].values
age_03_list['pop_40_lb'] = age_03_40['lower'].values
age_03_list['pop_40_ub'] = age_03_40['upper'].values

age_03_list['pop_45'] = age_03_45['val'].values
age_03_list['pop_45_lb'] = age_03_45['lower'].values
age_03_list['pop_45_ub'] = age_03_45['upper'].values

age_03_list['pop_50'] = age_03_50['val'].values
age_03_list['pop_50_lb'] = age_03_50['lower'].values
age_03_list['pop_50_ub'] = age_03_50['upper'].values

age_03_list['pop_55'] = age_03_55['val'].values
age_03_list['pop_55_lb'] = age_03_55['lower'].values
age_03_list['pop_55_ub'] = age_03_55['upper'].values

age_03_list['pop_60'] = age_03_60['val'].values
age_03_list['pop_60_lb'] = age_03_60['lower'].values
age_03_list['pop_60_ub'] = age_03_60['upper'].values

age_03_list['pop_65'] = age_03_65['val'].values
age_03_list['pop_65_lb'] = age_03_65['lower'].values
age_03_list['pop_65_ub'] = age_03_65['upper'].values

age_03_list['pop_70'] = age_03_70['val'].values
age_03_list['pop_70_lb'] = age_03_70['lower'].values
age_03_list['pop_70_ub'] = age_03_70['upper'].values

age_03_list['pop_75'] = age_03_75['val'].values
age_03_list['pop_75_lb'] = age_03_75['lower'].values
age_03_list['pop_75_ub'] = age_03_75['upper'].values

age_03_list['pop_80'] = age_03_80['val'].values
age_03_list['pop_80_lb'] = age_03_80['lower'].values
age_03_list['pop_80_ub'] = age_03_80['upper'].values

age_03_list['pop_25plus'] = age_03_list['pop_25']+age_03_list['pop_30']+age_03_list['pop_35']+age_03_list['pop_40']+age_03_list['pop_45']+age_03_list['pop_50']+age_03_list['pop_55']+age_03_list['pop_60']+age_03_list['pop_65']+age_03_list['pop_70']+age_03_list['pop_75']+age_03_list['pop_80']
age_03_list['pop_25plus_lb'] = age_03_list['pop_25_lb']+age_03_list['pop_30_lb']+age_03_list['pop_35_lb']+age_03_list['pop_40_lb']+age_03_list['pop_45_lb']+age_03_list['pop_50_lb']+age_03_list['pop_55_lb']+age_03_list['pop_60_lb']+age_03_list['pop_65_lb']+age_03_list['pop_70_lb']+age_03_list['pop_75_lb']+age_03_list['pop_80_lb']
age_03_list['pop_25plus_ub'] = age_03_list['pop_25_ub']+age_03_list['pop_30_ub']+age_03_list['pop_35_ub']+age_03_list['pop_40_ub']+age_03_list['pop_45_ub']+age_03_list['pop_50_ub']+age_03_list['pop_55_ub']+age_03_list['pop_60_ub']+age_03_list['pop_65_ub']+age_03_list['pop_70_ub']+age_03_list['pop_75_ub']+age_03_list['pop_80_ub']

age_03_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_03_list.csv', index=False)

# %%
age_04 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2004_Y2020M10D15.CSV')
age_04 = age_04[age_04['sex_id']==3]

age_04_25 = age_04[age_04['age_group_id'] == 10]
age_04_30 = age_04[age_04['age_group_id'] == 11]
age_04_35 = age_04[age_04['age_group_id'] == 12]
age_04_40 = age_04[age_04['age_group_id'] == 13]
age_04_45 = age_04[age_04['age_group_id'] == 14]
age_04_50 = age_04[age_04['age_group_id'] == 15]
age_04_55 = age_04[age_04['age_group_id'] == 16]
age_04_60 = age_04[age_04['age_group_id'] == 17]
age_04_65 = age_04[age_04['age_group_id'] == 18]
age_04_70 = age_04[age_04['age_group_id'] == 19]
age_04_75 = age_04[age_04['age_group_id'] == 20]
age_04_80 = age_04[age_04['age_group_id'] == 21]
age_04_all = age_04[age_04['age_group_id'] == 22]

age_04_list = age_04_all[['location_id','location_name']]
age_04_list['year'] = age_04_all['year_id']
age_04_list['pop_all'] = age_04_all['val']
age_04_list['pop_all_lb'] = age_04_all['lower']
age_04_list['pop_all_ub'] = age_04_all['upper']

age_04_list['pop_25'] = age_04_25['val'].values
age_04_list['pop_25_lb'] = age_04_25['lower'].values
age_04_list['pop_25_ub'] = age_04_25['upper'].values

age_04_list['pop_30'] = age_04_30['val'].values
age_04_list['pop_30_lb'] = age_04_30['lower'].values
age_04_list['pop_30_ub'] = age_04_30['upper'].values

age_04_list['pop_35'] = age_04_35['val'].values
age_04_list['pop_35_lb'] = age_04_35['lower'].values
age_04_list['pop_35_ub'] = age_04_35['upper'].values

age_04_list['pop_40'] = age_04_40['val'].values
age_04_list['pop_40_lb'] = age_04_40['lower'].values
age_04_list['pop_40_ub'] = age_04_40['upper'].values

age_04_list['pop_45'] = age_04_45['val'].values
age_04_list['pop_45_lb'] = age_04_45['lower'].values
age_04_list['pop_45_ub'] = age_04_45['upper'].values

age_04_list['pop_50'] = age_04_50['val'].values
age_04_list['pop_50_lb'] = age_04_50['lower'].values
age_04_list['pop_50_ub'] = age_04_50['upper'].values

age_04_list['pop_55'] = age_04_55['val'].values
age_04_list['pop_55_lb'] = age_04_55['lower'].values
age_04_list['pop_55_ub'] = age_04_55['upper'].values

age_04_list['pop_60'] = age_04_60['val'].values
age_04_list['pop_60_lb'] = age_04_60['lower'].values
age_04_list['pop_60_ub'] = age_04_60['upper'].values

age_04_list['pop_65'] = age_04_65['val'].values
age_04_list['pop_65_lb'] = age_04_65['lower'].values
age_04_list['pop_65_ub'] = age_04_65['upper'].values

age_04_list['pop_70'] = age_04_70['val'].values
age_04_list['pop_70_lb'] = age_04_70['lower'].values
age_04_list['pop_70_ub'] = age_04_70['upper'].values

age_04_list['pop_75'] = age_04_75['val'].values
age_04_list['pop_75_lb'] = age_04_75['lower'].values
age_04_list['pop_75_ub'] = age_04_75['upper'].values

age_04_list['pop_80'] = age_04_80['val'].values
age_04_list['pop_80_lb'] = age_04_80['lower'].values
age_04_list['pop_80_ub'] = age_04_80['upper'].values

age_04_list['pop_25plus'] = age_04_list['pop_25']+age_04_list['pop_30']+age_04_list['pop_35']+age_04_list['pop_40']+age_04_list['pop_45']+age_04_list['pop_50']+age_04_list['pop_55']+age_04_list['pop_60']+age_04_list['pop_65']+age_04_list['pop_70']+age_04_list['pop_75']+age_04_list['pop_80']
age_04_list['pop_25plus_lb'] = age_04_list['pop_25_lb']+age_04_list['pop_30_lb']+age_04_list['pop_35_lb']+age_04_list['pop_40_lb']+age_04_list['pop_45_lb']+age_04_list['pop_50_lb']+age_04_list['pop_55_lb']+age_04_list['pop_60_lb']+age_04_list['pop_65_lb']+age_04_list['pop_70_lb']+age_04_list['pop_75_lb']+age_04_list['pop_80_lb']
age_04_list['pop_25plus_ub'] = age_04_list['pop_25_ub']+age_04_list['pop_30_ub']+age_04_list['pop_35_ub']+age_04_list['pop_40_ub']+age_04_list['pop_45_ub']+age_04_list['pop_50_ub']+age_04_list['pop_55_ub']+age_04_list['pop_60_ub']+age_04_list['pop_65_ub']+age_04_list['pop_70_ub']+age_04_list['pop_75_ub']+age_04_list['pop_80_ub']

age_04_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_04_list.csv', index=False)

# %%
age_05 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2005_Y2020M10D15.CSV')
age_05 = age_05[age_05['sex_id']==3]

age_05_25 = age_05[age_05['age_group_id'] == 10]
age_05_30 = age_05[age_05['age_group_id'] == 11]
age_05_35 = age_05[age_05['age_group_id'] == 12]
age_05_40 = age_05[age_05['age_group_id'] == 13]
age_05_45 = age_05[age_05['age_group_id'] == 14]
age_05_50 = age_05[age_05['age_group_id'] == 15]
age_05_55 = age_05[age_05['age_group_id'] == 16]
age_05_60 = age_05[age_05['age_group_id'] == 17]
age_05_65 = age_05[age_05['age_group_id'] == 18]
age_05_70 = age_05[age_05['age_group_id'] == 19]
age_05_75 = age_05[age_05['age_group_id'] == 20]
age_05_80 = age_05[age_05['age_group_id'] == 21]
age_05_all = age_05[age_05['age_group_id'] == 22]

age_05_list = age_05_all[['location_id','location_name']]
age_05_list['year'] = age_05_all['year_id']
age_05_list['pop_all'] = age_05_all['val']
age_05_list['pop_all_lb'] = age_05_all['lower']
age_05_list['pop_all_ub'] = age_05_all['upper']

age_05_list['pop_25'] = age_05_25['val'].values
age_05_list['pop_25_lb'] = age_05_25['lower'].values
age_05_list['pop_25_ub'] = age_05_25['upper'].values

age_05_list['pop_30'] = age_05_30['val'].values
age_05_list['pop_30_lb'] = age_05_30['lower'].values
age_05_list['pop_30_ub'] = age_05_30['upper'].values

age_05_list['pop_35'] = age_05_35['val'].values
age_05_list['pop_35_lb'] = age_05_35['lower'].values
age_05_list['pop_35_ub'] = age_05_35['upper'].values

age_05_list['pop_40'] = age_05_40['val'].values
age_05_list['pop_40_lb'] = age_05_40['lower'].values
age_05_list['pop_40_ub'] = age_05_40['upper'].values

age_05_list['pop_45'] = age_05_45['val'].values
age_05_list['pop_45_lb'] = age_05_45['lower'].values
age_05_list['pop_45_ub'] = age_05_45['upper'].values

age_05_list['pop_50'] = age_05_50['val'].values
age_05_list['pop_50_lb'] = age_05_50['lower'].values
age_05_list['pop_50_ub'] = age_05_50['upper'].values

age_05_list['pop_55'] = age_05_55['val'].values
age_05_list['pop_55_lb'] = age_05_55['lower'].values
age_05_list['pop_55_ub'] = age_05_55['upper'].values

age_05_list['pop_60'] = age_05_60['val'].values
age_05_list['pop_60_lb'] = age_05_60['lower'].values
age_05_list['pop_60_ub'] = age_05_60['upper'].values

age_05_list['pop_65'] = age_05_65['val'].values
age_05_list['pop_65_lb'] = age_05_65['lower'].values
age_05_list['pop_65_ub'] = age_05_65['upper'].values

age_05_list['pop_70'] = age_05_70['val'].values
age_05_list['pop_70_lb'] = age_05_70['lower'].values
age_05_list['pop_70_ub'] = age_05_70['upper'].values

age_05_list['pop_75'] = age_05_75['val'].values
age_05_list['pop_75_lb'] = age_05_75['lower'].values
age_05_list['pop_75_ub'] = age_05_75['upper'].values

age_05_list['pop_80'] = age_05_80['val'].values
age_05_list['pop_80_lb'] = age_05_80['lower'].values
age_05_list['pop_80_ub'] = age_05_80['upper'].values

age_05_list['pop_25plus'] = age_05_list['pop_25']+age_05_list['pop_30']+age_05_list['pop_35']+age_05_list['pop_40']+age_05_list['pop_45']+age_05_list['pop_50']+age_05_list['pop_55']+age_05_list['pop_60']+age_05_list['pop_65']+age_05_list['pop_70']+age_05_list['pop_75']+age_05_list['pop_80']
age_05_list['pop_25plus_lb'] = age_05_list['pop_25_lb']+age_05_list['pop_30_lb']+age_05_list['pop_35_lb']+age_05_list['pop_40_lb']+age_05_list['pop_45_lb']+age_05_list['pop_50_lb']+age_05_list['pop_55_lb']+age_05_list['pop_60_lb']+age_05_list['pop_65_lb']+age_05_list['pop_70_lb']+age_05_list['pop_75_lb']+age_05_list['pop_80_lb']
age_05_list['pop_25plus_ub'] = age_05_list['pop_25_ub']+age_05_list['pop_30_ub']+age_05_list['pop_35_ub']+age_05_list['pop_40_ub']+age_05_list['pop_45_ub']+age_05_list['pop_50_ub']+age_05_list['pop_55_ub']+age_05_list['pop_60_ub']+age_05_list['pop_65_ub']+age_05_list['pop_70_ub']+age_05_list['pop_75_ub']+age_05_list['pop_80_ub']

age_05_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_05_list.csv', index=False)

# %%
age_06 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2006_Y2020M10D15.CSV')
age_06 = age_06[age_06['sex_id']==3]

age_06_25 = age_06[age_06['age_group_id'] == 10]
age_06_30 = age_06[age_06['age_group_id'] == 11]
age_06_35 = age_06[age_06['age_group_id'] == 12]
age_06_40 = age_06[age_06['age_group_id'] == 13]
age_06_45 = age_06[age_06['age_group_id'] == 14]
age_06_50 = age_06[age_06['age_group_id'] == 15]
age_06_55 = age_06[age_06['age_group_id'] == 16]
age_06_60 = age_06[age_06['age_group_id'] == 17]
age_06_65 = age_06[age_06['age_group_id'] == 18]
age_06_70 = age_06[age_06['age_group_id'] == 19]
age_06_75 = age_06[age_06['age_group_id'] == 20]
age_06_80 = age_06[age_06['age_group_id'] == 21]
age_06_all = age_06[age_06['age_group_id'] == 22]

age_06_list = age_06_all[['location_id','location_name']]
age_06_list['year'] = age_06_all['year_id']
age_06_list['pop_all'] = age_06_all['val']
age_06_list['pop_all_lb'] = age_06_all['lower']
age_06_list['pop_all_ub'] = age_06_all['upper']

age_06_list['pop_25'] = age_06_25['val'].values
age_06_list['pop_25_lb'] = age_06_25['lower'].values
age_06_list['pop_25_ub'] = age_06_25['upper'].values

age_06_list['pop_30'] = age_06_30['val'].values
age_06_list['pop_30_lb'] = age_06_30['lower'].values
age_06_list['pop_30_ub'] = age_06_30['upper'].values

age_06_list['pop_35'] = age_06_35['val'].values
age_06_list['pop_35_lb'] = age_06_35['lower'].values
age_06_list['pop_35_ub'] = age_06_35['upper'].values

age_06_list['pop_40'] = age_06_40['val'].values
age_06_list['pop_40_lb'] = age_06_40['lower'].values
age_06_list['pop_40_ub'] = age_06_40['upper'].values

age_06_list['pop_45'] = age_06_45['val'].values
age_06_list['pop_45_lb'] = age_06_45['lower'].values
age_06_list['pop_45_ub'] = age_06_45['upper'].values

age_06_list['pop_50'] = age_06_50['val'].values
age_06_list['pop_50_lb'] = age_06_50['lower'].values
age_06_list['pop_50_ub'] = age_06_50['upper'].values

age_06_list['pop_55'] = age_06_55['val'].values
age_06_list['pop_55_lb'] = age_06_55['lower'].values
age_06_list['pop_55_ub'] = age_06_55['upper'].values

age_06_list['pop_60'] = age_06_60['val'].values
age_06_list['pop_60_lb'] = age_06_60['lower'].values
age_06_list['pop_60_ub'] = age_06_60['upper'].values

age_06_list['pop_65'] = age_06_65['val'].values
age_06_list['pop_65_lb'] = age_06_65['lower'].values
age_06_list['pop_65_ub'] = age_06_65['upper'].values

age_06_list['pop_70'] = age_06_70['val'].values
age_06_list['pop_70_lb'] = age_06_70['lower'].values
age_06_list['pop_70_ub'] = age_06_70['upper'].values

age_06_list['pop_75'] = age_06_75['val'].values
age_06_list['pop_75_lb'] = age_06_75['lower'].values
age_06_list['pop_75_ub'] = age_06_75['upper'].values

age_06_list['pop_80'] = age_06_80['val'].values
age_06_list['pop_80_lb'] = age_06_80['lower'].values
age_06_list['pop_80_ub'] = age_06_80['upper'].values

age_06_list['pop_25plus'] = age_06_list['pop_25']+age_06_list['pop_30']+age_06_list['pop_35']+age_06_list['pop_40']+age_06_list['pop_45']+age_06_list['pop_50']+age_06_list['pop_55']+age_06_list['pop_60']+age_06_list['pop_65']+age_06_list['pop_70']+age_06_list['pop_75']+age_06_list['pop_80']
age_06_list['pop_25plus_lb'] = age_06_list['pop_25_lb']+age_06_list['pop_30_lb']+age_06_list['pop_35_lb']+age_06_list['pop_40_lb']+age_06_list['pop_45_lb']+age_06_list['pop_50_lb']+age_06_list['pop_55_lb']+age_06_list['pop_60_lb']+age_06_list['pop_65_lb']+age_06_list['pop_70_lb']+age_06_list['pop_75_lb']+age_06_list['pop_80_lb']
age_06_list['pop_25plus_ub'] = age_06_list['pop_25_ub']+age_06_list['pop_30_ub']+age_06_list['pop_35_ub']+age_06_list['pop_40_ub']+age_06_list['pop_45_ub']+age_06_list['pop_50_ub']+age_06_list['pop_55_ub']+age_06_list['pop_60_ub']+age_06_list['pop_65_ub']+age_06_list['pop_70_ub']+age_06_list['pop_75_ub']+age_06_list['pop_80_ub']

age_06_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_06_list.csv', index=False)

# %%
age_07 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2007_Y2020M10D15.CSV')
age_07 = age_07[age_07['sex_id']==3]

age_07_25 = age_07[age_07['age_group_id'] == 10]
age_07_30 = age_07[age_07['age_group_id'] == 11]
age_07_35 = age_07[age_07['age_group_id'] == 12]
age_07_40 = age_07[age_07['age_group_id'] == 13]
age_07_45 = age_07[age_07['age_group_id'] == 14]
age_07_50 = age_07[age_07['age_group_id'] == 15]
age_07_55 = age_07[age_07['age_group_id'] == 16]
age_07_60 = age_07[age_07['age_group_id'] == 17]
age_07_65 = age_07[age_07['age_group_id'] == 18]
age_07_70 = age_07[age_07['age_group_id'] == 19]
age_07_75 = age_07[age_07['age_group_id'] == 20]
age_07_80 = age_07[age_07['age_group_id'] == 21]
age_07_all = age_07[age_07['age_group_id'] == 22]

age_07_list = age_07_all[['location_id','location_name']]
age_07_list['year'] = age_07_all['year_id']
age_07_list['pop_all'] = age_07_all['val']
age_07_list['pop_all_lb'] = age_07_all['lower']
age_07_list['pop_all_ub'] = age_07_all['upper']

age_07_list['pop_25'] = age_07_25['val'].values
age_07_list['pop_25_lb'] = age_07_25['lower'].values
age_07_list['pop_25_ub'] = age_07_25['upper'].values

age_07_list['pop_30'] = age_07_30['val'].values
age_07_list['pop_30_lb'] = age_07_30['lower'].values
age_07_list['pop_30_ub'] = age_07_30['upper'].values

age_07_list['pop_35'] = age_07_35['val'].values
age_07_list['pop_35_lb'] = age_07_35['lower'].values
age_07_list['pop_35_ub'] = age_07_35['upper'].values

age_07_list['pop_40'] = age_07_40['val'].values
age_07_list['pop_40_lb'] = age_07_40['lower'].values
age_07_list['pop_40_ub'] = age_07_40['upper'].values

age_07_list['pop_45'] = age_07_45['val'].values
age_07_list['pop_45_lb'] = age_07_45['lower'].values
age_07_list['pop_45_ub'] = age_07_45['upper'].values

age_07_list['pop_50'] = age_07_50['val'].values
age_07_list['pop_50_lb'] = age_07_50['lower'].values
age_07_list['pop_50_ub'] = age_07_50['upper'].values

age_07_list['pop_55'] = age_07_55['val'].values
age_07_list['pop_55_lb'] = age_07_55['lower'].values
age_07_list['pop_55_ub'] = age_07_55['upper'].values

age_07_list['pop_60'] = age_07_60['val'].values
age_07_list['pop_60_lb'] = age_07_60['lower'].values
age_07_list['pop_60_ub'] = age_07_60['upper'].values

age_07_list['pop_65'] = age_07_65['val'].values
age_07_list['pop_65_lb'] = age_07_65['lower'].values
age_07_list['pop_65_ub'] = age_07_65['upper'].values

age_07_list['pop_70'] = age_07_70['val'].values
age_07_list['pop_70_lb'] = age_07_70['lower'].values
age_07_list['pop_70_ub'] = age_07_70['upper'].values

age_07_list['pop_75'] = age_07_75['val'].values
age_07_list['pop_75_lb'] = age_07_75['lower'].values
age_07_list['pop_75_ub'] = age_07_75['upper'].values

age_07_list['pop_80'] = age_07_80['val'].values
age_07_list['pop_80_lb'] = age_07_80['lower'].values
age_07_list['pop_80_ub'] = age_07_80['upper'].values

age_07_list['pop_25plus'] = age_07_list['pop_25']+age_07_list['pop_30']+age_07_list['pop_35']+age_07_list['pop_40']+age_07_list['pop_45']+age_07_list['pop_50']+age_07_list['pop_55']+age_07_list['pop_60']+age_07_list['pop_65']+age_07_list['pop_70']+age_07_list['pop_75']+age_07_list['pop_80']
age_07_list['pop_25plus_lb'] = age_07_list['pop_25_lb']+age_07_list['pop_30_lb']+age_07_list['pop_35_lb']+age_07_list['pop_40_lb']+age_07_list['pop_45_lb']+age_07_list['pop_50_lb']+age_07_list['pop_55_lb']+age_07_list['pop_60_lb']+age_07_list['pop_65_lb']+age_07_list['pop_70_lb']+age_07_list['pop_75_lb']+age_07_list['pop_80_lb']
age_07_list['pop_25plus_ub'] = age_07_list['pop_25_ub']+age_07_list['pop_30_ub']+age_07_list['pop_35_ub']+age_07_list['pop_40_ub']+age_07_list['pop_45_ub']+age_07_list['pop_50_ub']+age_07_list['pop_55_ub']+age_07_list['pop_60_ub']+age_07_list['pop_65_ub']+age_07_list['pop_70_ub']+age_07_list['pop_75_ub']+age_07_list['pop_80_ub']

age_07_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_07_list.csv', index=False)

# %%
age_08 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2008_Y2020M10D15.CSV')
age_08 = age_08[age_08['sex_id']==3]

age_08_25 = age_08[age_08['age_group_id'] == 10]
age_08_30 = age_08[age_08['age_group_id'] == 11]
age_08_35 = age_08[age_08['age_group_id'] == 12]
age_08_40 = age_08[age_08['age_group_id'] == 13]
age_08_45 = age_08[age_08['age_group_id'] == 14]
age_08_50 = age_08[age_08['age_group_id'] == 15]
age_08_55 = age_08[age_08['age_group_id'] == 16]
age_08_60 = age_08[age_08['age_group_id'] == 17]
age_08_65 = age_08[age_08['age_group_id'] == 18]
age_08_70 = age_08[age_08['age_group_id'] == 19]
age_08_75 = age_08[age_08['age_group_id'] == 20]
age_08_80 = age_08[age_08['age_group_id'] == 21]
age_08_all = age_08[age_08['age_group_id'] == 22]

age_08_list = age_08_all[['location_id','location_name']]
age_08_list['year'] = age_08_all['year_id']
age_08_list['pop_all'] = age_08_all['val']
age_08_list['pop_all_lb'] = age_08_all['lower']
age_08_list['pop_all_ub'] = age_08_all['upper']

age_08_list['pop_25'] = age_08_25['val'].values
age_08_list['pop_25_lb'] = age_08_25['lower'].values
age_08_list['pop_25_ub'] = age_08_25['upper'].values

age_08_list['pop_30'] = age_08_30['val'].values
age_08_list['pop_30_lb'] = age_08_30['lower'].values
age_08_list['pop_30_ub'] = age_08_30['upper'].values

age_08_list['pop_35'] = age_08_35['val'].values
age_08_list['pop_35_lb'] = age_08_35['lower'].values
age_08_list['pop_35_ub'] = age_08_35['upper'].values

age_08_list['pop_40'] = age_08_40['val'].values
age_08_list['pop_40_lb'] = age_08_40['lower'].values
age_08_list['pop_40_ub'] = age_08_40['upper'].values

age_08_list['pop_45'] = age_08_45['val'].values
age_08_list['pop_45_lb'] = age_08_45['lower'].values
age_08_list['pop_45_ub'] = age_08_45['upper'].values

age_08_list['pop_50'] = age_08_50['val'].values
age_08_list['pop_50_lb'] = age_08_50['lower'].values
age_08_list['pop_50_ub'] = age_08_50['upper'].values

age_08_list['pop_55'] = age_08_55['val'].values
age_08_list['pop_55_lb'] = age_08_55['lower'].values
age_08_list['pop_55_ub'] = age_08_55['upper'].values

age_08_list['pop_60'] = age_08_60['val'].values
age_08_list['pop_60_lb'] = age_08_60['lower'].values
age_08_list['pop_60_ub'] = age_08_60['upper'].values

age_08_list['pop_65'] = age_08_65['val'].values
age_08_list['pop_65_lb'] = age_08_65['lower'].values
age_08_list['pop_65_ub'] = age_08_65['upper'].values

age_08_list['pop_70'] = age_08_70['val'].values
age_08_list['pop_70_lb'] = age_08_70['lower'].values
age_08_list['pop_70_ub'] = age_08_70['upper'].values

age_08_list['pop_75'] = age_08_75['val'].values
age_08_list['pop_75_lb'] = age_08_75['lower'].values
age_08_list['pop_75_ub'] = age_08_75['upper'].values

age_08_list['pop_80'] = age_08_80['val'].values
age_08_list['pop_80_lb'] = age_08_80['lower'].values
age_08_list['pop_80_ub'] = age_08_80['upper'].values

age_08_list['pop_25plus'] = age_08_list['pop_25']+age_08_list['pop_30']+age_08_list['pop_35']+age_08_list['pop_40']+age_08_list['pop_45']+age_08_list['pop_50']+age_08_list['pop_55']+age_08_list['pop_60']+age_08_list['pop_65']+age_08_list['pop_70']+age_08_list['pop_75']+age_08_list['pop_80']
age_08_list['pop_25plus_lb'] = age_08_list['pop_25_lb']+age_08_list['pop_30_lb']+age_08_list['pop_35_lb']+age_08_list['pop_40_lb']+age_08_list['pop_45_lb']+age_08_list['pop_50_lb']+age_08_list['pop_55_lb']+age_08_list['pop_60_lb']+age_08_list['pop_65_lb']+age_08_list['pop_70_lb']+age_08_list['pop_75_lb']+age_08_list['pop_80_lb']
age_08_list['pop_25plus_ub'] = age_08_list['pop_25_ub']+age_08_list['pop_30_ub']+age_08_list['pop_35_ub']+age_08_list['pop_40_ub']+age_08_list['pop_45_ub']+age_08_list['pop_50_ub']+age_08_list['pop_55_ub']+age_08_list['pop_60_ub']+age_08_list['pop_65_ub']+age_08_list['pop_70_ub']+age_08_list['pop_75_ub']+age_08_list['pop_80_ub']

age_08_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_08_list.csv', index=False)

# %%
age_09 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2000_2009_0/IHME_GBD_2019_POP_2009_Y2020M10D15.CSV')
age_09 = age_09[age_09['sex_id']==3]

age_09_25 = age_09[age_09['age_group_id'] == 10]
age_09_30 = age_09[age_09['age_group_id'] == 11]
age_09_35 = age_09[age_09['age_group_id'] == 12]
age_09_40 = age_09[age_09['age_group_id'] == 13]
age_09_45 = age_09[age_09['age_group_id'] == 14]
age_09_50 = age_09[age_09['age_group_id'] == 15]
age_09_55 = age_09[age_09['age_group_id'] == 16]
age_09_60 = age_09[age_09['age_group_id'] == 17]
age_09_65 = age_09[age_09['age_group_id'] == 18]
age_09_70 = age_09[age_09['age_group_id'] == 19]
age_09_75 = age_09[age_09['age_group_id'] == 20]
age_09_80 = age_09[age_09['age_group_id'] == 21]
age_09_all = age_09[age_09['age_group_id'] == 22]

age_09_list = age_09_all[['location_id','location_name']]
age_09_list['year'] = age_09_all['year_id']
age_09_list['pop_all'] = age_09_all['val']
age_09_list['pop_all_lb'] = age_09_all['lower']
age_09_list['pop_all_ub'] = age_09_all['upper']

age_09_list['pop_25'] = age_09_25['val'].values
age_09_list['pop_25_lb'] = age_09_25['lower'].values
age_09_list['pop_25_ub'] = age_09_25['upper'].values

age_09_list['pop_30'] = age_09_30['val'].values
age_09_list['pop_30_lb'] = age_09_30['lower'].values
age_09_list['pop_30_ub'] = age_09_30['upper'].values

age_09_list['pop_35'] = age_09_35['val'].values
age_09_list['pop_35_lb'] = age_09_35['lower'].values
age_09_list['pop_35_ub'] = age_09_35['upper'].values

age_09_list['pop_40'] = age_09_40['val'].values
age_09_list['pop_40_lb'] = age_09_40['lower'].values
age_09_list['pop_40_ub'] = age_09_40['upper'].values

age_09_list['pop_45'] = age_09_45['val'].values
age_09_list['pop_45_lb'] = age_09_45['lower'].values
age_09_list['pop_45_ub'] = age_09_45['upper'].values

age_09_list['pop_50'] = age_09_50['val'].values
age_09_list['pop_50_lb'] = age_09_50['lower'].values
age_09_list['pop_50_ub'] = age_09_50['upper'].values

age_09_list['pop_55'] = age_09_55['val'].values
age_09_list['pop_55_lb'] = age_09_55['lower'].values
age_09_list['pop_55_ub'] = age_09_55['upper'].values

age_09_list['pop_60'] = age_09_60['val'].values
age_09_list['pop_60_lb'] = age_09_60['lower'].values
age_09_list['pop_60_ub'] = age_09_60['upper'].values

age_09_list['pop_65'] = age_09_65['val'].values
age_09_list['pop_65_lb'] = age_09_65['lower'].values
age_09_list['pop_65_ub'] = age_09_65['upper'].values

age_09_list['pop_70'] = age_09_70['val'].values
age_09_list['pop_70_lb'] = age_09_70['lower'].values
age_09_list['pop_70_ub'] = age_09_70['upper'].values

age_09_list['pop_75'] = age_09_75['val'].values
age_09_list['pop_75_lb'] = age_09_75['lower'].values
age_09_list['pop_75_ub'] = age_09_75['upper'].values

age_09_list['pop_80'] = age_09_80['val'].values
age_09_list['pop_80_lb'] = age_09_80['lower'].values
age_09_list['pop_80_ub'] = age_09_80['upper'].values

age_09_list['pop_25plus'] = age_09_list['pop_25']+age_09_list['pop_30']+age_09_list['pop_35']+age_09_list['pop_40']+age_09_list['pop_45']+age_09_list['pop_50']+age_09_list['pop_55']+age_09_list['pop_60']+age_09_list['pop_65']+age_09_list['pop_70']+age_09_list['pop_75']+age_09_list['pop_80']
age_09_list['pop_25plus_lb'] = age_09_list['pop_25_lb']+age_09_list['pop_30_lb']+age_09_list['pop_35_lb']+age_09_list['pop_40_lb']+age_09_list['pop_45_lb']+age_09_list['pop_50_lb']+age_09_list['pop_55_lb']+age_09_list['pop_60_lb']+age_09_list['pop_65_lb']+age_09_list['pop_70_lb']+age_09_list['pop_75_lb']+age_09_list['pop_80_lb']
age_09_list['pop_25plus_ub'] = age_09_list['pop_25_ub']+age_09_list['pop_30_ub']+age_09_list['pop_35_ub']+age_09_list['pop_40_ub']+age_09_list['pop_45_ub']+age_09_list['pop_50_ub']+age_09_list['pop_55_ub']+age_09_list['pop_60_ub']+age_09_list['pop_65_ub']+age_09_list['pop_70_ub']+age_09_list['pop_75_ub']+age_09_list['pop_80_ub']

age_09_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_09_list.csv', index=False)

# %%
age_10 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2010_Y2020M10D15.CSV')
age_10 = age_10[age_10['sex_id']==3]

age_10_25 = age_10[age_10['age_group_id'] == 10]
age_10_30 = age_10[age_10['age_group_id'] == 11]
age_10_35 = age_10[age_10['age_group_id'] == 12]
age_10_40 = age_10[age_10['age_group_id'] == 13]
age_10_45 = age_10[age_10['age_group_id'] == 14]
age_10_50 = age_10[age_10['age_group_id'] == 15]
age_10_55 = age_10[age_10['age_group_id'] == 16]
age_10_60 = age_10[age_10['age_group_id'] == 17]
age_10_65 = age_10[age_10['age_group_id'] == 18]
age_10_70 = age_10[age_10['age_group_id'] == 19]
age_10_75 = age_10[age_10['age_group_id'] == 20]
age_10_80 = age_10[age_10['age_group_id'] == 21]
age_10_all = age_10[age_10['age_group_id'] == 22]

age_10_list = age_10_all[['location_id','location_name']]
age_10_list['year'] = age_10_all['year_id']
age_10_list['pop_all'] = age_10_all['val']
age_10_list['pop_all_lb'] = age_10_all['lower']
age_10_list['pop_all_ub'] = age_10_all['upper']

age_10_list['pop_25'] = age_10_25['val'].values
age_10_list['pop_25_lb'] = age_10_25['lower'].values
age_10_list['pop_25_ub'] = age_10_25['upper'].values

age_10_list['pop_30'] = age_10_30['val'].values
age_10_list['pop_30_lb'] = age_10_30['lower'].values
age_10_list['pop_30_ub'] = age_10_30['upper'].values

age_10_list['pop_35'] = age_10_35['val'].values
age_10_list['pop_35_lb'] = age_10_35['lower'].values
age_10_list['pop_35_ub'] = age_10_35['upper'].values

age_10_list['pop_40'] = age_10_40['val'].values
age_10_list['pop_40_lb'] = age_10_40['lower'].values
age_10_list['pop_40_ub'] = age_10_40['upper'].values

age_10_list['pop_45'] = age_10_45['val'].values
age_10_list['pop_45_lb'] = age_10_45['lower'].values
age_10_list['pop_45_ub'] = age_10_45['upper'].values

age_10_list['pop_50'] = age_10_50['val'].values
age_10_list['pop_50_lb'] = age_10_50['lower'].values
age_10_list['pop_50_ub'] = age_10_50['upper'].values

age_10_list['pop_55'] = age_10_55['val'].values
age_10_list['pop_55_lb'] = age_10_55['lower'].values
age_10_list['pop_55_ub'] = age_10_55['upper'].values

age_10_list['pop_60'] = age_10_60['val'].values
age_10_list['pop_60_lb'] = age_10_60['lower'].values
age_10_list['pop_60_ub'] = age_10_60['upper'].values

age_10_list['pop_65'] = age_10_65['val'].values
age_10_list['pop_65_lb'] = age_10_65['lower'].values
age_10_list['pop_65_ub'] = age_10_65['upper'].values

age_10_list['pop_70'] = age_10_70['val'].values
age_10_list['pop_70_lb'] = age_10_70['lower'].values
age_10_list['pop_70_ub'] = age_10_70['upper'].values

age_10_list['pop_75'] = age_10_75['val'].values
age_10_list['pop_75_lb'] = age_10_75['lower'].values
age_10_list['pop_75_ub'] = age_10_75['upper'].values

age_10_list['pop_80'] = age_10_80['val'].values
age_10_list['pop_80_lb'] = age_10_80['lower'].values
age_10_list['pop_80_ub'] = age_10_80['upper'].values

age_10_list['pop_25plus'] = age_10_list['pop_25']+age_10_list['pop_30']+age_10_list['pop_35']+age_10_list['pop_40']+age_10_list['pop_45']+age_10_list['pop_50']+age_10_list['pop_55']+age_10_list['pop_60']+age_10_list['pop_65']+age_10_list['pop_70']+age_10_list['pop_75']+age_10_list['pop_80']
age_10_list['pop_25plus_lb'] = age_10_list['pop_25_lb']+age_10_list['pop_30_lb']+age_10_list['pop_35_lb']+age_10_list['pop_40_lb']+age_10_list['pop_45_lb']+age_10_list['pop_50_lb']+age_10_list['pop_55_lb']+age_10_list['pop_60_lb']+age_10_list['pop_65_lb']+age_10_list['pop_70_lb']+age_10_list['pop_75_lb']+age_10_list['pop_80_lb']
age_10_list['pop_25plus_ub'] = age_10_list['pop_25_ub']+age_10_list['pop_30_ub']+age_10_list['pop_35_ub']+age_10_list['pop_40_ub']+age_10_list['pop_45_ub']+age_10_list['pop_50_ub']+age_10_list['pop_55_ub']+age_10_list['pop_60_ub']+age_10_list['pop_65_ub']+age_10_list['pop_70_ub']+age_10_list['pop_75_ub']+age_10_list['pop_80_ub']

age_10_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_10_list.csv', index=False)

# %%
age_11 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2011_Y2020M10D15.CSV')
age_11 = age_11[age_11['sex_id']==3]

age_11_25 = age_11[age_11['age_group_id'] == 11]
age_11_30 = age_11[age_11['age_group_id'] == 11]
age_11_35 = age_11[age_11['age_group_id'] == 12]
age_11_40 = age_11[age_11['age_group_id'] == 13]
age_11_45 = age_11[age_11['age_group_id'] == 14]
age_11_50 = age_11[age_11['age_group_id'] == 15]
age_11_55 = age_11[age_11['age_group_id'] == 16]
age_11_60 = age_11[age_11['age_group_id'] == 17]
age_11_65 = age_11[age_11['age_group_id'] == 18]
age_11_70 = age_11[age_11['age_group_id'] == 19]
age_11_75 = age_11[age_11['age_group_id'] == 20]
age_11_80 = age_11[age_11['age_group_id'] == 21]
age_11_all = age_11[age_11['age_group_id'] == 22]

age_11_list = age_11_all[['location_id','location_name']]
age_11_list['year'] = age_11_all['year_id']
age_11_list['pop_all'] = age_11_all['val']
age_11_list['pop_all_lb'] = age_11_all['lower']
age_11_list['pop_all_ub'] = age_11_all['upper']

age_11_list['pop_25'] = age_11_25['val'].values
age_11_list['pop_25_lb'] = age_11_25['lower'].values
age_11_list['pop_25_ub'] = age_11_25['upper'].values

age_11_list['pop_30'] = age_11_30['val'].values
age_11_list['pop_30_lb'] = age_11_30['lower'].values
age_11_list['pop_30_ub'] = age_11_30['upper'].values

age_11_list['pop_35'] = age_11_35['val'].values
age_11_list['pop_35_lb'] = age_11_35['lower'].values
age_11_list['pop_35_ub'] = age_11_35['upper'].values

age_11_list['pop_40'] = age_11_40['val'].values
age_11_list['pop_40_lb'] = age_11_40['lower'].values
age_11_list['pop_40_ub'] = age_11_40['upper'].values

age_11_list['pop_45'] = age_11_45['val'].values
age_11_list['pop_45_lb'] = age_11_45['lower'].values
age_11_list['pop_45_ub'] = age_11_45['upper'].values

age_11_list['pop_50'] = age_11_50['val'].values
age_11_list['pop_50_lb'] = age_11_50['lower'].values
age_11_list['pop_50_ub'] = age_11_50['upper'].values

age_11_list['pop_55'] = age_11_55['val'].values
age_11_list['pop_55_lb'] = age_11_55['lower'].values
age_11_list['pop_55_ub'] = age_11_55['upper'].values

age_11_list['pop_60'] = age_11_60['val'].values
age_11_list['pop_60_lb'] = age_11_60['lower'].values
age_11_list['pop_60_ub'] = age_11_60['upper'].values

age_11_list['pop_65'] = age_11_65['val'].values
age_11_list['pop_65_lb'] = age_11_65['lower'].values
age_11_list['pop_65_ub'] = age_11_65['upper'].values

age_11_list['pop_70'] = age_11_70['val'].values
age_11_list['pop_70_lb'] = age_11_70['lower'].values
age_11_list['pop_70_ub'] = age_11_70['upper'].values

age_11_list['pop_75'] = age_11_75['val'].values
age_11_list['pop_75_lb'] = age_11_75['lower'].values
age_11_list['pop_75_ub'] = age_11_75['upper'].values

age_11_list['pop_80'] = age_11_80['val'].values
age_11_list['pop_80_lb'] = age_11_80['lower'].values
age_11_list['pop_80_ub'] = age_11_80['upper'].values

age_11_list['pop_25plus'] = age_11_list['pop_25']+age_11_list['pop_30']+age_11_list['pop_35']+age_11_list['pop_40']+age_11_list['pop_45']+age_11_list['pop_50']+age_11_list['pop_55']+age_11_list['pop_60']+age_11_list['pop_65']+age_11_list['pop_70']+age_11_list['pop_75']+age_11_list['pop_80']
age_11_list['pop_25plus_lb'] = age_11_list['pop_25_lb']+age_11_list['pop_30_lb']+age_11_list['pop_35_lb']+age_11_list['pop_40_lb']+age_11_list['pop_45_lb']+age_11_list['pop_50_lb']+age_11_list['pop_55_lb']+age_11_list['pop_60_lb']+age_11_list['pop_65_lb']+age_11_list['pop_70_lb']+age_11_list['pop_75_lb']+age_11_list['pop_80_lb']
age_11_list['pop_25plus_ub'] = age_11_list['pop_25_ub']+age_11_list['pop_30_ub']+age_11_list['pop_35_ub']+age_11_list['pop_40_ub']+age_11_list['pop_45_ub']+age_11_list['pop_50_ub']+age_11_list['pop_55_ub']+age_11_list['pop_60_ub']+age_11_list['pop_65_ub']+age_11_list['pop_70_ub']+age_11_list['pop_75_ub']+age_11_list['pop_80_ub']

age_11_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_11_list.csv', index=False)

# %%
age_12 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2012_Y2020M10D15.CSV')
age_12 = age_12[age_12['sex_id']==3]

age_12_25 = age_12[age_12['age_group_id'] == 12]
age_12_30 = age_12[age_12['age_group_id'] == 12]
age_12_35 = age_12[age_12['age_group_id'] == 12]
age_12_40 = age_12[age_12['age_group_id'] == 13]
age_12_45 = age_12[age_12['age_group_id'] == 14]
age_12_50 = age_12[age_12['age_group_id'] == 15]
age_12_55 = age_12[age_12['age_group_id'] == 16]
age_12_60 = age_12[age_12['age_group_id'] == 17]
age_12_65 = age_12[age_12['age_group_id'] == 18]
age_12_70 = age_12[age_12['age_group_id'] == 19]
age_12_75 = age_12[age_12['age_group_id'] == 20]
age_12_80 = age_12[age_12['age_group_id'] == 21]
age_12_all = age_12[age_12['age_group_id'] == 22]

age_12_list = age_12_all[['location_id','location_name']]
age_12_list['year'] = age_12_all['year_id']
age_12_list['pop_all'] = age_12_all['val']
age_12_list['pop_all_lb'] = age_12_all['lower']
age_12_list['pop_all_ub'] = age_12_all['upper']

age_12_list['pop_25'] = age_12_25['val'].values
age_12_list['pop_25_lb'] = age_12_25['lower'].values
age_12_list['pop_25_ub'] = age_12_25['upper'].values

age_12_list['pop_30'] = age_12_30['val'].values
age_12_list['pop_30_lb'] = age_12_30['lower'].values
age_12_list['pop_30_ub'] = age_12_30['upper'].values

age_12_list['pop_35'] = age_12_35['val'].values
age_12_list['pop_35_lb'] = age_12_35['lower'].values
age_12_list['pop_35_ub'] = age_12_35['upper'].values

age_12_list['pop_40'] = age_12_40['val'].values
age_12_list['pop_40_lb'] = age_12_40['lower'].values
age_12_list['pop_40_ub'] = age_12_40['upper'].values

age_12_list['pop_45'] = age_12_45['val'].values
age_12_list['pop_45_lb'] = age_12_45['lower'].values
age_12_list['pop_45_ub'] = age_12_45['upper'].values

age_12_list['pop_50'] = age_12_50['val'].values
age_12_list['pop_50_lb'] = age_12_50['lower'].values
age_12_list['pop_50_ub'] = age_12_50['upper'].values

age_12_list['pop_55'] = age_12_55['val'].values
age_12_list['pop_55_lb'] = age_12_55['lower'].values
age_12_list['pop_55_ub'] = age_12_55['upper'].values

age_12_list['pop_60'] = age_12_60['val'].values
age_12_list['pop_60_lb'] = age_12_60['lower'].values
age_12_list['pop_60_ub'] = age_12_60['upper'].values

age_12_list['pop_65'] = age_12_65['val'].values
age_12_list['pop_65_lb'] = age_12_65['lower'].values
age_12_list['pop_65_ub'] = age_12_65['upper'].values

age_12_list['pop_70'] = age_12_70['val'].values
age_12_list['pop_70_lb'] = age_12_70['lower'].values
age_12_list['pop_70_ub'] = age_12_70['upper'].values

age_12_list['pop_75'] = age_12_75['val'].values
age_12_list['pop_75_lb'] = age_12_75['lower'].values
age_12_list['pop_75_ub'] = age_12_75['upper'].values

age_12_list['pop_80'] = age_12_80['val'].values
age_12_list['pop_80_lb'] = age_12_80['lower'].values
age_12_list['pop_80_ub'] = age_12_80['upper'].values

age_12_list['pop_25plus'] = age_12_list['pop_25']+age_12_list['pop_30']+age_12_list['pop_35']+age_12_list['pop_40']+age_12_list['pop_45']+age_12_list['pop_50']+age_12_list['pop_55']+age_12_list['pop_60']+age_12_list['pop_65']+age_12_list['pop_70']+age_12_list['pop_75']+age_12_list['pop_80']
age_12_list['pop_25plus_lb'] = age_12_list['pop_25_lb']+age_12_list['pop_30_lb']+age_12_list['pop_35_lb']+age_12_list['pop_40_lb']+age_12_list['pop_45_lb']+age_12_list['pop_50_lb']+age_12_list['pop_55_lb']+age_12_list['pop_60_lb']+age_12_list['pop_65_lb']+age_12_list['pop_70_lb']+age_12_list['pop_75_lb']+age_12_list['pop_80_lb']
age_12_list['pop_25plus_ub'] = age_12_list['pop_25_ub']+age_12_list['pop_30_ub']+age_12_list['pop_35_ub']+age_12_list['pop_40_ub']+age_12_list['pop_45_ub']+age_12_list['pop_50_ub']+age_12_list['pop_55_ub']+age_12_list['pop_60_ub']+age_12_list['pop_65_ub']+age_12_list['pop_70_ub']+age_12_list['pop_75_ub']+age_12_list['pop_80_ub']

age_12_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_12_list.csv', index=False)

# %%
age_13 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2013_Y2020M10D15.CSV')
age_13 = age_13[age_13['sex_id']==3]

age_13_25 = age_13[age_13['age_group_id'] == 13]
age_13_30 = age_13[age_13['age_group_id'] == 13]
age_13_35 = age_13[age_13['age_group_id'] == 12]
age_13_40 = age_13[age_13['age_group_id'] == 13]
age_13_45 = age_13[age_13['age_group_id'] == 14]
age_13_50 = age_13[age_13['age_group_id'] == 15]
age_13_55 = age_13[age_13['age_group_id'] == 16]
age_13_60 = age_13[age_13['age_group_id'] == 17]
age_13_65 = age_13[age_13['age_group_id'] == 18]
age_13_70 = age_13[age_13['age_group_id'] == 19]
age_13_75 = age_13[age_13['age_group_id'] == 20]
age_13_80 = age_13[age_13['age_group_id'] == 21]
age_13_all = age_13[age_13['age_group_id'] == 22]

age_13_list = age_13_all[['location_id','location_name']]
age_13_list['year'] = age_13_all['year_id']
age_13_list['pop_all'] = age_13_all['val']
age_13_list['pop_all_lb'] = age_13_all['lower']
age_13_list['pop_all_ub'] = age_13_all['upper']

age_13_list['pop_25'] = age_13_25['val'].values
age_13_list['pop_25_lb'] = age_13_25['lower'].values
age_13_list['pop_25_ub'] = age_13_25['upper'].values

age_13_list['pop_30'] = age_13_30['val'].values
age_13_list['pop_30_lb'] = age_13_30['lower'].values
age_13_list['pop_30_ub'] = age_13_30['upper'].values

age_13_list['pop_35'] = age_13_35['val'].values
age_13_list['pop_35_lb'] = age_13_35['lower'].values
age_13_list['pop_35_ub'] = age_13_35['upper'].values

age_13_list['pop_40'] = age_13_40['val'].values
age_13_list['pop_40_lb'] = age_13_40['lower'].values
age_13_list['pop_40_ub'] = age_13_40['upper'].values

age_13_list['pop_45'] = age_13_45['val'].values
age_13_list['pop_45_lb'] = age_13_45['lower'].values
age_13_list['pop_45_ub'] = age_13_45['upper'].values

age_13_list['pop_50'] = age_13_50['val'].values
age_13_list['pop_50_lb'] = age_13_50['lower'].values
age_13_list['pop_50_ub'] = age_13_50['upper'].values

age_13_list['pop_55'] = age_13_55['val'].values
age_13_list['pop_55_lb'] = age_13_55['lower'].values
age_13_list['pop_55_ub'] = age_13_55['upper'].values

age_13_list['pop_60'] = age_13_60['val'].values
age_13_list['pop_60_lb'] = age_13_60['lower'].values
age_13_list['pop_60_ub'] = age_13_60['upper'].values

age_13_list['pop_65'] = age_13_65['val'].values
age_13_list['pop_65_lb'] = age_13_65['lower'].values
age_13_list['pop_65_ub'] = age_13_65['upper'].values

age_13_list['pop_70'] = age_13_70['val'].values
age_13_list['pop_70_lb'] = age_13_70['lower'].values
age_13_list['pop_70_ub'] = age_13_70['upper'].values

age_13_list['pop_75'] = age_13_75['val'].values
age_13_list['pop_75_lb'] = age_13_75['lower'].values
age_13_list['pop_75_ub'] = age_13_75['upper'].values

age_13_list['pop_80'] = age_13_80['val'].values
age_13_list['pop_80_lb'] = age_13_80['lower'].values
age_13_list['pop_80_ub'] = age_13_80['upper'].values

age_13_list['pop_25plus'] = age_13_list['pop_25']+age_13_list['pop_30']+age_13_list['pop_35']+age_13_list['pop_40']+age_13_list['pop_45']+age_13_list['pop_50']+age_13_list['pop_55']+age_13_list['pop_60']+age_13_list['pop_65']+age_13_list['pop_70']+age_13_list['pop_75']+age_13_list['pop_80']
age_13_list['pop_25plus_lb'] = age_13_list['pop_25_lb']+age_13_list['pop_30_lb']+age_13_list['pop_35_lb']+age_13_list['pop_40_lb']+age_13_list['pop_45_lb']+age_13_list['pop_50_lb']+age_13_list['pop_55_lb']+age_13_list['pop_60_lb']+age_13_list['pop_65_lb']+age_13_list['pop_70_lb']+age_13_list['pop_75_lb']+age_13_list['pop_80_lb']
age_13_list['pop_25plus_ub'] = age_13_list['pop_25_ub']+age_13_list['pop_30_ub']+age_13_list['pop_35_ub']+age_13_list['pop_40_ub']+age_13_list['pop_45_ub']+age_13_list['pop_50_ub']+age_13_list['pop_55_ub']+age_13_list['pop_60_ub']+age_13_list['pop_65_ub']+age_13_list['pop_70_ub']+age_13_list['pop_75_ub']+age_13_list['pop_80_ub']

age_13_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_13_list.csv', index=False)

# %%
age_14 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2014_Y2020M10D15.CSV')
age_14 = age_14[age_14['sex_id']==3]

age_14_25 = age_14[age_14['age_group_id'] == 14]
age_14_30 = age_14[age_14['age_group_id'] == 14]
age_14_35 = age_14[age_14['age_group_id'] == 12]
age_14_40 = age_14[age_14['age_group_id'] == 13]
age_14_45 = age_14[age_14['age_group_id'] == 14]
age_14_50 = age_14[age_14['age_group_id'] == 15]
age_14_55 = age_14[age_14['age_group_id'] == 16]
age_14_60 = age_14[age_14['age_group_id'] == 17]
age_14_65 = age_14[age_14['age_group_id'] == 18]
age_14_70 = age_14[age_14['age_group_id'] == 19]
age_14_75 = age_14[age_14['age_group_id'] == 20]
age_14_80 = age_14[age_14['age_group_id'] == 21]
age_14_all = age_14[age_14['age_group_id'] == 22]

age_14_list = age_14_all[['location_id','location_name']]
age_14_list['year'] = age_14_all['year_id']
age_14_list['pop_all'] = age_14_all['val']
age_14_list['pop_all_lb'] = age_14_all['lower']
age_14_list['pop_all_ub'] = age_14_all['upper']

age_14_list['pop_25'] = age_14_25['val'].values
age_14_list['pop_25_lb'] = age_14_25['lower'].values
age_14_list['pop_25_ub'] = age_14_25['upper'].values

age_14_list['pop_30'] = age_14_30['val'].values
age_14_list['pop_30_lb'] = age_14_30['lower'].values
age_14_list['pop_30_ub'] = age_14_30['upper'].values

age_14_list['pop_35'] = age_14_35['val'].values
age_14_list['pop_35_lb'] = age_14_35['lower'].values
age_14_list['pop_35_ub'] = age_14_35['upper'].values

age_14_list['pop_40'] = age_14_40['val'].values
age_14_list['pop_40_lb'] = age_14_40['lower'].values
age_14_list['pop_40_ub'] = age_14_40['upper'].values

age_14_list['pop_45'] = age_14_45['val'].values
age_14_list['pop_45_lb'] = age_14_45['lower'].values
age_14_list['pop_45_ub'] = age_14_45['upper'].values

age_14_list['pop_50'] = age_14_50['val'].values
age_14_list['pop_50_lb'] = age_14_50['lower'].values
age_14_list['pop_50_ub'] = age_14_50['upper'].values

age_14_list['pop_55'] = age_14_55['val'].values
age_14_list['pop_55_lb'] = age_14_55['lower'].values
age_14_list['pop_55_ub'] = age_14_55['upper'].values

age_14_list['pop_60'] = age_14_60['val'].values
age_14_list['pop_60_lb'] = age_14_60['lower'].values
age_14_list['pop_60_ub'] = age_14_60['upper'].values

age_14_list['pop_65'] = age_14_65['val'].values
age_14_list['pop_65_lb'] = age_14_65['lower'].values
age_14_list['pop_65_ub'] = age_14_65['upper'].values

age_14_list['pop_70'] = age_14_70['val'].values
age_14_list['pop_70_lb'] = age_14_70['lower'].values
age_14_list['pop_70_ub'] = age_14_70['upper'].values

age_14_list['pop_75'] = age_14_75['val'].values
age_14_list['pop_75_lb'] = age_14_75['lower'].values
age_14_list['pop_75_ub'] = age_14_75['upper'].values

age_14_list['pop_80'] = age_14_80['val'].values
age_14_list['pop_80_lb'] = age_14_80['lower'].values
age_14_list['pop_80_ub'] = age_14_80['upper'].values

age_14_list['pop_25plus'] = age_14_list['pop_25']+age_14_list['pop_30']+age_14_list['pop_35']+age_14_list['pop_40']+age_14_list['pop_45']+age_14_list['pop_50']+age_14_list['pop_55']+age_14_list['pop_60']+age_14_list['pop_65']+age_14_list['pop_70']+age_14_list['pop_75']+age_14_list['pop_80']
age_14_list['pop_25plus_lb'] = age_14_list['pop_25_lb']+age_14_list['pop_30_lb']+age_14_list['pop_35_lb']+age_14_list['pop_40_lb']+age_14_list['pop_45_lb']+age_14_list['pop_50_lb']+age_14_list['pop_55_lb']+age_14_list['pop_60_lb']+age_14_list['pop_65_lb']+age_14_list['pop_70_lb']+age_14_list['pop_75_lb']+age_14_list['pop_80_lb']
age_14_list['pop_25plus_ub'] = age_14_list['pop_25_ub']+age_14_list['pop_30_ub']+age_14_list['pop_35_ub']+age_14_list['pop_40_ub']+age_14_list['pop_45_ub']+age_14_list['pop_50_ub']+age_14_list['pop_55_ub']+age_14_list['pop_60_ub']+age_14_list['pop_65_ub']+age_14_list['pop_70_ub']+age_14_list['pop_75_ub']+age_14_list['pop_80_ub']

age_14_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_14_list.csv', index=False)

# %%
age_15 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2015_Y2020M10D15.CSV')
age_15 = age_15[age_15['sex_id']==3]

age_15_25 = age_15[age_15['age_group_id'] == 15]
age_15_30 = age_15[age_15['age_group_id'] == 15]
age_15_35 = age_15[age_15['age_group_id'] == 12]
age_15_40 = age_15[age_15['age_group_id'] == 13]
age_15_45 = age_15[age_15['age_group_id'] == 14]
age_15_50 = age_15[age_15['age_group_id'] == 15]
age_15_55 = age_15[age_15['age_group_id'] == 16]
age_15_60 = age_15[age_15['age_group_id'] == 17]
age_15_65 = age_15[age_15['age_group_id'] == 18]
age_15_70 = age_15[age_15['age_group_id'] == 19]
age_15_75 = age_15[age_15['age_group_id'] == 20]
age_15_80 = age_15[age_15['age_group_id'] == 21]
age_15_all = age_15[age_15['age_group_id'] == 22]

age_15_list = age_15_all[['location_id','location_name']]
age_15_list['year'] = age_15_all['year_id']
age_15_list['pop_all'] = age_15_all['val']
age_15_list['pop_all_lb'] = age_15_all['lower']
age_15_list['pop_all_ub'] = age_15_all['upper']

age_15_list['pop_25'] = age_15_25['val'].values
age_15_list['pop_25_lb'] = age_15_25['lower'].values
age_15_list['pop_25_ub'] = age_15_25['upper'].values

age_15_list['pop_30'] = age_15_30['val'].values
age_15_list['pop_30_lb'] = age_15_30['lower'].values
age_15_list['pop_30_ub'] = age_15_30['upper'].values

age_15_list['pop_35'] = age_15_35['val'].values
age_15_list['pop_35_lb'] = age_15_35['lower'].values
age_15_list['pop_35_ub'] = age_15_35['upper'].values

age_15_list['pop_40'] = age_15_40['val'].values
age_15_list['pop_40_lb'] = age_15_40['lower'].values
age_15_list['pop_40_ub'] = age_15_40['upper'].values

age_15_list['pop_45'] = age_15_45['val'].values
age_15_list['pop_45_lb'] = age_15_45['lower'].values
age_15_list['pop_45_ub'] = age_15_45['upper'].values

age_15_list['pop_50'] = age_15_50['val'].values
age_15_list['pop_50_lb'] = age_15_50['lower'].values
age_15_list['pop_50_ub'] = age_15_50['upper'].values

age_15_list['pop_55'] = age_15_55['val'].values
age_15_list['pop_55_lb'] = age_15_55['lower'].values
age_15_list['pop_55_ub'] = age_15_55['upper'].values

age_15_list['pop_60'] = age_15_60['val'].values
age_15_list['pop_60_lb'] = age_15_60['lower'].values
age_15_list['pop_60_ub'] = age_15_60['upper'].values

age_15_list['pop_65'] = age_15_65['val'].values
age_15_list['pop_65_lb'] = age_15_65['lower'].values
age_15_list['pop_65_ub'] = age_15_65['upper'].values

age_15_list['pop_70'] = age_15_70['val'].values
age_15_list['pop_70_lb'] = age_15_70['lower'].values
age_15_list['pop_70_ub'] = age_15_70['upper'].values

age_15_list['pop_75'] = age_15_75['val'].values
age_15_list['pop_75_lb'] = age_15_75['lower'].values
age_15_list['pop_75_ub'] = age_15_75['upper'].values

age_15_list['pop_80'] = age_15_80['val'].values
age_15_list['pop_80_lb'] = age_15_80['lower'].values
age_15_list['pop_80_ub'] = age_15_80['upper'].values

age_15_list['pop_25plus'] = age_15_list['pop_25']+age_15_list['pop_30']+age_15_list['pop_35']+age_15_list['pop_40']+age_15_list['pop_45']+age_15_list['pop_50']+age_15_list['pop_55']+age_15_list['pop_60']+age_15_list['pop_65']+age_15_list['pop_70']+age_15_list['pop_75']+age_15_list['pop_80']
age_15_list['pop_25plus_lb'] = age_15_list['pop_25_lb']+age_15_list['pop_30_lb']+age_15_list['pop_35_lb']+age_15_list['pop_40_lb']+age_15_list['pop_45_lb']+age_15_list['pop_50_lb']+age_15_list['pop_55_lb']+age_15_list['pop_60_lb']+age_15_list['pop_65_lb']+age_15_list['pop_70_lb']+age_15_list['pop_75_lb']+age_15_list['pop_80_lb']
age_15_list['pop_25plus_ub'] = age_15_list['pop_25_ub']+age_15_list['pop_30_ub']+age_15_list['pop_35_ub']+age_15_list['pop_40_ub']+age_15_list['pop_45_ub']+age_15_list['pop_50_ub']+age_15_list['pop_55_ub']+age_15_list['pop_60_ub']+age_15_list['pop_65_ub']+age_15_list['pop_70_ub']+age_15_list['pop_75_ub']+age_15_list['pop_80_ub']

age_15_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_15_list.csv', index=False)

# %%
age_16 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2016_Y2020M10D15.CSV')
age_16 = age_16[age_16['sex_id']==3]

age_16_25 = age_16[age_16['age_group_id'] == 16]
age_16_30 = age_16[age_16['age_group_id'] == 16]
age_16_35 = age_16[age_16['age_group_id'] == 12]
age_16_40 = age_16[age_16['age_group_id'] == 13]
age_16_45 = age_16[age_16['age_group_id'] == 14]
age_16_50 = age_16[age_16['age_group_id'] == 15]
age_16_55 = age_16[age_16['age_group_id'] == 16]
age_16_60 = age_16[age_16['age_group_id'] == 17]
age_16_65 = age_16[age_16['age_group_id'] == 18]
age_16_70 = age_16[age_16['age_group_id'] == 19]
age_16_75 = age_16[age_16['age_group_id'] == 20]
age_16_80 = age_16[age_16['age_group_id'] == 21]
age_16_all = age_16[age_16['age_group_id'] == 22]

age_16_list = age_16_all[['location_id','location_name']]
age_16_list['year'] = age_16_all['year_id']
age_16_list['pop_all'] = age_16_all['val']
age_16_list['pop_all_lb'] = age_16_all['lower']
age_16_list['pop_all_ub'] = age_16_all['upper']

age_16_list['pop_25'] = age_16_25['val'].values
age_16_list['pop_25_lb'] = age_16_25['lower'].values
age_16_list['pop_25_ub'] = age_16_25['upper'].values

age_16_list['pop_30'] = age_16_30['val'].values
age_16_list['pop_30_lb'] = age_16_30['lower'].values
age_16_list['pop_30_ub'] = age_16_30['upper'].values

age_16_list['pop_35'] = age_16_35['val'].values
age_16_list['pop_35_lb'] = age_16_35['lower'].values
age_16_list['pop_35_ub'] = age_16_35['upper'].values

age_16_list['pop_40'] = age_16_40['val'].values
age_16_list['pop_40_lb'] = age_16_40['lower'].values
age_16_list['pop_40_ub'] = age_16_40['upper'].values

age_16_list['pop_45'] = age_16_45['val'].values
age_16_list['pop_45_lb'] = age_16_45['lower'].values
age_16_list['pop_45_ub'] = age_16_45['upper'].values

age_16_list['pop_50'] = age_16_50['val'].values
age_16_list['pop_50_lb'] = age_16_50['lower'].values
age_16_list['pop_50_ub'] = age_16_50['upper'].values

age_16_list['pop_55'] = age_16_55['val'].values
age_16_list['pop_55_lb'] = age_16_55['lower'].values
age_16_list['pop_55_ub'] = age_16_55['upper'].values

age_16_list['pop_60'] = age_16_60['val'].values
age_16_list['pop_60_lb'] = age_16_60['lower'].values
age_16_list['pop_60_ub'] = age_16_60['upper'].values

age_16_list['pop_65'] = age_16_65['val'].values
age_16_list['pop_65_lb'] = age_16_65['lower'].values
age_16_list['pop_65_ub'] = age_16_65['upper'].values

age_16_list['pop_70'] = age_16_70['val'].values
age_16_list['pop_70_lb'] = age_16_70['lower'].values
age_16_list['pop_70_ub'] = age_16_70['upper'].values

age_16_list['pop_75'] = age_16_75['val'].values
age_16_list['pop_75_lb'] = age_16_75['lower'].values
age_16_list['pop_75_ub'] = age_16_75['upper'].values

age_16_list['pop_80'] = age_16_80['val'].values
age_16_list['pop_80_lb'] = age_16_80['lower'].values
age_16_list['pop_80_ub'] = age_16_80['upper'].values

age_16_list['pop_25plus'] = age_16_list['pop_25']+age_16_list['pop_30']+age_16_list['pop_35']+age_16_list['pop_40']+age_16_list['pop_45']+age_16_list['pop_50']+age_16_list['pop_55']+age_16_list['pop_60']+age_16_list['pop_65']+age_16_list['pop_70']+age_16_list['pop_75']+age_16_list['pop_80']
age_16_list['pop_25plus_lb'] = age_16_list['pop_25_lb']+age_16_list['pop_30_lb']+age_16_list['pop_35_lb']+age_16_list['pop_40_lb']+age_16_list['pop_45_lb']+age_16_list['pop_50_lb']+age_16_list['pop_55_lb']+age_16_list['pop_60_lb']+age_16_list['pop_65_lb']+age_16_list['pop_70_lb']+age_16_list['pop_75_lb']+age_16_list['pop_80_lb']
age_16_list['pop_25plus_ub'] = age_16_list['pop_25_ub']+age_16_list['pop_30_ub']+age_16_list['pop_35_ub']+age_16_list['pop_40_ub']+age_16_list['pop_45_ub']+age_16_list['pop_50_ub']+age_16_list['pop_55_ub']+age_16_list['pop_60_ub']+age_16_list['pop_65_ub']+age_16_list['pop_70_ub']+age_16_list['pop_75_ub']+age_16_list['pop_80_ub']

age_16_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_16_list.csv', index=False)

# %%
age_17 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2017_Y2020M10D15.CSV')
age_17 = age_17[age_17['sex_id']==3]

age_17_25 = age_17[age_17['age_group_id'] == 17]
age_17_30 = age_17[age_17['age_group_id'] == 17]
age_17_35 = age_17[age_17['age_group_id'] == 12]
age_17_40 = age_17[age_17['age_group_id'] == 13]
age_17_45 = age_17[age_17['age_group_id'] == 14]
age_17_50 = age_17[age_17['age_group_id'] == 15]
age_17_55 = age_17[age_17['age_group_id'] == 16]
age_17_60 = age_17[age_17['age_group_id'] == 17]
age_17_65 = age_17[age_17['age_group_id'] == 18]
age_17_70 = age_17[age_17['age_group_id'] == 19]
age_17_75 = age_17[age_17['age_group_id'] == 20]
age_17_80 = age_17[age_17['age_group_id'] == 21]
age_17_all = age_17[age_17['age_group_id'] == 22]

age_17_list = age_17_all[['location_id','location_name']]
age_17_list['year'] = age_17_all['year_id']
age_17_list['pop_all'] = age_17_all['val']
age_17_list['pop_all_lb'] = age_17_all['lower']
age_17_list['pop_all_ub'] = age_17_all['upper']

age_17_list['pop_25'] = age_17_25['val'].values
age_17_list['pop_25_lb'] = age_17_25['lower'].values
age_17_list['pop_25_ub'] = age_17_25['upper'].values

age_17_list['pop_30'] = age_17_30['val'].values
age_17_list['pop_30_lb'] = age_17_30['lower'].values
age_17_list['pop_30_ub'] = age_17_30['upper'].values

age_17_list['pop_35'] = age_17_35['val'].values
age_17_list['pop_35_lb'] = age_17_35['lower'].values
age_17_list['pop_35_ub'] = age_17_35['upper'].values

age_17_list['pop_40'] = age_17_40['val'].values
age_17_list['pop_40_lb'] = age_17_40['lower'].values
age_17_list['pop_40_ub'] = age_17_40['upper'].values

age_17_list['pop_45'] = age_17_45['val'].values
age_17_list['pop_45_lb'] = age_17_45['lower'].values
age_17_list['pop_45_ub'] = age_17_45['upper'].values

age_17_list['pop_50'] = age_17_50['val'].values
age_17_list['pop_50_lb'] = age_17_50['lower'].values
age_17_list['pop_50_ub'] = age_17_50['upper'].values

age_17_list['pop_55'] = age_17_55['val'].values
age_17_list['pop_55_lb'] = age_17_55['lower'].values
age_17_list['pop_55_ub'] = age_17_55['upper'].values

age_17_list['pop_60'] = age_17_60['val'].values
age_17_list['pop_60_lb'] = age_17_60['lower'].values
age_17_list['pop_60_ub'] = age_17_60['upper'].values

age_17_list['pop_65'] = age_17_65['val'].values
age_17_list['pop_65_lb'] = age_17_65['lower'].values
age_17_list['pop_65_ub'] = age_17_65['upper'].values

age_17_list['pop_70'] = age_17_70['val'].values
age_17_list['pop_70_lb'] = age_17_70['lower'].values
age_17_list['pop_70_ub'] = age_17_70['upper'].values

age_17_list['pop_75'] = age_17_75['val'].values
age_17_list['pop_75_lb'] = age_17_75['lower'].values
age_17_list['pop_75_ub'] = age_17_75['upper'].values

age_17_list['pop_80'] = age_17_80['val'].values
age_17_list['pop_80_lb'] = age_17_80['lower'].values
age_17_list['pop_80_ub'] = age_17_80['upper'].values

age_17_list['pop_25plus'] = age_17_list['pop_25']+age_17_list['pop_30']+age_17_list['pop_35']+age_17_list['pop_40']+age_17_list['pop_45']+age_17_list['pop_50']+age_17_list['pop_55']+age_17_list['pop_60']+age_17_list['pop_65']+age_17_list['pop_70']+age_17_list['pop_75']+age_17_list['pop_80']
age_17_list['pop_25plus_lb'] = age_17_list['pop_25_lb']+age_17_list['pop_30_lb']+age_17_list['pop_35_lb']+age_17_list['pop_40_lb']+age_17_list['pop_45_lb']+age_17_list['pop_50_lb']+age_17_list['pop_55_lb']+age_17_list['pop_60_lb']+age_17_list['pop_65_lb']+age_17_list['pop_70_lb']+age_17_list['pop_75_lb']+age_17_list['pop_80_lb']
age_17_list['pop_25plus_ub'] = age_17_list['pop_25_ub']+age_17_list['pop_30_ub']+age_17_list['pop_35_ub']+age_17_list['pop_40_ub']+age_17_list['pop_45_ub']+age_17_list['pop_50_ub']+age_17_list['pop_55_ub']+age_17_list['pop_60_ub']+age_17_list['pop_65_ub']+age_17_list['pop_70_ub']+age_17_list['pop_75_ub']+age_17_list['pop_80_ub']

age_17_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_17_list.csv', index=False)

# %%
age_18 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2018_Y2020M10D15.CSV')
age_18 = age_18[age_18['sex_id']==3]

age_18_25 = age_18[age_18['age_group_id'] == 18]
age_18_30 = age_18[age_18['age_group_id'] == 18]
age_18_35 = age_18[age_18['age_group_id'] == 12]
age_18_40 = age_18[age_18['age_group_id'] == 13]
age_18_45 = age_18[age_18['age_group_id'] == 14]
age_18_50 = age_18[age_18['age_group_id'] == 15]
age_18_55 = age_18[age_18['age_group_id'] == 16]
age_18_60 = age_18[age_18['age_group_id'] == 17]
age_18_65 = age_18[age_18['age_group_id'] == 18]
age_18_70 = age_18[age_18['age_group_id'] == 19]
age_18_75 = age_18[age_18['age_group_id'] == 20]
age_18_80 = age_18[age_18['age_group_id'] == 21]
age_18_all = age_18[age_18['age_group_id'] == 22]

age_18_list = age_18_all[['location_id','location_name']]
age_18_list['year'] = age_18_all['year_id']
age_18_list['pop_all'] = age_18_all['val']
age_18_list['pop_all_lb'] = age_18_all['lower']
age_18_list['pop_all_ub'] = age_18_all['upper']

age_18_list['pop_25'] = age_18_25['val'].values
age_18_list['pop_25_lb'] = age_18_25['lower'].values
age_18_list['pop_25_ub'] = age_18_25['upper'].values

age_18_list['pop_30'] = age_18_30['val'].values
age_18_list['pop_30_lb'] = age_18_30['lower'].values
age_18_list['pop_30_ub'] = age_18_30['upper'].values

age_18_list['pop_35'] = age_18_35['val'].values
age_18_list['pop_35_lb'] = age_18_35['lower'].values
age_18_list['pop_35_ub'] = age_18_35['upper'].values

age_18_list['pop_40'] = age_18_40['val'].values
age_18_list['pop_40_lb'] = age_18_40['lower'].values
age_18_list['pop_40_ub'] = age_18_40['upper'].values

age_18_list['pop_45'] = age_18_45['val'].values
age_18_list['pop_45_lb'] = age_18_45['lower'].values
age_18_list['pop_45_ub'] = age_18_45['upper'].values

age_18_list['pop_50'] = age_18_50['val'].values
age_18_list['pop_50_lb'] = age_18_50['lower'].values
age_18_list['pop_50_ub'] = age_18_50['upper'].values

age_18_list['pop_55'] = age_18_55['val'].values
age_18_list['pop_55_lb'] = age_18_55['lower'].values
age_18_list['pop_55_ub'] = age_18_55['upper'].values

age_18_list['pop_60'] = age_18_60['val'].values
age_18_list['pop_60_lb'] = age_18_60['lower'].values
age_18_list['pop_60_ub'] = age_18_60['upper'].values

age_18_list['pop_65'] = age_18_65['val'].values
age_18_list['pop_65_lb'] = age_18_65['lower'].values
age_18_list['pop_65_ub'] = age_18_65['upper'].values

age_18_list['pop_70'] = age_18_70['val'].values
age_18_list['pop_70_lb'] = age_18_70['lower'].values
age_18_list['pop_70_ub'] = age_18_70['upper'].values

age_18_list['pop_75'] = age_18_75['val'].values
age_18_list['pop_75_lb'] = age_18_75['lower'].values
age_18_list['pop_75_ub'] = age_18_75['upper'].values

age_18_list['pop_80'] = age_18_80['val'].values
age_18_list['pop_80_lb'] = age_18_80['lower'].values
age_18_list['pop_80_ub'] = age_18_80['upper'].values

age_18_list['pop_25plus'] = age_18_list['pop_25']+age_18_list['pop_30']+age_18_list['pop_35']+age_18_list['pop_40']+age_18_list['pop_45']+age_18_list['pop_50']+age_18_list['pop_55']+age_18_list['pop_60']+age_18_list['pop_65']+age_18_list['pop_70']+age_18_list['pop_75']+age_18_list['pop_80']
age_18_list['pop_25plus_lb'] = age_18_list['pop_25_lb']+age_18_list['pop_30_lb']+age_18_list['pop_35_lb']+age_18_list['pop_40_lb']+age_18_list['pop_45_lb']+age_18_list['pop_50_lb']+age_18_list['pop_55_lb']+age_18_list['pop_60_lb']+age_18_list['pop_65_lb']+age_18_list['pop_70_lb']+age_18_list['pop_75_lb']+age_18_list['pop_80_lb']
age_18_list['pop_25plus_ub'] = age_18_list['pop_25_ub']+age_18_list['pop_30_ub']+age_18_list['pop_35_ub']+age_18_list['pop_40_ub']+age_18_list['pop_45_ub']+age_18_list['pop_50_ub']+age_18_list['pop_55_ub']+age_18_list['pop_60_ub']+age_18_list['pop_65_ub']+age_18_list['pop_70_ub']+age_18_list['pop_75_ub']+age_18_list['pop_80_ub']

age_18_list['pop_25plus'] = age_18_list['pop_25']+age_18_list['pop_30']+age_18_list['pop_35']+age_18_list['pop_40']+age_18_list['pop_45']+age_18_list['pop_50']+age_18_list['pop_55']+age_18_list['pop_60']+age_18_list['pop_65']+age_18_list['pop_70']+age_18_list['pop_75']+age_18_list['pop_80']
age_18_list['pop_25plus_lb'] = age_18_list['pop_25_lb']+age_18_list['pop_30_lb']+age_18_list['pop_35_lb']+age_18_list['pop_40_lb']+age_18_list['pop_45_lb']+age_18_list['pop_50_lb']+age_18_list['pop_55_lb']+age_18_list['pop_60_lb']+age_18_list['pop_65_lb']+age_18_list['pop_70_lb']+age_18_list['pop_75_lb']+age_18_list['pop_80_lb']
age_18_list['pop_25plus_ub'] = age_18_list['pop_25_ub']+age_18_list['pop_30_ub']+age_18_list['pop_35_ub']+age_18_list['pop_40_ub']+age_18_list['pop_45_ub']+age_18_list['pop_50_ub']+age_18_list['pop_55_ub']+age_18_list['pop_60_ub']+age_18_list['pop_65_ub']+age_18_list['pop_70_ub']+age_18_list['pop_75_ub']+age_18_list['pop_80_ub']

age_18_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_18_list.csv', index=False)

# %%
age_19 = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME_GBD_2019_POP_2010_2019_0/IHME_GBD_2019_POP_2019_Y2020M10D15.CSV')
age_19 = age_19[age_19['sex_id']==3]

age_19_25 = age_19[age_19['age_group_id'] == 19]
age_19_30 = age_19[age_19['age_group_id'] == 19]
age_19_35 = age_19[age_19['age_group_id'] == 12]
age_19_40 = age_19[age_19['age_group_id'] == 13]
age_19_45 = age_19[age_19['age_group_id'] == 14]
age_19_50 = age_19[age_19['age_group_id'] == 15]
age_19_55 = age_19[age_19['age_group_id'] == 16]
age_19_60 = age_19[age_19['age_group_id'] == 17]
age_19_65 = age_19[age_19['age_group_id'] == 18]
age_19_70 = age_19[age_19['age_group_id'] == 19]
age_19_75 = age_19[age_19['age_group_id'] == 20]
age_19_80 = age_19[age_19['age_group_id'] == 21]
age_19_all = age_19[age_19['age_group_id'] == 22]

age_19_list = age_19_all[['location_id','location_name']]
age_19_list['year'] = age_19_all['year_id']
age_19_list['pop_all'] = age_19_all['val']
age_19_list['pop_all_lb'] = age_19_all['lower']
age_19_list['pop_all_ub'] = age_19_all['upper']

age_19_list['pop_25'] = age_19_25['val'].values
age_19_list['pop_25_lb'] = age_19_25['lower'].values
age_19_list['pop_25_ub'] = age_19_25['upper'].values

age_19_list['pop_30'] = age_19_30['val'].values
age_19_list['pop_30_lb'] = age_19_30['lower'].values
age_19_list['pop_30_ub'] = age_19_30['upper'].values

age_19_list['pop_35'] = age_19_35['val'].values
age_19_list['pop_35_lb'] = age_19_35['lower'].values
age_19_list['pop_35_ub'] = age_19_35['upper'].values

age_19_list['pop_40'] = age_19_40['val'].values
age_19_list['pop_40_lb'] = age_19_40['lower'].values
age_19_list['pop_40_ub'] = age_19_40['upper'].values

age_19_list['pop_45'] = age_19_45['val'].values
age_19_list['pop_45_lb'] = age_19_45['lower'].values
age_19_list['pop_45_ub'] = age_19_45['upper'].values

age_19_list['pop_50'] = age_19_50['val'].values
age_19_list['pop_50_lb'] = age_19_50['lower'].values
age_19_list['pop_50_ub'] = age_19_50['upper'].values

age_19_list['pop_55'] = age_19_55['val'].values
age_19_list['pop_55_lb'] = age_19_55['lower'].values
age_19_list['pop_55_ub'] = age_19_55['upper'].values

age_19_list['pop_60'] = age_19_60['val'].values
age_19_list['pop_60_lb'] = age_19_60['lower'].values
age_19_list['pop_60_ub'] = age_19_60['upper'].values

age_19_list['pop_65'] = age_19_65['val'].values
age_19_list['pop_65_lb'] = age_19_65['lower'].values
age_19_list['pop_65_ub'] = age_19_65['upper'].values

age_19_list['pop_70'] = age_19_70['val'].values
age_19_list['pop_70_lb'] = age_19_70['lower'].values
age_19_list['pop_70_ub'] = age_19_70['upper'].values

age_19_list['pop_75'] = age_19_75['val'].values
age_19_list['pop_75_lb'] = age_19_75['lower'].values
age_19_list['pop_75_ub'] = age_19_75['upper'].values

age_19_list['pop_80'] = age_19_80['val'].values
age_19_list['pop_80_lb'] = age_19_80['lower'].values
age_19_list['pop_80_ub'] = age_19_80['upper'].values

age_19_list['pop_25plus'] = age_19_list['pop_25']+age_19_list['pop_30']+age_19_list['pop_35']+age_19_list['pop_40']+age_19_list['pop_45']+age_19_list['pop_50']+age_19_list['pop_55']+age_19_list['pop_60']+age_19_list['pop_65']+age_19_list['pop_70']+age_19_list['pop_75']+age_19_list['pop_80']
age_19_list['pop_25plus_lb'] = age_19_list['pop_25_lb']+age_19_list['pop_30_lb']+age_19_list['pop_35_lb']+age_19_list['pop_40_lb']+age_19_list['pop_45_lb']+age_19_list['pop_50_lb']+age_19_list['pop_55_lb']+age_19_list['pop_60_lb']+age_19_list['pop_65_lb']+age_19_list['pop_70_lb']+age_19_list['pop_75_lb']+age_19_list['pop_80_lb']
age_19_list['pop_25plus_ub'] = age_19_list['pop_25_ub']+age_19_list['pop_30_ub']+age_19_list['pop_35_ub']+age_19_list['pop_40_ub']+age_19_list['pop_45_ub']+age_19_list['pop_50_ub']+age_19_list['pop_55_ub']+age_19_list['pop_60_ub']+age_19_list['pop_65_ub']+age_19_list['pop_70_ub']+age_19_list['pop_75_ub']+age_19_list['pop_80_ub']

age_19_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/age_19_list.csv', index=False)

# %%
age_19_list
# Out:
#        location_id                           location_name  year  \
# 97               1                                  Global  2019
# 211              4  Southeast Asia, East Asia, and Oceania  2019
# 325              5                               East Asia  2019
# 439              6                                   China  2019
# 553              7   Democratic People's Republic of Korea  2019
# ...            ...                                     ...   ...
# 76375        44788                                  Torbay  2019
# 76489        44789                        Bristol, City of  2019
# 76603        44790                             Bournemouth  2019
# 76717        44791                                Cornwall  2019
# 76831        44792                                Plymouth  2019
#
#             pop_all    pop_all_lb    pop_all_ub        pop_25     pop_25_lb  \
# 97     7.737465e+09  7.482640e+09  7.992502e+09  1.870871e+08  1.801846e+08
# ...
