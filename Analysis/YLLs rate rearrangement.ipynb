# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/IHME-GBD_2019_DATA-5b8483fa-1/IHME-GBD_2019_DATA-5b8483fa-1.csv')

# %%
list(data)
# Out:
# ['measure_id',
#  'measure_name',
#  'location_id',
#  'location_name',
#  'sex_id',
#  'sex_name',
#  'age_id',
#  'age_name',
#  'cause_id',
#  'cause_name',
#  'metric_id',
#  'metric_name',
#  'year',
#  'val',
#  'upper',
#  'lower']

# %%
data = data[['location_id','location_name','age_id','age_name','year','val','upper','lower']]

# %%
ylls_90 = data[data['year'] == 1990]

ylls_90_25 = ylls_90[ylls_90['age_id'] == 10]
ylls_90_30 = ylls_90[ylls_90['age_id'] == 11]
ylls_90_35 = ylls_90[ylls_90['age_id'] == 12]
ylls_90_40 = ylls_90[ylls_90['age_id'] == 13]
ylls_90_45 = ylls_90[ylls_90['age_id'] == 14]
ylls_90_50 = ylls_90[ylls_90['age_id'] == 15]
ylls_90_55 = ylls_90[ylls_90['age_id'] == 16]
ylls_90_60 = ylls_90[ylls_90['age_id'] == 17]
ylls_90_65 = ylls_90[ylls_90['age_id'] == 18]
ylls_90_70 = ylls_90[ylls_90['age_id'] == 19]
ylls_90_75 = ylls_90[ylls_90['age_id'] == 20]
ylls_90_80 = ylls_90[ylls_90['age_id'] == 21]

ylls_90_25plus = ylls_90[ylls_90['age_id'] == 157]

ylls_90_list = ylls_90_25plus[['location_id','location_name']]
ylls_90_list['year'] = ylls_90_25plus['year']
ylls_90_list['ylls_25plus'] = ylls_90_25plus['val']
ylls_90_list['ylls_25plus_lb'] = ylls_90_25plus['lower']
ylls_90_list['ylls_25plus_ub'] = ylls_90_25plus['upper']

ylls_90_list['ylls_25'] = ylls_90_25['val'].values
ylls_90_list['ylls_25_lb'] = ylls_90_25['lower'].values
ylls_90_list['ylls_25_ub'] = ylls_90_25['upper'].values

ylls_90_list['ylls_30'] = ylls_90_30['val'].values
ylls_90_list['ylls_30_lb'] = ylls_90_30['lower'].values
ylls_90_list['ylls_30_ub'] = ylls_90_30['upper'].values

ylls_90_list['ylls_35'] = ylls_90_35['val'].values
ylls_90_list['ylls_35_lb'] = ylls_90_35['lower'].values
ylls_90_list['ylls_35_ub'] = ylls_90_35['upper'].values

ylls_90_list['ylls_40'] = ylls_90_40['val'].values
ylls_90_list['ylls_40_lb'] = ylls_90_40['lower'].values
ylls_90_list['ylls_40_ub'] = ylls_90_40['upper'].values

ylls_90_list['ylls_45'] = ylls_90_45['val'].values
ylls_90_list['ylls_45_lb'] = ylls_90_45['lower'].values
ylls_90_list['ylls_45_ub'] = ylls_90_45['upper'].values

ylls_90_list['ylls_50'] = ylls_90_50['val'].values
ylls_90_list['ylls_50_lb'] = ylls_90_50['lower'].values
ylls_90_list['ylls_50_ub'] = ylls_90_50['upper'].values

ylls_90_list['ylls_55'] = ylls_90_55['val'].values
ylls_90_list['ylls_55_lb'] = ylls_90_55['lower'].values
ylls_90_list['ylls_55_ub'] = ylls_90_55['upper'].values

ylls_90_list['ylls_60'] = ylls_90_60['val'].values
ylls_90_list['ylls_60_lb'] = ylls_90_60['lower'].values
ylls_90_list['ylls_60_ub'] = ylls_90_60['upper'].values

ylls_90_list['ylls_65'] = ylls_90_65['val'].values
ylls_90_list['ylls_65_lb'] = ylls_90_65['lower'].values
ylls_90_list['ylls_65_ub'] = ylls_90_65['upper'].values

ylls_90_list['ylls_70'] = ylls_90_70['val'].values
ylls_90_list['ylls_70_lb'] = ylls_90_70['lower'].values
ylls_90_list['ylls_70_ub'] = ylls_90_70['upper'].values

ylls_90_list['ylls_75'] = ylls_90_75['val'].values
ylls_90_list['ylls_75_lb'] = ylls_90_75['lower'].values
ylls_90_list['ylls_75_ub'] = ylls_90_75['upper'].values

ylls_90_list['ylls_80'] = ylls_90_80['val'].values
ylls_90_list['ylls_80_lb'] = ylls_90_80['lower'].values
ylls_90_list['ylls_80_ub'] = ylls_90_80['upper'].values

ylls_90_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/YLLs list/YLLs_90_list.csv', index=False)

# %%
ylls_19 = data[data['year'] == 2019]

ylls_19_25 = ylls_19[ylls_19['age_id'] == 10]
ylls_19_30 = ylls_19[ylls_19['age_id'] == 11]
ylls_19_35 = ylls_19[ylls_19['age_id'] == 12]
ylls_19_40 = ylls_19[ylls_19['age_id'] == 13]
ylls_19_45 = ylls_19[ylls_19['age_id'] == 14]
ylls_19_50 = ylls_19[ylls_19['age_id'] == 15]
ylls_19_55 = ylls_19[ylls_19['age_id'] == 16]
ylls_19_60 = ylls_19[ylls_19['age_id'] == 17]
ylls_19_65 = ylls_19[ylls_19['age_id'] == 18]
ylls_19_70 = ylls_19[ylls_19['age_id'] == 19]
ylls_19_75 = ylls_19[ylls_19['age_id'] == 20]
ylls_19_80 = ylls_19[ylls_19['age_id'] == 21]

ylls_19_25plus = ylls_19[ylls_19['age_id'] == 157]

ylls_19_list = ylls_19_25plus[['location_id','location_name']]
ylls_19_list['year'] = ylls_19_25plus['year']
ylls_19_list['ylls_25plus'] = ylls_19_25plus['val']
ylls_19_list['ylls_25plus_lb'] = ylls_19_25plus['lower']
ylls_19_list['ylls_25plus_ub'] = ylls_19_25plus['upper']

ylls_19_list['ylls_25'] = ylls_19_25['val'].values
ylls_19_list['ylls_25_lb'] = ylls_19_25['lower'].values
ylls_19_list['ylls_25_ub'] = ylls_19_25['upper'].values

ylls_19_list['ylls_30'] = ylls_19_30['val'].values
ylls_19_list['ylls_30_lb'] = ylls_19_30['lower'].values
ylls_19_list['ylls_30_ub'] = ylls_19_30['upper'].values

ylls_19_list['ylls_35'] = ylls_19_35['val'].values
ylls_19_list['ylls_35_lb'] = ylls_19_35['lower'].values
ylls_19_list['ylls_35_ub'] = ylls_19_35['upper'].values

ylls_19_list['ylls_40'] = ylls_19_40['val'].values
ylls_19_list['ylls_40_lb'] = ylls_19_40['lower'].values
ylls_19_list['ylls_40_ub'] = ylls_19_40['upper'].values

ylls_19_list['ylls_45'] = ylls_19_45['val'].values
ylls_19_list['ylls_45_lb'] = ylls_19_45['lower'].values
ylls_19_list['ylls_45_ub'] = ylls_19_45['upper'].values

ylls_19_list['ylls_50'] = ylls_19_50['val'].values
ylls_19_list['ylls_50_lb'] = ylls_19_50['lower'].values
ylls_19_list['ylls_50_ub'] = ylls_19_50['upper'].values

ylls_19_list['ylls_55'] = ylls_19_55['val'].values
ylls_19_list['ylls_55_lb'] = ylls_19_55['lower'].values
ylls_19_list['ylls_55_ub'] = ylls_19_55['upper'].values

ylls_19_list['ylls_60'] = ylls_19_60['val'].values
ylls_19_list['ylls_60_lb'] = ylls_19_60['lower'].values
ylls_19_list['ylls_60_ub'] = ylls_19_60['upper'].values

ylls_19_list['ylls_65'] = ylls_19_65['val'].values
ylls_19_list['ylls_65_lb'] = ylls_19_65['lower'].values
ylls_19_list['ylls_65_ub'] = ylls_19_65['upper'].values

ylls_19_list['ylls_70'] = ylls_19_70['val'].values
ylls_19_list['ylls_70_lb'] = ylls_19_70['lower'].values
ylls_19_list['ylls_70_ub'] = ylls_19_70['upper'].values

ylls_19_list['ylls_75'] = ylls_19_75['val'].values
ylls_19_list['ylls_75_lb'] = ylls_19_75['lower'].values
ylls_19_list['ylls_75_ub'] = ylls_19_75['upper'].values

ylls_19_list['ylls_80'] = ylls_19_80['val'].values
ylls_19_list['ylls_80_lb'] = ylls_19_80['lower'].values
ylls_19_list['ylls_80_ub'] = ylls_19_80['upper'].values

ylls_19_list.to_csv('/Users/csuen/Desktop/Sun-NCR-23/Analysis/YLLs list/YLLs_19_list.csv', index=False)
