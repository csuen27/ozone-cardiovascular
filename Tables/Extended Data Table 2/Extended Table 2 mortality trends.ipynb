# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data_90 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1990(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_90 = data_90.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_90.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_90_M49C.csv')

deaths_M49R = data_90.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_90_M49R.csv')

omr_M49C = data_90.groupby(['M49C']).sum()[['population_urban_90','population_rural_90',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_90']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_90']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_90']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_90']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_90']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_90']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_90_M49C.csv')

omr_M49R = data_90.groupby(['M49R']).sum()[['population_urban_90','population_rural_90',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_90']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_90']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_90']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_90']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_90']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_90']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_90_M49R.csv')

# %%
data_91 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1991(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_91 = data_91.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_91.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_91_M49C.csv')

deaths_M49R = data_91.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_91_M49R.csv')

omr_M49C = data_91.groupby(['M49C']).sum()[['population_urban_91','population_rural_91',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_91']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_91']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_91']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_91']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_91']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_91']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_91_M49C.csv')

omr_M49R = data_91.groupby(['M49R']).sum()[['population_urban_91','population_rural_91',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_91']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_91']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_91']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_91']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_91']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_91']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_91_M49R.csv')

# %%
data_92 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1992(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_92 = data_92.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_92.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_92_M49C.csv')

deaths_M49R = data_92.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_92_M49R.csv')

omr_M49C = data_92.groupby(['M49C']).sum()[['population_urban_92','population_rural_92',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_92']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_92']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_92']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_92']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_92']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_92']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_92_M49C.csv')

omr_M49R = data_92.groupby(['M49R']).sum()[['population_urban_92','population_rural_92',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_92']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_92']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_92']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_92']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_92']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_92']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_92_M49R.csv')

# %%
data_93 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1993(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_93 = data_93.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_93.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_93_M49C.csv')

deaths_M49R = data_93.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_93_M49R.csv')

omr_M49C = data_93.groupby(['M49C']).sum()[['population_urban_93','population_rural_93',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_93']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_93']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_93']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_93']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_93']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_93']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_93_M49C.csv')

omr_M49R = data_93.groupby(['M49R']).sum()[['population_urban_93','population_rural_93',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_93']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_93']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_93']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_93']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_93']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_93']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_93_M49R.csv')

# %%
data_94 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1994(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_94 = data_94.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_94.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_94_M49C.csv')

deaths_M49R = data_94.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_94_M49R.csv')

omr_M49C = data_94.groupby(['M49C']).sum()[['population_urban_94','population_rural_94',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_94']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_94']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_94']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_94']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_94']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_94']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_94_M49C.csv')

omr_M49R = data_94.groupby(['M49R']).sum()[['population_urban_94','population_rural_94',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_94']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_94']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_94']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_94']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_94']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_94']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_94_M49R.csv')

# %%
data_95 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1995(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_95 = data_95.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_95.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_95_M49C.csv')

deaths_M49R = data_95.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_95_M49R.csv')

omr_M49C = data_95.groupby(['M49C']).sum()[['population_urban_95','population_rural_95',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_95']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_95']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_95']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_95']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_95']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_95']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_95_M49C.csv')

omr_M49R = data_95.groupby(['M49R']).sum()[['population_urban_95','population_rural_95',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_95']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_95']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_95']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_95']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_95']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_95']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_95_M49R.csv')

# %%
data_96 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1996(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_96 = data_96.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_96.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_96_M49C.csv')

deaths_M49R = data_96.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_96_M49R.csv')

omr_M49C = data_96.groupby(['M49C']).sum()[['population_urban_96','population_rural_96',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_96']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_96']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_96']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_96']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_96']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_96']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_96_M49C.csv')

omr_M49R = data_96.groupby(['M49R']).sum()[['population_urban_96','population_rural_96',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_96']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_96']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_96']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_96']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_96']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_96']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_96_M49R.csv')

# %%
data_97 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1997(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_97 = data_97.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_97.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_97_M49C.csv')

deaths_M49R = data_97.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_97_M49R.csv')

omr_M49C = data_97.groupby(['M49C']).sum()[['population_urban_97','population_rural_97',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_97']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_97']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_97']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_97']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_97']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_97']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_97_M49C.csv')

omr_M49R = data_97.groupby(['M49R']).sum()[['population_urban_97','population_rural_97',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_97']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_97']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_97']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_97']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_97']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_97']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_97_M49R.csv')

# %%
data_98 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1998(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_98 = data_98.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_98.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_98_M49C.csv')

deaths_M49R = data_98.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_98_M49R.csv')

omr_M49C = data_98.groupby(['M49C']).sum()[['population_urban_98','population_rural_98',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_98']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_98']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_98']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_98']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_98']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_98']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_98_M49C.csv')

omr_M49R = data_98.groupby(['M49R']).sum()[['population_urban_98','population_rural_98',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_98']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_98']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_98']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_98']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_98']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_98']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_98_M49R.csv')

# %%
data_99 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-1999(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_99 = data_99.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_99.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_99_M49C.csv')

deaths_M49R = data_99.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_99_M49R.csv')

omr_M49C = data_99.groupby(['M49C']).sum()[['population_urban_99','population_rural_99',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_99']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_99']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_99']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_99']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_99']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_99']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_99_M49C.csv')

omr_M49R = data_99.groupby(['M49R']).sum()[['population_urban_99','population_rural_99',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_99']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_99']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_99']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_99']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_99']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_99']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_99_M49R.csv')

# %%
data_00 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2000(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_00 = data_00.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_00.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_00_M49C.csv')

deaths_M49R = data_00.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_00_M49R.csv')

omr_M49C = data_00.groupby(['M49C']).sum()[['population_urban_00','population_rural_00',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_00']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_00']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_00']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_00']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_00']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_00']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_00_M49C.csv')

omr_M49R = data_00.groupby(['M49R']).sum()[['population_urban_00','population_rural_00',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_00']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_00']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_00']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_00']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_00']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_00']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_00_M49R.csv')

# %%
data_01 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2001(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_01 = data_01.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_01.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_01_M49C.csv')

deaths_M49R = data_01.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_01_M49R.csv')

omr_M49C = data_01.groupby(['M49C']).sum()[['population_urban_01','population_rural_01',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_01']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_01']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_01']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_01']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_01']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_01']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_01_M49C.csv')

omr_M49R = data_01.groupby(['M49R']).sum()[['population_urban_01','population_rural_01',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_01']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_01']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_01']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_01']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_01']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_01']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_01_M49R.csv')

# %%
data_02 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2002(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_02 = data_02.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_02.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_02_M49C.csv')

deaths_M49R = data_02.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_02_M49R.csv')

omr_M49C = data_02.groupby(['M49C']).sum()[['population_urban_02','population_rural_02',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_02']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_02']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_02']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_02']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_02']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_02']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_02_M49C.csv')

omr_M49R = data_02.groupby(['M49R']).sum()[['population_urban_02','population_rural_02',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_02']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_02']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_02']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_02']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_02']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_02']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_02_M49R.csv')

# %%
data_03 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2003(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_03 = data_03.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_03.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_03_M49C.csv')

deaths_M49R = data_03.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_03_M49R.csv')

omr_M49C = data_03.groupby(['M49C']).sum()[['population_urban_03','population_rural_03',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_03']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_03']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_03']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_03']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_03']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_03']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_03_M49C.csv')

omr_M49R = data_03.groupby(['M49R']).sum()[['population_urban_03','population_rural_03',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_03']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_03']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_03']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_03']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_03']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_03']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_03_M49R.csv')

# %%
data_04 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2004(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_04 = data_04.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_04.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_04_M49C.csv')

deaths_M49R = data_04.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_04_M49R.csv')

omr_M49C = data_04.groupby(['M49C']).sum()[['population_urban_04','population_rural_04',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_04']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_04']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_04']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_04']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_04']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_04']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_04_M49C.csv')

omr_M49R = data_04.groupby(['M49R']).sum()[['population_urban_04','population_rural_04',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_04']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_04']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_04']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_04']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_04']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_04']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_04_M49R.csv')

# %%
data_05 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2005(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_05 = data_05.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_05.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_05_M49C.csv')

deaths_M49R = data_05.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_05_M49R.csv')

omr_M49C = data_05.groupby(['M49C']).sum()[['population_urban_05','population_rural_05',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_05']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_05']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_05']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_05']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_05']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_05']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_05_M49C.csv')

omr_M49R = data_05.groupby(['M49R']).sum()[['population_urban_05','population_rural_05',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_05']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_05']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_05']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_05']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_05']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_05']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_05_M49R.csv')

# %%
data_06 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2006(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_06 = data_06.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_06.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_06_M49C.csv')

deaths_M49R = data_06.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_06_M49R.csv')

omr_M49C = data_06.groupby(['M49C']).sum()[['population_urban_06','population_rural_06',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_06']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_06']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_06']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_06']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_06']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_06']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_06_M49C.csv')

omr_M49R = data_06.groupby(['M49R']).sum()[['population_urban_06','population_rural_06',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_06']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_06']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_06']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_06']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_06']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_06']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_06_M49R.csv')

# %%
data_07 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2007(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_07 = data_07.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_07.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_07_M49C.csv')

deaths_M49R = data_07.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_07_M49R.csv')

omr_M49C = data_07.groupby(['M49C']).sum()[['population_urban_07','population_rural_07',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_07']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_07']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_07']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_07']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_07']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_07']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_07_M49C.csv')

omr_M49R = data_07.groupby(['M49R']).sum()[['population_urban_07','population_rural_07',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_07']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_07']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_07']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_07']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_07']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_07']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_07_M49R.csv')

# %%
data_08 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2008(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_08 = data_08.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_08.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_08_M49C.csv')

deaths_M49R = data_08.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_08_M49R.csv')

omr_M49C = data_08.groupby(['M49C']).sum()[['population_urban_08','population_rural_08',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_08']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_08']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_08']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_08']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_08']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_08']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_08_M49C.csv')

omr_M49R = data_08.groupby(['M49R']).sum()[['population_urban_08','population_rural_08',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_08']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_08']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_08']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_08']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_08']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_08']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_08_M49R.csv')

# %%
data_09 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2009(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_09 = data_09.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_09.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_09_M49C.csv')

deaths_M49R = data_09.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_09_M49R.csv')

omr_M49C = data_09.groupby(['M49C']).sum()[['population_urban_09','population_rural_09',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_09']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_09']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_09']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_09']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_09']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_09']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_09_M49C.csv')

omr_M49R = data_09.groupby(['M49R']).sum()[['population_urban_09','population_rural_09',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_09']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_09']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_09']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_09']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_09']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_09']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_09_M49R.csv')

# %%
data_10 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2010(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_10 = data_10.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_10.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_10_M49C.csv')

deaths_M49R = data_10.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_10_M49R.csv')

omr_M49C = data_10.groupby(['M49C']).sum()[['population_urban_10','population_rural_10',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_10']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_10']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_10']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_10']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_10']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_10']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_10_M49C.csv')

omr_M49R = data_10.groupby(['M49R']).sum()[['population_urban_10','population_rural_10',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_10']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_10']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_10']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_10']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_10']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_10']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_10_M49R.csv')

# %%
data_11 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2011(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_11 = data_11.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_11.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_11_M49C.csv')

deaths_M49R = data_11.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_11_M49R.csv')

omr_M49C = data_11.groupby(['M49C']).sum()[['population_urban_11','population_rural_11',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_11']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_11']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_11']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_11']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_11']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_11']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_11_M49C.csv')

omr_M49R = data_11.groupby(['M49R']).sum()[['population_urban_11','population_rural_11',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_11']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_11']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_11']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_11']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_11']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_11']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_11_M49R.csv')

# %%
data_12 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2012(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_12 = data_12.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_12.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_12_M49C.csv')

deaths_M49R = data_12.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_12_M49R.csv')

omr_M49C = data_12.groupby(['M49C']).sum()[['population_urban_12','population_rural_12',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_12']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_12']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_12']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_12']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_12']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_12']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_12_M49C.csv')

omr_M49R = data_12.groupby(['M49R']).sum()[['population_urban_12','population_rural_12',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_12']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_12']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_12']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_12']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_12']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_12']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_12_M49R.csv')

# %%
data_13 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2013(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_13 = data_13.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_13.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_13_M49C.csv')

deaths_M49R = data_13.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_13_M49R.csv')

omr_M49C = data_13.groupby(['M49C']).sum()[['population_urban_13','population_rural_13',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_13']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_13']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_13']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_13']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_13']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_13']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_13_M49C.csv')

omr_M49R = data_13.groupby(['M49R']).sum()[['population_urban_13','population_rural_13',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_13']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_13']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_13']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_13']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_13']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_13']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_13_M49R.csv')

# %%
data_14 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2014(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_14 = data_14.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_14.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_14_M49C.csv')

deaths_M49R = data_14.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_14_M49R.csv')

omr_M49C = data_14.groupby(['M49C']).sum()[['population_urban_14','population_rural_14',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_14']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_14']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_14']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_14']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_14']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_14']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_14_M49C.csv')

omr_M49R = data_14.groupby(['M49R']).sum()[['population_urban_14','population_rural_14',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_14']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_14']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_14']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_14']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_14']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_14']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_14_M49R.csv')

# %%
data_15 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2015(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_15 = data_15.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_15.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_15_M49C.csv')

deaths_M49R = data_15.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_15_M49R.csv')

omr_M49C = data_15.groupby(['M49C']).sum()[['population_urban_15','population_rural_15',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_15']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_15']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_15']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_15']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_15']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_15']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_15_M49C.csv')

omr_M49R = data_15.groupby(['M49R']).sum()[['population_urban_15','population_rural_15',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_15']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_15']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_15']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_15']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_15']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_15']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_15_M49R.csv')

# %%
data_16 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2016(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_16 = data_16.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_16.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_16_M49C.csv')

deaths_M49R = data_16.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_16_M49R.csv')

omr_M49C = data_16.groupby(['M49C']).sum()[['population_urban_16','population_rural_16',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_16']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_16']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_16']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_16']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_16']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_16']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_16_M49C.csv')

omr_M49R = data_16.groupby(['M49R']).sum()[['population_urban_16','population_rural_16',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_16']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_16']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_16']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_16']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_16']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_16']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_16_M49R.csv')

# %%
data_17 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2017(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_17 = data_17.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_17.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_17_M49C.csv')

deaths_M49R = data_17.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_17_M49R.csv')

omr_M49C = data_17.groupby(['M49C']).sum()[['population_urban_17','population_rural_17',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_17']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_17']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_17']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_17']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_17']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_17']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_17_M49C.csv')

omr_M49R = data_17.groupby(['M49R']).sum()[['population_urban_17','population_rural_17',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_17']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_17']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_17']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_17']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_17']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_17']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_17_M49R.csv')

# %%
data_18 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2018(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_18 = data_18.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_18.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_18_M49C.csv')

deaths_M49R = data_18.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_18_M49R.csv')

omr_M49C = data_18.groupby(['M49C']).sum()[['population_urban_18','population_rural_18',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_18']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_18']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_18']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_18']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_18']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_18']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_18_M49C.csv')

omr_M49R = data_18.groupby(['M49R']).sum()[['population_urban_18','population_rural_18',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_18']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_18']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_18']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_18']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_18']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_18']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_18_M49R.csv')

# %%
data_19 = pd.read_csv('~/ozone-mortality/ozone-cvd-mortality-2019(v0).csv')
M49 = pd.read_csv('~/Health/M49 list.csv')
data_19 = data_19.merge(M49, how='left', left_on=['arcgis_ID'], right_on=['arcgisID'])                     

deaths_M49C = data_19.groupby(['M49C']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49C = np.round(deaths_M49C,-2)
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_19_M49C.csv')

deaths_M49R = data_19.groupby(['M49R']).sum()[['cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                               'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]
deaths_M49R = np.round(deaths_M49R,-2)
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_19_M49R.csv')

omr_M49C = data_19.groupby(['M49C']).sum()[['population_urban_19','population_rural_19',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49C['cvd_25_omr_urban_est'] = omr_M49C['cvd_25_death_urban_est']/omr_M49C['population_urban_19']*100000
omr_M49C['cvd_25_omr_urban_lb']  = omr_M49C['cvd_25_death_urban_lb']/omr_M49C['population_urban_19']*100000
omr_M49C['cvd_25_omr_urban_ub']  = omr_M49C['cvd_25_death_urban_ub']/omr_M49C['population_urban_19']*100000

omr_M49C['cvd_25_omr_rural_est'] = omr_M49C['cvd_25_death_rural_est']/omr_M49C['population_rural_19']*100000
omr_M49C['cvd_25_omr_rural_lb']  = omr_M49C['cvd_25_death_rural_lb']/omr_M49C['population_rural_19']*100000
omr_M49C['cvd_25_omr_rural_ub']  = omr_M49C['cvd_25_death_rural_ub']/omr_M49C['population_rural_19']*100000

omr_M49C = np.round(omr_M49C[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_19_M49C.csv')

omr_M49R = data_19.groupby(['M49R']).sum()[['population_urban_19','population_rural_19',
                                            'cvd_25_death_urban_est','cvd_25_death_urban_lb','cvd_25_death_urban_ub',
                                            'cvd_25_death_rural_est','cvd_25_death_rural_lb','cvd_25_death_rural_ub']]

omr_M49R['cvd_25_omr_urban_est'] = omr_M49R['cvd_25_death_urban_est']/omr_M49R['population_urban_19']*100000
omr_M49R['cvd_25_omr_urban_lb']  = omr_M49R['cvd_25_death_urban_lb']/omr_M49R['population_urban_19']*100000
omr_M49R['cvd_25_omr_urban_ub']  = omr_M49R['cvd_25_death_urban_ub']/omr_M49R['population_urban_19']*100000

omr_M49R['cvd_25_omr_rural_est'] = omr_M49R['cvd_25_death_rural_est']/omr_M49R['population_rural_19']*100000
omr_M49R['cvd_25_omr_rural_lb']  = omr_M49R['cvd_25_death_rural_lb']/omr_M49R['population_rural_19']*100000
omr_M49R['cvd_25_omr_rural_ub']  = omr_M49R['cvd_25_death_rural_ub']/omr_M49R['population_rural_19']*100000

omr_M49R = np.round(omr_M49R[['cvd_25_omr_urban_est','cvd_25_omr_urban_lb','cvd_25_omr_urban_ub',
                              'cvd_25_omr_rural_est','cvd_25_omr_rural_lb','cvd_25_omr_rural_ub']],1)
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_19_M49R.csv')

# %% [markdown]
# #### Reload the summaries and conduct trend analysis

# %%
deaths_90_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_90_M49C.csv')
deaths_91_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_91_M49C.csv')
deaths_92_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_92_M49C.csv')
deaths_93_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_93_M49C.csv')
deaths_94_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_94_M49C.csv')
deaths_95_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_95_M49C.csv')
deaths_96_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_96_M49C.csv')
deaths_97_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_97_M49C.csv')
deaths_98_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_98_M49C.csv')
deaths_99_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_99_M49C.csv')

deaths_00_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_00_M49C.csv')
deaths_01_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_01_M49C.csv')
deaths_02_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_02_M49C.csv')
deaths_03_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_03_M49C.csv')
deaths_04_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_04_M49C.csv')
deaths_05_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_05_M49C.csv')
deaths_06_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_06_M49C.csv')
deaths_07_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_07_M49C.csv')
deaths_08_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_08_M49C.csv')
deaths_09_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_09_M49C.csv')

deaths_10_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_10_M49C.csv')
deaths_11_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_11_M49C.csv')
deaths_12_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_12_M49C.csv')
deaths_13_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_13_M49C.csv')
deaths_14_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_14_M49C.csv')
deaths_15_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_15_M49C.csv')
deaths_16_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_16_M49C.csv')
deaths_17_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_17_M49C.csv')
deaths_18_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_18_M49C.csv')
deaths_19_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_19_M49C.csv')

# %%
deaths_90_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_90_M49R.csv')
deaths_91_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_91_M49R.csv')
deaths_92_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_92_M49R.csv')
deaths_93_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_93_M49R.csv')
deaths_94_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_94_M49R.csv')
deaths_95_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_95_M49R.csv')
deaths_96_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_96_M49R.csv')
deaths_97_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_97_M49R.csv')
deaths_98_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_98_M49R.csv')
deaths_99_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_99_M49R.csv')

deaths_00_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_00_M49R.csv')
deaths_01_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_01_M49R.csv')
deaths_02_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_02_M49R.csv')
deaths_03_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_03_M49R.csv')
deaths_04_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_04_M49R.csv')
deaths_05_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_05_M49R.csv')
deaths_06_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_06_M49R.csv')
deaths_07_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_07_M49R.csv')
deaths_08_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_08_M49R.csv')
deaths_09_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_09_M49R.csv')

deaths_10_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_10_M49R.csv')
deaths_11_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_11_M49R.csv')
deaths_12_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_12_M49R.csv')
deaths_13_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_13_M49R.csv')
deaths_14_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_14_M49R.csv')
deaths_15_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_15_M49R.csv')
deaths_16_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_16_M49R.csv')
deaths_17_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_17_M49R.csv')
deaths_18_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_18_M49R.csv')
deaths_19_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/deaths_19_M49R.csv')

# %%
omr_90_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_90_M49C.csv')
omr_91_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_91_M49C.csv')
omr_92_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_92_M49C.csv')
omr_93_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_93_M49C.csv')
omr_94_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_94_M49C.csv')
omr_95_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_95_M49C.csv')
omr_96_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_96_M49C.csv')
omr_97_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_97_M49C.csv')
omr_98_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_98_M49C.csv')
omr_99_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_99_M49C.csv')

omr_00_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_00_M49C.csv')
omr_01_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_01_M49C.csv')
omr_02_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_02_M49C.csv')
omr_03_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_03_M49C.csv')
omr_04_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_04_M49C.csv')
omr_05_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_05_M49C.csv')
omr_06_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_06_M49C.csv')
omr_07_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_07_M49C.csv')
omr_08_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_08_M49C.csv')
omr_09_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_09_M49C.csv')

omr_10_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_10_M49C.csv')
omr_11_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_11_M49C.csv')
omr_12_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_12_M49C.csv')
omr_13_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_13_M49C.csv')
omr_14_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_14_M49C.csv')
omr_15_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_15_M49C.csv')
omr_16_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_16_M49C.csv')
omr_17_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_17_M49C.csv')
omr_18_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_18_M49C.csv')
omr_19_M49C = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_19_M49C.csv')

# %%
omr_90_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_90_M49R.csv')
omr_91_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_91_M49R.csv')
omr_92_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_92_M49R.csv')
omr_93_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_93_M49R.csv')
omr_94_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_94_M49R.csv')
omr_95_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_95_M49R.csv')
omr_96_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_96_M49R.csv')
omr_97_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_97_M49R.csv')
omr_98_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_98_M49R.csv')
omr_99_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_99_M49R.csv')

omr_00_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_00_M49R.csv')
omr_01_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_01_M49R.csv')
omr_02_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_02_M49R.csv')
omr_03_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_03_M49R.csv')
omr_04_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_04_M49R.csv')
omr_05_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_05_M49R.csv')
omr_06_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_06_M49R.csv')
omr_07_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_07_M49R.csv')
omr_08_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_08_M49R.csv')
omr_09_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_09_M49R.csv')

omr_10_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_10_M49R.csv')
omr_11_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_11_M49R.csv')
omr_12_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_12_M49R.csv')
omr_13_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_13_M49R.csv')
omr_14_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_14_M49R.csv')
omr_15_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_15_M49R.csv')
omr_16_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_16_M49R.csv')
omr_17_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_17_M49R.csv')
omr_18_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_18_M49R.csv')
omr_19_M49R = pd.read_csv('~/ozone-mortality/results presentation/cache/omr_19_M49R.csv')

# %%
deaths_90_M49C['year']=1990
deaths_91_M49C['year']=1991
deaths_92_M49C['year']=1992
deaths_93_M49C['year']=1993
deaths_94_M49C['year']=1994
deaths_95_M49C['year']=1995
deaths_96_M49C['year']=1996
deaths_97_M49C['year']=1997
deaths_98_M49C['year']=1998
deaths_99_M49C['year']=1999

deaths_00_M49C['year']=2000
deaths_01_M49C['year']=2001
deaths_02_M49C['year']=2002
deaths_03_M49C['year']=2003
deaths_04_M49C['year']=2004
deaths_05_M49C['year']=2005
deaths_06_M49C['year']=2006
deaths_07_M49C['year']=2007
deaths_08_M49C['year']=2008
deaths_09_M49C['year']=2009

deaths_10_M49C['year']=2010
deaths_11_M49C['year']=2011
deaths_12_M49C['year']=2012
deaths_13_M49C['year']=2013
deaths_14_M49C['year']=2014
deaths_15_M49C['year']=2015
deaths_16_M49C['year']=2016
deaths_17_M49C['year']=2017
deaths_18_M49C['year']=2018
deaths_19_M49C['year']=2019

# %%
deaths_90_M49R['year']=1990
deaths_91_M49R['year']=1991
deaths_92_M49R['year']=1992
deaths_93_M49R['year']=1993
deaths_94_M49R['year']=1994
deaths_95_M49R['year']=1995
deaths_96_M49R['year']=1996
deaths_97_M49R['year']=1997
deaths_98_M49R['year']=1998
deaths_99_M49R['year']=1999

deaths_00_M49R['year']=2000
deaths_01_M49R['year']=2001
deaths_02_M49R['year']=2002
deaths_03_M49R['year']=2003
deaths_04_M49R['year']=2004
deaths_05_M49R['year']=2005
deaths_06_M49R['year']=2006
deaths_07_M49R['year']=2007
deaths_08_M49R['year']=2008
deaths_09_M49R['year']=2009

deaths_10_M49R['year']=2010
deaths_11_M49R['year']=2011
deaths_12_M49R['year']=2012
deaths_13_M49R['year']=2013
deaths_14_M49R['year']=2014
deaths_15_M49R['year']=2015
deaths_16_M49R['year']=2016
deaths_17_M49R['year']=2017
deaths_18_M49R['year']=2018
deaths_19_M49R['year']=2019

# %%
omr_90_M49C['year']=1990
omr_91_M49C['year']=1991
omr_92_M49C['year']=1992
omr_93_M49C['year']=1993
omr_94_M49C['year']=1994
omr_95_M49C['year']=1995
omr_96_M49C['year']=1996
omr_97_M49C['year']=1997
omr_98_M49C['year']=1998
omr_99_M49C['year']=1999

omr_00_M49C['year']=2000
omr_01_M49C['year']=2001
omr_02_M49C['year']=2002
omr_03_M49C['year']=2003
omr_04_M49C['year']=2004
omr_05_M49C['year']=2005
omr_06_M49C['year']=2006
omr_07_M49C['year']=2007
omr_08_M49C['year']=2008
omr_09_M49C['year']=2009

omr_10_M49C['year']=2010
omr_11_M49C['year']=2011
omr_12_M49C['year']=2012
omr_13_M49C['year']=2013
omr_14_M49C['year']=2014
omr_15_M49C['year']=2015
omr_16_M49C['year']=2016
omr_17_M49C['year']=2017
omr_18_M49C['year']=2018
omr_19_M49C['year']=2019

# %%
omr_90_M49R['year']=1990
omr_91_M49R['year']=1991
omr_92_M49R['year']=1992
omr_93_M49R['year']=1993
omr_94_M49R['year']=1994
omr_95_M49R['year']=1995
omr_96_M49R['year']=1996
omr_97_M49R['year']=1997
omr_98_M49R['year']=1998
omr_99_M49R['year']=1999

omr_00_M49R['year']=2000
omr_01_M49R['year']=2001
omr_02_M49R['year']=2002
omr_03_M49R['year']=2003
omr_04_M49R['year']=2004
omr_05_M49R['year']=2005
omr_06_M49R['year']=2006
omr_07_M49R['year']=2007
omr_08_M49R['year']=2008
omr_09_M49R['year']=2009

omr_10_M49R['year']=2010
omr_11_M49R['year']=2011
omr_12_M49R['year']=2012
omr_13_M49R['year']=2013
omr_14_M49R['year']=2014
omr_15_M49R['year']=2015
omr_16_M49R['year']=2016
omr_17_M49R['year']=2017
omr_18_M49R['year']=2018
omr_19_M49R['year']=2019

# %%
deaths_M49C = deaths_90_M49C.append(deaths_91_M49C).append(deaths_92_M49C).append(deaths_93_M49C).append(deaths_94_M49C)
deaths_M49C = deaths_M49C.append(deaths_95_M49C).append(deaths_96_M49C).append(deaths_97_M49C).append(deaths_98_M49C).append(deaths_99_M49C)
deaths_M49C = deaths_M49C.append(deaths_00_M49C).append(deaths_01_M49C).append(deaths_02_M49C).append(deaths_03_M49C).append(deaths_04_M49C)
deaths_M49C = deaths_M49C.append(deaths_05_M49C).append(deaths_06_M49C).append(deaths_07_M49C).append(deaths_08_M49C).append(deaths_09_M49C)
deaths_M49C = deaths_M49C.append(deaths_10_M49C).append(deaths_11_M49C).append(deaths_12_M49C).append(deaths_13_M49C).append(deaths_14_M49C)
deaths_M49C = deaths_M49C.append(deaths_15_M49C).append(deaths_16_M49C).append(deaths_17_M49C).append(deaths_18_M49C).append(deaths_19_M49C)

deaths_M49R = deaths_90_M49R.append(deaths_91_M49R).append(deaths_92_M49R).append(deaths_93_M49R).append(deaths_94_M49R)
deaths_M49R = deaths_M49R.append(deaths_95_M49R).append(deaths_96_M49R).append(deaths_97_M49R).append(deaths_98_M49R).append(deaths_99_M49R)
deaths_M49R = deaths_M49R.append(deaths_00_M49R).append(deaths_01_M49R).append(deaths_02_M49R).append(deaths_03_M49R).append(deaths_04_M49R)
deaths_M49R = deaths_M49R.append(deaths_05_M49R).append(deaths_06_M49R).append(deaths_07_M49R).append(deaths_08_M49R).append(deaths_09_M49R)
deaths_M49R = deaths_M49R.append(deaths_10_M49R).append(deaths_11_M49R).append(deaths_12_M49R).append(deaths_13_M49R).append(deaths_14_M49R)
deaths_M49R = deaths_M49R.append(deaths_15_M49R).append(deaths_16_M49R).append(deaths_17_M49R).append(deaths_18_M49R).append(deaths_19_M49R)

omr_M49C = omr_90_M49C.append(omr_91_M49C).append(omr_92_M49C).append(omr_93_M49C).append(omr_94_M49C)
omr_M49C = omr_M49C.append(omr_95_M49C).append(omr_96_M49C).append(omr_97_M49C).append(omr_98_M49C).append(omr_99_M49C)
omr_M49C = omr_M49C.append(omr_00_M49C).append(omr_01_M49C).append(omr_02_M49C).append(omr_03_M49C).append(omr_04_M49C)
omr_M49C = omr_M49C.append(omr_05_M49C).append(omr_06_M49C).append(omr_07_M49C).append(omr_08_M49C).append(omr_09_M49C)
omr_M49C = omr_M49C.append(omr_10_M49C).append(omr_11_M49C).append(omr_12_M49C).append(omr_13_M49C).append(omr_14_M49C)
omr_M49C = omr_M49C.append(omr_15_M49C).append(omr_16_M49C).append(omr_17_M49C).append(omr_18_M49C).append(omr_19_M49C)

omr_M49R = omr_90_M49R.append(omr_91_M49R).append(omr_92_M49R).append(omr_93_M49R).append(omr_94_M49R)
omr_M49R = omr_M49R.append(omr_95_M49R).append(omr_96_M49R).append(omr_97_M49R).append(omr_98_M49R).append(omr_99_M49R)
omr_M49R = omr_M49R.append(omr_00_M49R).append(omr_01_M49R).append(omr_02_M49R).append(omr_03_M49R).append(omr_04_M49R)
omr_M49R = omr_M49R.append(omr_05_M49R).append(omr_06_M49R).append(omr_07_M49R).append(omr_08_M49R).append(omr_09_M49R)
omr_M49R = omr_M49R.append(omr_10_M49R).append(omr_11_M49R).append(omr_12_M49R).append(omr_13_M49R).append(omr_14_M49R)
omr_M49R = omr_M49R.append(omr_15_M49R).append(omr_16_M49R).append(omr_17_M49R).append(omr_18_M49R).append(omr_19_M49R)

# %%
deaths_M49C.to_csv('~/ozone-mortality/results presentation/cache/deaths_M49C.csv')
deaths_M49R.to_csv('~/ozone-mortality/results presentation/cache/deaths_M49R.csv')
omr_M49C.to_csv('~/ozone-mortality/results presentation/cache/omr_M49C.csv')
omr_M49R.to_csv('~/ozone-mortality/results presentation/cache/omr_M49R.csv')

# %% [markdown]
# #### Calculate the tredn statistics

# %%
from sklearn.linear_model import LinearRegression as GLM

# %%
## Americas 

temp = deaths_M49C[deaths_M49C['M49C']=="Americas"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Americas"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49C[omr_M49C['M49C']=="Americas"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Americas.csv', index=False)

# %%
## North America 

temp = deaths_M49R[deaths_M49R['M49R']=="North America"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["North America"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="North America"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_North America.csv', index=False)

# %%
## South America 

temp = deaths_M49R[deaths_M49R['M49R']=="South America"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["South America"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="South America"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_South America.csv', index=False)

# %%
## Europe 

temp = deaths_M49C[deaths_M49C['M49C']=="Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Europe"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49C[omr_M49C['M49C']=="Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Europe.csv', index=False)

# %%
## Northern Europe 

temp = deaths_M49R[deaths_M49R['M49R']=="Northern Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Northern Europe"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Northern Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Northern Europe.csv', index=False)

# %%
## Western Europe 

temp = deaths_M49R[deaths_M49R['M49R']=="Western Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Western Europe"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Western Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Western Europe.csv', index=False)

# %%
## Southern Europe 

temp = deaths_M49R[deaths_M49R['M49R']=="Southern Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Southern Europe"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Southern Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Southern Europe.csv', index=False)

# %%
## Eastern Europe 

temp = deaths_M49R[deaths_M49R['M49R']=="Eastern Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Eastern Europe"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Eastern Europe"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Eastern Europe.csv', index=False)

# %%
## Africa 

temp = deaths_M49C[deaths_M49C['M49C']=="Africa"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Africa"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49C[omr_M49C['M49C']=="Africa"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Africa.csv', index=False)

# %%
## Northern Africa 

temp = deaths_M49R[deaths_M49R['M49R']=="Northern Africa"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["North Africa"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Northern Africa"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Northern Africa.csv', index=False)

# %%
## Sub-Saharan Africa 

temp = deaths_M49R[deaths_M49R['M49R']=="Sub-Saharan Africa"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Sub-Sahara Africa"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Sub-Saharan Africa"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Sub-Saharan Africa.csv', index=False)

# %%
## Asia 

temp = deaths_M49C[deaths_M49C['M49C']=="Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49C[omr_M49C['M49C']=="Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Asia.csv', index=False)

# %%
## Western Asia 

temp = deaths_M49R[deaths_M49R['M49R']=="Western Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Western Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Western Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Western Asia.csv', index=False)

# %%
## Southern Asia 

temp = deaths_M49R[deaths_M49R['M49R']=="Southern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["South Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Southern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Southern Asia.csv', index=False)

# %%
## Southeastern Asia 

temp = deaths_M49R[deaths_M49R['M49R']=="Southeastern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Southeast Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Southeastern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Southeastern Asia.csv', index=False)

# %%
## Southern Asia 

temp = deaths_M49R[deaths_M49R['M49R']=="Southern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["South Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Southern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Southern Asia.csv', index=False)

# %%
## Eastern Asia 

temp = deaths_M49R[deaths_M49R['M49R']=="Eastern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["East Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Eastern Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Eastern Asia.csv', index=False)

# %%
## Central Asia 

temp = deaths_M49R[deaths_M49R['M49R']=="Central Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Central Asia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Central Asia"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Central Asia.csv', index=False)

# %%
## Oceania 

temp = deaths_M49C[deaths_M49C['M49C']=="Oceania"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Oceania"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49C[omr_M49C['M49C']=="Oceania"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Oceania.csv', index=False)

# %%
## Australia and New Zealand 

temp = deaths_M49R[deaths_M49R['M49R']=="Australia and New Zealand"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Australasia"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Australia and New Zealand"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Australia and New Zealand.csv', index=False)

# %%
## Other Oceania 

temp = deaths_M49R[deaths_M49R['M49R']=="Other Oceania"]
X = temp[['year']]

y_urban_est = temp['cvd_25_death_urban_est']
y_urban_lb  = temp['cvd_25_death_urban_lb']
y_urban_ub  = temp['cvd_25_death_urban_ub']
y_rural_est = temp['cvd_25_death_rural_est']
y_rural_lb  = temp['cvd_25_death_rural_lb']
y_rural_ub  = temp['cvd_25_death_rural_ub']

model = GLM()
result = pd.DataFrame(columns={'Region'})
result['Region']=["Other Oceania"]
result['cvd_25_death_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, -1)
result['cvd_25_death_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  -1)
result['cvd_25_death_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  -1)
result['cvd_25_death_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, -1)
result['cvd_25_death_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  -1)
result['cvd_25_death_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  -1)

temp = omr_M49R[omr_M49R['M49R']=="Other Oceania"]
X = temp[['year']]

y_urban_est = temp['cvd_25_omr_urban_est']
y_urban_lb  = temp['cvd_25_omr_urban_lb']
y_urban_ub  = temp['cvd_25_omr_urban_ub']
y_rural_est = temp['cvd_25_omr_rural_est']
y_rural_lb  = temp['cvd_25_omr_rural_lb']
y_rural_ub  = temp['cvd_25_omr_rural_ub']

result['cvd_25_omr_urban_est'] = np.round(model.fit(X,y_urban_est).coef_, 2)
result['cvd_25_omr_urban_lb']  = np.round(model.fit(X,y_urban_lb).coef_,  2)
result['cvd_25_omr_urban_ub']  = np.round(model.fit(X,y_urban_ub).coef_,  2)
result['cvd_25_omr_rural_est'] = np.round(model.fit(X,y_rural_est).coef_, 2)
result['cvd_25_omr_rural_lb']  = np.round(model.fit(X,y_rural_lb).coef_,  2)
result['cvd_25_omr_rural_ub']  = np.round(model.fit(X,y_rural_ub).coef_,  2)

result.to_csv('~/ozone-mortality/results presentation/cache/trends_Other Oceania.csv', index=False)

# %% [markdown]
# #### Result summary incorporation

# %%
result_01 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Africa.csv')
result_02 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Northern Africa.csv')
result_03 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Sub-Saharan Africa.csv')
result_04 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Americas.csv')
result_05 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_North America.csv')
result_06 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_South America.csv')
result_07 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Asia.csv')
result_08 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Central Asia.csv')
result_09 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Eastern Asia.csv')
result_10 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Southeastern Asia.csv')
result_11 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Southern Asia.csv')
result_12 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Western Asia.csv')
result_13 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Europe.csv')
result_14 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Eastern Europe.csv')
result_15 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Northern Europe.csv')
result_16 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Southern Europe.csv')
result_17 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Western Europe.csv')
result_18 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Oceania.csv')
result_19 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Australia and New Zealand.csv')
result_20 = pd.read_csv('~/ozone-mortality/results presentation/cache/trends_Other Oceania.csv')

# %%
results = result_01.append(result_02).append(result_03).append(result_04).append(result_05)
results = results.append(result_06).append(result_07).append(result_08).append(result_09).append(result_10)
results = results.append(result_11).append(result_12).append(result_13).append(result_14).append(result_15)
results = results.append(result_16).append(result_17).append(result_18).append(result_19).append(result_20)
results
# Out:
#               Region  cvd_25_death_urban_est  cvd_25_death_urban_lb  \
# 0             Africa                   210.0                  110.0
# 0       North Africa                   150.0                   80.0
# 0  Sub-Sahara Africa                    60.0                   30.0
# 0           Americas                  -190.0                 -110.0
# 0      North America                  -280.0                 -150.0
# 0      South America                    80.0                   40.0
# 0               Asia                  6550.0                 3490.0
# 0       Central Asia                    30.0                   20.0
# 0          East Asia                  4330.0                 2310.0
# 0     Southeast Asia                   340.0                  180.0
# 0         South Asia                  1570.0                  840.0
# 0       Western Asia                   170.0                   90.0
# 0             Europe                   120.0                   60.0
# ...

# %%
results.to_csv('~/ozone-mortality/results presentation/Extended Table 2 30-year trends.csv', index=False)
