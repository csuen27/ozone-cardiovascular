# %% [markdown]
# # This extended file is to demonstrate why using a different scale for Y-axes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial']
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Here we need to import the global 30-year estimated mortality burden

# %%
trend_glob = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort global trend.csv')

# %% [markdown]
# Here we plot the discrete bar charts setting the Y-axes at a proper scale

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

T = np.arange(1990, 2020, 1)

X1 = trend_glob['cvd_25_death_urban_est']/1000
X2 = trend_glob['cvd_25_death_urban_ub']/1000

Y1 = -trend_glob['cvd_25_death_rural_est']/1000
Y2 = -trend_glob['cvd_25_death_rural_ub']/1000

a = 0.50 

plt.bar(T, X2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, X1, width=a, color = 'salmon', edgecolor=None)

plt.bar(T, Y2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, Y1, width=a, color = 'salmon', edgecolor=None)

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.xlabel("Years")
plt.ylabel("Excess Cardiovascular Deaths")
plt.title("Global")

plt.xlim(1989,2020)
plt.ylim(-800,800)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_northam = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort North America trend.csv')

T = np.arange(1990, 2020, 1)

X1 = trend_northam['cvd_25_death_urban_est']/1000
X2 = trend_northam['cvd_25_death_urban_ub']/1000

Y1 = -trend_northam['cvd_25_death_rural_est']/1000
Y2 = -trend_northam['cvd_25_death_rural_ub']/1000

a = 0.50 

plt.bar(T, X2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, X1, width=a, color = 'salmon', edgecolor=None)

plt.bar(T, Y2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, Y1, width=a, color = 'salmon', edgecolor=None)

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.xlabel("Years")
plt.ylabel("Excess Deaths")
plt.title("North America")

plt.xlim(1989,2020)
plt.ylim(-50,100)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_southam = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort South America trend.csv')
trend_oceania = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Oceania trend.csv')

trend_sao = pd.DataFrame()
trend_sao['cvd_25_death_urban_est'] = trend_southam['cvd_25_death_urban_est'] + trend_oceania['cvd_25_death_urban_est']
trend_sao['cvd_25_death_rural_est'] = trend_southam['cvd_25_death_rural_est'] + trend_oceania['cvd_25_death_rural_est']
trend_sao['cvd_25_death_urban_ub']  = trend_southam['cvd_25_death_urban_ub']  + trend_oceania['cvd_25_death_urban_ub']
trend_sao['cvd_25_death_rural_ub']  = trend_southam['cvd_25_death_rural_ub']  + trend_oceania['cvd_25_death_rural_ub']

T = np.arange(1990, 2020, 1)

X1 = trend_sao['cvd_25_death_urban_est']/1000
X2 = trend_sao['cvd_25_death_urban_ub']/1000

Y1 = -trend_sao['cvd_25_death_rural_est']/1000
Y2 = -trend_sao['cvd_25_death_rural_ub']/1000

a = 0.50 

plt.bar(T, X2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, X1, width=a, color = 'salmon', edgecolor=None)

plt.bar(T, Y2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, Y1, width=a, color = 'salmon', edgecolor=None)

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.xlabel("Years")
plt.ylabel("Excess Deaths")
plt.title("South America and Oceania")

plt.xlim(1989,2020)
plt.ylim(-6,6)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_asia = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Asia trend.csv')

T = np.arange(1990, 2020, 1)

X1 = trend_asia['cvd_25_death_urban_est']/1000
X2 = trend_asia['cvd_25_death_urban_ub']/1000

Y1 = -trend_asia['cvd_25_death_rural_est']/1000
Y2 = -trend_asia['cvd_25_death_rural_ub']/1000

a = 0.50 

plt.bar(T, X2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, X1, width=a, color = 'salmon', edgecolor=None)

plt.bar(T, Y2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, Y1, width=a, color = 'salmon', edgecolor=None)

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.xlabel("Years")
plt.ylabel("Excess Deaths")
plt.title("Asia")

plt.xlim(1989,2020)
plt.ylim(-600,600)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_europe = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Europe trend.csv')

T = np.arange(1990, 2020, 1)

X1 = trend_europe['cvd_25_death_urban_est']/1000
X2 = trend_europe['cvd_25_death_urban_ub']/1000

Y1 = -trend_europe['cvd_25_death_rural_est']/1000
Y2 = -trend_europe['cvd_25_death_rural_ub']/1000

a = 0.50 

plt.bar(T, X2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, X1, width=a, color = 'salmon', edgecolor=None)

plt.bar(T, Y2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, Y1, width=a, color = 'salmon', edgecolor=None)

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.xlabel("Years")
plt.ylabel("Excess Deaths")
plt.title("Europe")

plt.xlim(1989,2020)
plt.ylim(-100,100)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_africa = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Africa trend.csv')

T = np.arange(1990, 2020, 1)

X1 = trend_africa['cvd_25_death_urban_est']/1000
X2 = trend_africa['cvd_25_death_urban_ub']/1000

Y1 = -trend_africa['cvd_25_death_rural_est']/1000
Y2 = -trend_africa['cvd_25_death_rural_ub']/1000

a = 0.50 

plt.bar(T, X2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, X1, width=a, color = 'salmon', edgecolor=None)

plt.bar(T, Y2, width=a, color = 'mistyrose', edgecolor=None)
plt.bar(T, Y1, width=a, color = 'salmon', edgecolor=None)

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.xlabel("Years")
plt.ylabel("Excess Deaths")
plt.title("Africa")

plt.xlim(1989,2020)
plt.ylim(-60,60)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.show()

# %% [markdown]
# #### Cubic spline smoothing

# %%
import seaborn as sns  
from sklearn.metrics import mean_squared_error
from patsy import dmatrix
import statsmodels.api as sm

# %%
df=5
T = np.arange(1990, 2020, 1)
transformed = dmatrix("cr(T,df)", {"T": T}, return_type='dataframe')

X = trend_glob['cvd_25_death_urban_est']
ncs = sm.GLM(X, transformed).fit()
urban_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_glob['cvd_25_death_urban_est_smooth'] = urban_est_pred.values

X = trend_glob['cvd_25_death_urban_ub']
ncs = sm.GLM(X, transformed).fit()
urban_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_glob['cvd_25_death_urban_ub_smooth'] = urban_ub_pred.values

X = trend_glob['cvd_25_death_rural_est']
ncs = sm.GLM(X, transformed).fit()
rural_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_glob['cvd_25_death_rural_est_smooth'] = rural_est_pred.values

X = trend_glob['cvd_25_death_rural_ub']
ncs = sm.GLM(X, transformed).fit()
rural_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_glob['cvd_25_death_rural_ub_smooth'] = rural_ub_pred.values

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

T = np.arange(1990, 2020, 1)

x1 = trend_glob['cvd_25_death_urban_est_smooth']/1000
x2 = trend_glob['cvd_25_death_urban_ub_smooth']/1000

y1 = -trend_glob['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_glob['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.title("Global")

plt.xlim(1990,2019)
plt.ylim(-800,800)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_northam = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort North America trend.csv')
df=5
T = np.arange(1990, 2020, 1)
transformed = dmatrix("cr(T,df)", {"T": T}, return_type='dataframe')

X = trend_northam['cvd_25_death_urban_est']
ncs = sm.GLM(X, transformed).fit()
urban_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_northam['cvd_25_death_urban_est_smooth'] = urban_est_pred.values

X = trend_northam['cvd_25_death_urban_ub']
ncs = sm.GLM(X, transformed).fit()
urban_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_northam['cvd_25_death_urban_ub_smooth'] = urban_ub_pred.values

X = trend_northam['cvd_25_death_rural_est']
ncs = sm.GLM(X, transformed).fit()
rural_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_northam['cvd_25_death_rural_est_smooth'] = rural_est_pred.values

X = trend_northam['cvd_25_death_rural_ub']
ncs = sm.GLM(X, transformed).fit()
rural_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_northam['cvd_25_death_rural_ub_smooth'] = rural_ub_pred.values

T = np.arange(1990, 2020, 1)

x1 = trend_northam['cvd_25_death_urban_est_smooth']/1000
x2 = trend_northam['cvd_25_death_urban_ub_smooth']/1000

y1 = -trend_northam['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_northam['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.title("North America")

plt.xlim(1990,2019)
plt.ylim(-60,60)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

trend_europe = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Europe trend.csv')
df=4
T = np.arange(1990, 2020, 1)
transformed = dmatrix("cr(T,df)", {"T": T}, return_type='dataframe')

X = trend_europe['cvd_25_death_urban_est']
ncs = sm.GLM(X, transformed).fit()
urban_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_europe['cvd_25_death_urban_est_smooth'] = urban_est_pred.values

X = trend_europe['cvd_25_death_urban_ub']
ncs = sm.GLM(X, transformed).fit()
urban_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_europe['cvd_25_death_urban_ub_smooth'] = urban_ub_pred.values

X = trend_europe['cvd_25_death_rural_est']
ncs = sm.GLM(X, transformed).fit()
rural_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_europe['cvd_25_death_rural_est_smooth'] = rural_est_pred.values

X = trend_europe['cvd_25_death_rural_ub']
ncs = sm.GLM(X, transformed).fit()
rural_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_europe['cvd_25_death_rural_ub_smooth'] = rural_ub_pred.values

T = np.arange(1990, 2020, 1)

x1 = trend_europe['cvd_25_death_urban_est_smooth']/1000
x2 = trend_europe['cvd_25_death_urban_ub_smooth']/1000

y1 = -trend_europe['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_europe['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.title("Europe")

plt.xlim(1990,2019)
plt.ylim(-100,100)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

df=4
trend_asia = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Asia trend.csv')

T = np.arange(1990, 2020, 1)
transformed = dmatrix("cr(T,df)", {"T": T}, return_type='dataframe')

X = trend_asia['cvd_25_death_urban_est']
ncs = sm.GLM(X, transformed).fit()
urban_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_asia['cvd_25_death_urban_est_smooth'] = urban_est_pred.values

X = trend_asia['cvd_25_death_urban_ub']
ncs = sm.GLM(X, transformed).fit()
urban_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_asia['cvd_25_death_urban_ub_smooth'] = urban_ub_pred.values

X = trend_asia['cvd_25_death_rural_est']
ncs = sm.GLM(X, transformed).fit()
rural_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_asia['cvd_25_death_rural_est_smooth'] = rural_est_pred.values

X = trend_asia['cvd_25_death_rural_ub']
ncs = sm.GLM(X, transformed).fit()
rural_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_asia['cvd_25_death_rural_ub_smooth'] = rural_ub_pred.values

T = np.arange(1990, 2020, 1)

x1 = trend_asia['cvd_25_death_urban_est_smooth']/1000
x2 = trend_asia['cvd_25_death_urban_ub_smooth']/1000

y1 = -trend_asia['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_asia['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.title("Asia")

plt.xlim(1990,2019)
plt.ylim(-600,600)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

df=4
trend_africa = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Africa trend.csv')

T = np.arange(1990, 2020, 1)
transformed = dmatrix("cr(T,df)", {"T": T}, return_type='dataframe')

X = trend_africa['cvd_25_death_urban_est']
ncs = sm.GLM(X, transformed).fit()
urban_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_africa['cvd_25_death_urban_est_smooth'] = urban_est_pred.values

X = trend_africa['cvd_25_death_urban_ub']
ncs = sm.GLM(X, transformed).fit()
urban_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_africa['cvd_25_death_urban_ub_smooth'] = urban_ub_pred.values

X = trend_africa['cvd_25_death_rural_est']
ncs = sm.GLM(X, transformed).fit()
rural_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_africa['cvd_25_death_rural_est_smooth'] = rural_est_pred.values

X = trend_africa['cvd_25_death_rural_ub']
ncs = sm.GLM(X, transformed).fit()
rural_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_africa['cvd_25_death_rural_ub_smooth'] = rural_ub_pred.values

T = np.arange(1990, 2020, 1)

x1 = trend_africa['cvd_25_death_urban_est_smooth']/1000
x2 = trend_africa['cvd_25_death_urban_ub_smooth']/1000

y1 = -trend_africa['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_africa['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.title("Africa")

plt.xlim(1990,2019)
plt.ylim(-60,60)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(4, 4), dpi=50, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

df=4
trend_southam = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort South America trend.csv')
trend_oceania = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-cardiovascular/Figures/Fig. 2/Fig. 2 mort Oceania trend.csv')

trend_sao = pd.DataFrame()
trend_sao['cvd_25_death_urban_est'] = trend_southam['cvd_25_death_urban_est'] + trend_oceania['cvd_25_death_urban_est']
trend_sao['cvd_25_death_rural_est'] = trend_southam['cvd_25_death_rural_est'] + trend_oceania['cvd_25_death_rural_est']
trend_sao['cvd_25_death_urban_ub']  = trend_southam['cvd_25_death_urban_ub']  + trend_oceania['cvd_25_death_urban_ub']
trend_sao['cvd_25_death_rural_ub']  = trend_southam['cvd_25_death_rural_ub']  + trend_oceania['cvd_25_death_rural_ub']

transformed = dmatrix("cr(T,df)", {"T": T}, return_type='dataframe')

X = trend_sao['cvd_25_death_urban_est']
ncs = sm.GLM(X, transformed).fit()
urban_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_sao['cvd_25_death_urban_est_smooth'] = urban_est_pred.values

X = trend_sao['cvd_25_death_urban_ub']
ncs = sm.GLM(X, transformed).fit()
urban_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_sao['cvd_25_death_urban_ub_smooth'] = urban_ub_pred.values

X = trend_sao['cvd_25_death_rural_est']
ncs = sm.GLM(X, transformed).fit()
rural_est_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_sao['cvd_25_death_rural_est_smooth'] = rural_est_pred.values

X = trend_sao['cvd_25_death_rural_ub']
ncs = sm.GLM(X, transformed).fit()
rural_ub_pred = ncs.predict(dmatrix("cr(T, df)", {"T": T}, return_type='dataframe'))
trend_sao['cvd_25_death_rural_ub_smooth'] = rural_ub_pred.values

T = np.arange(1990, 2020, 1)

x1 = trend_sao['cvd_25_death_urban_est_smooth']/1000
x2 = trend_sao['cvd_25_death_urban_ub_smooth']/1000

y1 = -trend_sao['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_sao['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='-', linewidth = 0.8)

plt.title("South America and Oceania")

plt.xlim(1990,2019)
plt.ylim(-6,6)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(8, 10.5), dpi=300, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

plt.subplot(3,2,1)
T = np.arange(1990, 2020, 1)
x1 =  trend_glob['cvd_25_death_urban_est_smooth']/1000
x2 =  trend_glob['cvd_25_death_urban_ub_smooth']/1000
y1 = -trend_glob['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_glob['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='--', linewidth = 0.8)
plt.title("Global")

plt.xlim(1990,2019)
plt.ylim(-400,400)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.subplot(3,2,2)
x1 =  trend_asia['cvd_25_death_urban_est_smooth']/1000
x2 =  trend_asia['cvd_25_death_urban_ub_smooth']/1000
y1 = -trend_asia['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_asia['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='--', linewidth = 0.8)
plt.title("Asia")

plt.xlim(1990,2019)
plt.ylim(-400,400)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.subplot(3,2,3)
x1 =  trend_northam['cvd_25_death_urban_est_smooth']/1000
x2 =  trend_northam['cvd_25_death_urban_ub_smooth']/1000
y1 = -trend_northam['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_northam['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='--', linewidth = 0.8)

plt.title("North America")

plt.xlim(1990,2019)
plt.ylim(-400,400)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.subplot(3,2,6)
x1 = trend_sao['cvd_25_death_urban_est_smooth']/1000
x2 = trend_sao['cvd_25_death_urban_ub_smooth']/1000
y1 = -trend_sao['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_sao['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='--', linewidth = 0.8)

plt.title("South America and Oceania")

plt.xlim(1990,2019)
plt.ylim(-400,400)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.subplot(3,2,5)
x1 = trend_europe['cvd_25_death_urban_est_smooth']/1000
x2 = trend_europe['cvd_25_death_urban_ub_smooth']/1000
y1 = -trend_europe['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_europe['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='--', linewidth = 0.8)

plt.title("Europe")

plt.xlim(1990,2019)
plt.ylim(-400,400)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
    
plt.subplot(3,2,4)
x1 = trend_africa['cvd_25_death_urban_est_smooth']/1000
x2 = trend_africa['cvd_25_death_urban_ub_smooth']/1000
y1 = -trend_africa['cvd_25_death_rural_est_smooth']/1000
y2 = -trend_africa['cvd_25_death_rural_ub_smooth']/1000

plt.fill_between(T, x2, y2, facecolor = "mistyrose")
plt.fill_between(T, x1, y1, facecolor = "salmon")

plt.axhline(y=0, color='black', linestyle='--', linewidth = 0.8)

plt.title("Africa")

plt.xlim(1990,2019)
plt.ylim(-400,400)
plt.xticks([1990,1995,2000,2005,2010,2015,2019])

ax=plt.gca()
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)

plt.savefig('Figure 3 unify Y-axes for referecne.pdf', bbox_inches='tight')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
mod = LinearRegression()

# %%
y1 = trend_glob['cvd_25_death_urban_est']/1000
y2 = trend_glob['cvd_25_death_rural_est']/1000
X = trend_glob[['year']]
np.round(mod.fit(X,y1).coef_,1),np.round(mod.fit(X,y2).coef_,1)
# Out:
# (array([6.6]), array([2.]))

# %%
y1 = trend_asia['cvd_25_death_urban_est']/1000
y2 = trend_asia['cvd_25_death_rural_est']/1000
X = trend_asia[['year']]
np.round(mod.fit(X,y1).coef_,1),np.round(mod.fit(X,y2).coef_,1)
# Out:
# (array([6.5]), array([3.3]))

# %%
y1 = trend_northam['cvd_25_death_urban_est']/1000
y2 = trend_northam['cvd_25_death_rural_est']/1000
X = trend_northam[['year']]
np.round(mod.fit(X,y1).coef_,1),np.round(mod.fit(X,y2).coef_,1)
# Out:
# (array([-0.3]), array([-0.3]))

# %%
y1 = trend_africa['cvd_25_death_urban_est']/1000
y2 = trend_africa['cvd_25_death_rural_est']/1000
X = trend_africa[['year']]
np.round(mod.fit(X,y1).coef_,1),np.round(mod.fit(X,y2).coef_,1)
# Out:
# (array([0.2]), array([-0.2]))

# %%
y1 = trend_europe['cvd_25_death_urban_est']/1000
y2 = trend_europe['cvd_25_death_rural_est']/1000
X = trend_europe[['year']]
np.round(mod.fit(X,y1).coef_,1),np.round(mod.fit(X,y2).coef_,1)
# Out:
# (array([0.1]), array([-0.9]))

# %%
y1 = trend_sao['cvd_25_death_urban_est']/1000
y2 = trend_sao['cvd_25_death_rural_est']/1000
X = trend_europe[['year']]
np.round(mod.fit(X,y1).coef_,1),np.round(mod.fit(X,y2).coef_,2)
# Out:
# (array([0.1]), array([-0.02]))
